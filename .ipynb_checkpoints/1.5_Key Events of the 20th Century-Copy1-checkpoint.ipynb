# %% [markdown]
# # Text mining LOTR

# %%
from textblob import TextBlob 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import nltk
import re
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from collections import Counter
sns.set()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/woodoooo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/woodoooo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/woodoooo/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ## Tokenization

# %%
myfile = open('Key events of the 20th century_without references.txt', encoding='utf-8')

# %%
# Import txt file

with open('Key events of the 20th century_without references.txt', 'r', errors='ignore') as file:
    data = file.read().replace('\n', ' ').replace('\t', ' ')

# %%
# Sentence tokenization 

from nltk.tokenize import sent_tokenize
tokenized_sent = sent_tokenize(data)
print(tokenized_sent)
# Out:
# ['    Key events of the 20th century - Wikipedia                            Jump to content        Main menu      Main menu move to sidebar hide      Navigation     Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us        Contribute     HelpLearn to editCommunity portalRecent changesUpload fileSpecial pages                    Search            Search                       Appearance                 Donate  Create account  Log in         Personal tools      Donate Create account Log in        Pages for logged out editors learn more    ContributionsTalk                             Contents move to sidebar hide     (Top)      1 Historic events in the 20th century     Toggle Historic events in the 20th century subsection      1.1 World at the beginning of the century       1.1.1 "The war to end all wars": World War I (1914–1918)           1.2 Spanish flu       1.2.1 Russian Revolution and communism           1.3 Between the wars       1.3.1 Economic depression         1.3.2 The rise of dictatorship           1.4 Global war: World War II (1939–1945)       1.4.1 The war in Europe         1.4.2 Blitzkrieg         1.4.3 Operation Barbarossa         1.4.4 Turning tides         1.4.5 Operation Overlord         1.4.6 Final days         1.4.7 The war in the Pacific       1.4.7.1 Background           1.4.8 Japanese Expansion         1.4.9 Allied offensive         1.4.10 Final days         1.4.11 The Holocaust         1.4.12 The Nuclear Age begins           1.5 The post-war world       1.5.1 The end of empires: decolonization         1.5.2 The Cold War (1947–1991)         1.5.3 War by proxy         1.5.4 The space race         1.5.5 The end of the Cold War         1.5.6 Information and communications technology           1.6 The world at the end of the century           2 See also         3 References         4 Sources         5 External links                   Toggle the table of contents        Key events of the 20th century    2 languages     العربيةУкраїнська  Edit links            ArticleTalk      English                  ReadEditView history        Tools      Tools move to sidebar hide      Actions     ReadEditView history        General     What links hereRelated changesUpload filePermanent linkPage informationCite this pageGet shortened URLDownload QR code        Print/export     Download as PDFPrintable version        In other projects     Wikimedia CommonsWikidata item                      Appearance move to sidebar hide           From Wikipedia, the free encyclopedia    The 20th century changed the world in unprecedented ways.', 'The World Wars sparked tension between countries and led to the creation of atomic bombs, the Cold War led to the Space Race and the creation of space-based rockets, and the World Wide Web was created.', "These advancements have played a significant role in citizens' lives and shaped the 21st century into what it is today.", 'Historic events in the 20th century[edit] World at the beginning of the century[edit] Main article: Edwardian era The new beginning of the 20th century marked significant changes.', 'The 1900s saw the decade herald a series of inventions, including the automobile, airplane and radio broadcasting.', '1914 saw the completion of the Panama Canal.', 'The Scramble for Africa continued in the 1900s and resulted in wars and genocide across the continent.', 'The atrocities in the Congo Free State shocked the civilized world.', 'From 1914 to 1918, the First World War, and its aftermath, caused major changes in the power balance of the world, destroying or transforming some of the most powerful empires.', '"The war to end all wars": World War I (1914–1918)[edit] Main article: World War I Arrest of a suspect in Sarajevo following the Assassination of Archduke Franz Ferdinand The First World War (or simply WWI), termed "The Great War" by contemporaries, started in July 1914 and ended in November 1918.', "The war was precipitated by the Assassination in Sarajevo of the Austr ...

# %%
# Word tokenization

from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(data)
print(tokenized_word)
# Out:
# ['Key', 'events', 'of', 'the', '20th', 'century', '-', 'Wikipedia', 'Jump', 'to', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'to', 'sidebar', 'hide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'us', 'Contribute', 'HelpLearn', 'to', 'editCommunity', 'portalRecent', 'changesUpload', 'fileSpecial', 'pages', 'Search', 'Search', 'Appearance', 'Donate', 'Create', 'account', 'Log', 'in', 'Personal', 'tools', 'Donate', 'Create', 'account', 'Log', 'in', 'Pages', 'for', 'logged', 'out', 'editors', 'learn', 'more', 'ContributionsTalk', 'Contents', 'move', 'to', 'sidebar', 'hide', '(', 'Top', ')', '1', 'Historic', 'events', 'in', 'the', '20th', 'century', 'Toggle', 'Historic', 'events', 'in', 'the', '20th', 'century', 'subsection', '1.1', 'World', 'at', 'the', 'beginning', 'of', 'the', 'century', '1.1.1', '``', 'The', 'war', 'to', 'end', 'all', 'wars', "''", ':', 'World', 'War', 'I', '(', '1914–1918', ')', '1.2', 'Spanish', 'flu', '1.2.1', 'Russian', 'Revolution', 'and', 'communism', '1.3', 'Between', 'the', 'wars', '1.3.1', 'Economic', 'depression', '1.3.2', 'The', 'rise', 'of', 'dictatorship', '1.4', 'Global', 'war', ':', 'World', 'War', 'II', '(', '1939–1945', ')', '1.4.1', 'The', 'war', 'in', 'Europe', '1.4.2', 'Blitzkrieg', '1.4.3', 'Operation', 'Barbarossa', '1.4.4', 'Turning', 'tides', '1.4.5', 'Operation', 'Overlord', '1.4.6', 'Final', 'days', '1.4.7', 'The', 'war', 'in', 'the', 'Pacific', '1.4.7.1', 'Background', '1.4.8', 'Japanese', 'Expansion', '1.4.9', 'Allied', 'offensive', '1.4.10', 'Final', 'days', '1.4.11', 'The', 'Holocaust', '1.4.12', 'The', 'Nuclear', 'Age', 'begins', '1.5', 'The', 'post-war', 'world', '1.5.1', 'The', 'end', 'of', 'empires', ':', 'decolonization', '1.5.2', 'The', 'Cold', 'War', '(', '1947–1991', ')', '1.5.3', 'War', 'by', 'proxy', '1.5.4', 'The', 'space', 'race', '1.5.5', 'The', 'end', 'of', 'the', 'Cold', 'War', '1.5.6', 'Information', 'and', 'communications', 'technology', '1.6', 'The', 'world', 'at', 'the', 'end', 'of', 'the', 'century', '2', 'See', 'also', '3', 'References', '4', 'Sources', '5', 'External', 'links', 'Toggle', 'the', 'table', 'of', 'contents', 'Key', 'events', 'of', 'the', '20th', 'century', '2', 'languages', 'العربيةУкраїнська', 'Edit', 'links', 'ArticleTalk', 'English', 'ReadEditView', 'history', 'Tools', 'Tools', 'move', 'to', 'sidebar', 'hide', 'Actions', 'ReadEditView', 'history', 'General', 'What', 'links', 'hereRelated', 'changesUpload', 'filePermanent', 'linkPage', 'informationCite', 'this', 'pageGet', 'shortened', 'URLDownload', 'QR', 'code', 'Print/export', 'Download', 'as', 'PDFPrintable', 'version', 'In', 'other', 'projects', 'Wikimedia', 'CommonsWikidata', 'item', 'Appearance', 'move', 'to', 'sidebar', 'hide', 'From', 'Wikipedia', ',', 'the', 'free', 'encyclopedia', 'The', '20th', 'century', 'changed', 'the', 'world', 'in', 'unprecedented', 'ways', '.', 'The', 'World', 'Wars', 'sparked', 'tension', 'between', 'countries', 'and', 'led', 'to', 'the', 'creation', 'of', 'atomic', 'bombs', ',', 'the', 'Cold', 'War', 'led', 'to', 'the', 'Space', 'Race', 'and', 'the', 'creation', 'of', 'space-based', 'rockets', ',', 'and', 'the', 'World', 'Wide', 'Web', 'was', 'created', '.', 'These', 'advancements', 'have', 'played', 'a', 'significant', 'role', 'in', 'citizens', "'", 'lives', 'and', 'shaped', 'the', '21st', 'century', 'into', 'what', 'it', 'is', 'today', '.', 'Historic', 'events', 'in', 'the', '20th', 'century', '[', 'edit', ']', 'World', 'at', 'the', 'beginning', 'of', 'the', 'century', '[', 'edit', ']', 'Main', 'article', ':', 'Edwardian', 'era', 'The', 'new', 'beginning', 'of', 'the', '20th', 'century', 'marked', 'significant', 'changes', '.', 'The', '1900s', 'saw', 'the', 'decade', 'herald', 'a', 'series', 'of', 'inventions', ',', 'including', 'the', 'automobile', ',', 'airplane', 'and', 'radio', 'broadcasting', '.', '1914', 'saw', 'the', 'completion', 'of', 'the', 'Panama', 'Canal', '.', 'The', 'Scramble', 'for ...

# %%
# Create frequency distribution

from nltk.probability import FreqDist
dist_words = FreqDist(tokenized_word)
print(dist_words)
# Out:
# <FreqDist with 3382 samples and 13555 outcomes>

# %%
dist_words.most_common(10)
# Out:
# [('the', 962),
#  (',', 720),
#  ('of', 452),
#  ('.', 450),
#  ('and', 343),
#  ('to', 306),
#  ('[', 304),
#  (']', 304),
#  ('in', 253),
#  ('a', 171)]

# %%
# Frequency Distribution Plot

plt.figure(figsize=(8, 3))
dist_words.plot(10,cumulative = False)
plt.show()

# %% [markdown]
# ## Stopwords

# %%
# Defining stopwords

from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# {'into', 'myself', 'shouldn', 'if', 'me', "she'd", "they'd", 'hadn', 'on', "should've", 'most', 'about', 'at', 'ours', "won't", 'above', "i'll", 'with', 've', 'ma', 'same', "mightn't", 'hasn', 'herself', 'doing', 'all', 'can', 'had', 'his', 'hers', 'o', "weren't", 'wouldn', 'your', 'shan', "hasn't", 'being', "they'll", "i'm", 's', 'as', 'he', 'in', 'doesn', "he'd", 'itself', 'having', 'ourselves', 'did', "we've", 'him', "we'd", "needn't", 'because', "you'd", 'such', 'needn', 'so', "she'll", 'under', 'aren', 'out', 'them', "we're", "she's", 'theirs', 'during', 'himself', "doesn't", 'our', 'below', 'those', 'been', 're', "it'd", 'will', "you'll", "you've", 'over', "that'll", 'against', 'why', 'of', "haven't", 'too', 'mustn', 'couldn', 'not', 'to', 'before', 'be', 'once', 'a', "they're", "we'll", 'when', 'after', 'nor', 'should', 'again', 'wasn', 'up', 'there', "it's", 'themselves', "isn't", 'from', 'mightn', 'was', 'by', 'more', 'between', 't', 'my', "he'll", 'for', "didn't", 'its', 'y', 'haven', 'further', 'll', 'we', 'which', 'she', 'has', 'off', 'few', 'other', 'is', "hadn't", 'only', 'ain', 'it', 'who', 'yours', 'just', 'then', 'these', 'any', 'their', 'her', 'do', 'and', "shouldn't", "i'd", 'until', 'now', 'the', 'through', "wouldn't", 'you', 'an', "couldn't", 'were', "i've", 'm', "shan't", 'but', 'isn', 'am', 'while', 'down', 'whom', 'are', 'some', "mustn't", 'what', "he's", 'i', 'won', "don't", 'here', 'weren', 'own', 'didn', 'than', 'does', 'how', 'very', 'this', 'or', 'yourself', 'where', 'each', "they've", "wasn't", "you're", 'don', 'they', 'have', 'd', "it'll", 'that', 'yourselves', "aren't", 'both', 'no'}

# %%
# Removing stopwords in words

filtered_words = [] # creates an empty list
for word in tokenized_word:
    if word not in stop_words:
        filtered_words.append(word)

# %%
filtered_words
# Out:
# ['Key',
#  'events',
#  '20th',
#  'century',
#  '-',
#  'Wikipedia',
#  'Jump',
#  'content',
#  'Main',
#  'menu',
#  'Main',
#  'menu',
#  'move',
#  'sidebar',
#  'hide',
#  'Navigation',
#  'Main',
#  'pageContentsCurrent',
#  'eventsRandom',
#  'articleAbout',
#  'WikipediaContact',
#  'us',
#  'Contribute',
#  'HelpLearn',
#  'editCommunity',
#  'portalRecent',
#  'changesUpload',
#  'fileSpecial',
#  'pages',
#  'Search',
#  'Search',
#  'Appearance',
#  'Donate',
#  'Create',
#  'account',
#  'Log',
#  'Personal',
#  'tools',
#  'Donate',
#  'Create',
#  'account',
#  'Log',
#  'Pages',
#  'logged',
#  'editors',
#  'learn',
#  'ContributionsTalk',
#  'Contents',
#  'move',
#  'sidebar',
#  'hide',
#  '(',
#  'Top',
#  ')',
#  '1',
#  'Historic',
#  'events',
#  '20th',
#  'century',
#  'Toggle',
#  'Historic',
#  'events',
#  '20th',
#  'century',
#  'subsection',
#  '1.1',
#  'World',
#  'beginning',
#  'century',
#  '1.1.1',
#  '``',
#  'The',
#  'war',
#  'end',
#  'wars',
#  "''",
#  ':',
#  'World',
#  'War',
#  'I',
#  '(',
#  '1914–1918',
#  ')',
#  '1.2',
#  'Spanish',
#  'flu',
#  '1.2.1',
#  'Russian',
#  'Revolution',
#  'communism',
#  '1.3',
#  'Between',
#  'wars',
#  '1.3.1',
#  'Economic',
#  'depression',
#  '1.3.2',
#  'The',
#  'rise',
#  'dictatorship',
#  '1.4',
#  'Global',
#  'war',
#  ':',
#  'World',
#  'War',
#  'II',
#  '(',
#  '1939–1945',
#  ')',
#  '1.4.1',
#  'The',
#  'war',
#  'Europe',
#  '1.4.2',
#  'Blitzkrieg',
#  '1.4.3',
#  'Operation',
#  'Barbarossa',
#  '1.4.4',
#  'Turning',
#  'tides',
#  '1.4.5',
#  'Operation',
#  'Overlord',
#  '1.4.6',
#  'Final',
#  'days',
#  '1.4.7',
#  'The',
#  'war',
#  'Pacific',
#  '1.4.7.1',
#  'Background',
#  '1.4.8',
#  'Japanese',
#  'Expansion',
#  '1.4.9',
#  'Allied',
#  'offensive',
#  '1.4.10',
#  'Final',
#  'days',
#  '1.4.11',
#  'The',
#  'Holocaust',
#  '1.4.12',
#  'The',
#  'Nuclear',
#  'Age',
#  'begins',
#  '1.5',
#  'The',
#  'post-war',
#  'world',
#  '1.5.1',
#  'The',
#  'end',
#  'empires',
#  ':',
#  'decolonization',
#  '1.5.2',
#  'The',
#  'Cold',
#  'War',
#  '(',
#  '1947–1991',
#  ')',
#  '1.5.3',
#  'War',
#  'proxy',
#  '1.5.4',
#  'The',
#  'space',
#  'race',
#  '1.5.5',
#  'The',
#  'end',
#  'Cold',
#  'War',
#  '1.5.6',
#  'Information',
#  'communications',
#  'technology',
#  '1.6',
#  'The',
#  'world',
#  'end',
#  'century',
#  '2',
#  'See',
#  'also',
#  '3',
#  'References',
#  '4',
#  'Sources',
#  '5',
#  'External',
#  'links',
#  'Toggle',
#  'table',
#  'contents',
#  'Key',
#  'events',
#  '20th',
#  'century',
#  '2',
#  'languages',
#  'العربيةУкраїнська',
#  'Edit',
#  'links',
#  'ArticleTalk',
#  'English',
#  'ReadEditView',
#  'history',
#  'Tools',
#  'Tools',
#  'move',
#  'sidebar',
#  'hide',
#  'Actions',
#  'ReadEditView',
#  'history',
#  'General',
#  'What',
#  'links',
#  'hereRelated',
#  'changesUpload',
#  'filePermanent',
#  'linkPage',
#  'informationCite',
#  'pageGet',
#  'shortened',
#  'URLDownload',
#  'QR',
#  'code',
#  'Print/export',
#  'Download',
#  'PDFPrintable',
#  'version',
#  'In',
#  'projects',
#  'Wikimedia',
#  'CommonsWikidata',
#  'item',
#  'Appearance',
#  'move',
#  'sidebar',
#  'hide',
#  'From',
#  'Wikipedia',
#  ',',
#  'free',
#  'encyclopedia',
#  'The',
#  '20th',
#  'century',
#  'changed',
#  'world',
#  'unprecedented',
#  'ways',
#  '.',
#  'The',
#  'World',
#  'Wars',
#  'sparked',
#  'tension',
#  'countries',
#  'led',
#  'creation',
#  'atomic',
#  'bombs',
#  ',',
#  'Cold',
#  'War',
#  'led',
#  'Space',
#  'Race',
#  'creation',
#  'space-based',
#  'rockets',
#  ',',
#  'World',
#  'Wide',
#  'Web',
#  'created',
#  '.',
#  'These',
#  'advancements',
#  'played',
#  'significant',
#  'role',
#  'citizens',
#  "'",
#  'lives',
#  'shaped',
#  '21st',
#  'century',
#  'today',
#  '.',
#  'Historic',
#  'events',
#  '20th',
#  'century',
#  '[',
#  'edit',
#  ']',
#  'World',
#  'beginning',
#  'century',
#  '[',
#  'edit',
#  ']',
#  'Main',
#  'article',
#  ':',
#  'Edwardian',
#  'era',
#  'The',
#  'new',
#  'beginning',
#  '20th',
#  'century',
#  'marked',
#  'significant',
#  'changes',
#  '.',
#  'The',
#  '1900s',
#  'saw',
#  'decade',
#  'herald',
#  'series',
#  'inventions',
#  ',',
#  'including',
#  'automobile',
#  ',',
#  'airplane',
#  'radio',
#  'broadcasting',
#  '.',
#  '1914',
#  'saw',
#  'completion',
#  'Panama',
#  'Canal',
#  '.',
#  'The',
#  'Scramble',
#  'Africa',
#  'continued',
#  '1900s',
#  'resulted',
#  'wars',
#  'genocide',
#  'across',
#  'continent',
#  '.',
#  'The',
#  'atrocities',
#  'Congo',
#  'Free',
#  'State',
#  'shocked',
#  'civilized',
#  'world',
#  '.',
#  'From',
#  '1914',
#  '1918',
#  ',',
#  'First',
#  'World',
#  'War',
#  ',',
#  'aftermath',
#  ',',
#  'caused',
#  'major',
#  'changes',
#  'power',
#  'balance',
#  'world',
#  ',',
#  'destroying',
#  'transforming',
#  'powerful',
#  'empires',
#  '.',
#  '``',
#  'The',
#  'war',
#  'end',
#  'wars',
#  "''",
#  ':',
#  'World',
#  'War',
#  'I',
#  '(',
#  '1914–1918',
#  ')',
#  '[',
#  'edit',
#  ']',
#  'Main',
#  'article',
#  ':',
#  'World',
#  'War',
#  'I',
#  'Arrest',
#  'suspect',
#  'Sarajevo',
#  'following',
#  'Assassination',
#  'Archduke',
#  'Franz',
#  'Ferdinand',
#  'The',
#  'First',
#  'World',
#  'War',
#  '(',
#  'simply',
#  'WWI',
#  ')',
#  ',',
#  'termed',
#  '``',
#  'The',
#  'Great',
#  'War',
#  "''",
#  'contemporaries',
#  ',',
#  'started',
#  'July',
#  '1914',
#  'ended',
#  'November',
#  '1918',
#  '.',
#  'The',
#  'war',
#  'precipitated',
#  'Assassination',
#  'Sarajevo',
#  'Austro-Hungarian',
#  'Empire',
#  "'s",
#  'heir',
#  'throne',
#  ',',
#  'Erzherzog',
#  'Franz',
#  'Ferdinand',
#  ',',
#  'Gavrilo',
#  'Princip',
#  ',',
#  'member',
#  'Young',
#  'Bosnia',
#  'liberation',
#  'movement',
#  '.',
#  'After',
#  'period',
#  'diplomatic',
#  'military',
#  'escalation',
#  'known',
#  'July',
#  'Crisis',
#  ',',
#  'end',
#  'July',
#  '1914',
#  'two',
#  'coalitions',
#  'war',
#  ':',
#  'Allies',
#  ',',
#  'comprised',
#  'initially',
#  'British',
#  'Empire',
#  ',',
#  'France',
#  ',',
#  'Russian',
#  'Empire',
#  ';',
#  'Central',
#  'Powers',
#  ',',
#  'comprised',
#  'initially',
#  'German',
#  'Empire',
#  'Austria-Hungary',
#  '.',
#  '[',
#  '1',
#  ']',
#  '[',
#  '2',
#  ']',
#  'In',
#  '1917',
#  ',',
#  'Russia',
#  'ended',
#  'hostile',
#  'actions',
#  'Central',
#  'Powers',
#  'fall',
#  'Tsar',
#  '.',
#  'The',
#  'Bolsheviks',
#  'negotiated',
#  'Treaty',
#  'Brest-Litovsk',
#  'Germany',
#  ',',
#  'although',
#  'huge',
#  'cost',
#  'Russia',
#  '.',
#  'In',
#  'treaty',
#  ',',
#  'Bolshevik',
#  'Russia',
#  'ceded',
#  'Baltic',
#  'states',
#  'Germany',
#  ',',
#  'province',
#  'Kars',
#  'Oblast',
#  'South',
#  'Caucasus',
#  'Ottoman',
#  'Empire',
#  '.',
#  'It',
#  'also',
#  'recognized',
#  'independence',
#  'Ukraine',
#  '.',
#  '[',
#  '3',
#  ']',
#  'Although',
#  'Germany',
#  'shifted',
#  'huge',
#  'forces',
#  'eastern',
#  'western',
#  'front',
#  'signing',
#  'treaty',
#  ',',
#  'unable',
#  'stop',
#  'Allied',
#  'advance',
#  ',',
#  'especially',
#  'entrance',
#  'American',
#  'troops',
#  '1918',
#  '.',
#  '[',
#  '4',
#  ']',
#  'The',
#  'war',
#  'also',
#  'chance',
#  'combatant',
#  'nations',
#  'show',
#  'military',
#  'strength',
#  'technological',
#  'ingenuity',
#  '.',
#  'The',
#  'Germans',
#  'introduced',
#  'machine',
#  'gun',
#  ',',
#  '[',
#  '5',
#  ']',
#  'U-boats',
#  '[',
#  '6',
#  ']',
#  'deadly',
#  'gases',
#  '.',
#  '[',
#  '7',
#  ']',
#  'The',
#  'British',
#  'first',
#  'used',
#  'tank',
#  '.',
#  '[',
#  '8',
#  ']',
#  'Both',
#  'sides',
#  'chance',
#  'test',
#  'new',
#  'aircraft',
#  'see',
#  'could',
#  'used',
#  'warfare',
#  '.',
#  'It',
#  'widely',
#  'believed',
#  'war',
#  'would',
#  'short',
#  '.',
#  'Unfortunately',
#  ',',
#  'since',
#  'trench',
#  'warfare',
#  'best',
#  'form',
#  'defense',
#  ',',
#  'advances',
#  'sides',
#  'slow',
#  'came',
#  'terrible',
#  'cost',
#  'lives',
#  '.',
#  '[',
#  '9',
#  ']',
#  'Division',
#  'Austria-Hungary',
#  'World',
#  'War',
#  'I',
#  'When',
#  'war',
#  'finally',
#  '1918',
#  ',',
#  'results',
#  'would',
#  'set',
#  'stage',
#  'next',
#  'twenty',
#  'years',
#  '.',
#  'First',
#  'foremost',
#  ',',
#  'Germans',
#  'forced',
#  'sign',
#  'Treaty',
#  'Versailles',
#  ',',
#  'forcing',
#  'make',
#  'exorbitant',
#  'payments',
#  'repair',
#  'damages',
#  'caused',
#  'War',
#  '.',
#  'Many',
#  'Germans',
#  'felt',
#  'reparations',
#  'unfair',
#  'actually',
#  '``',
#  'lose',
#  "''",
#  'war',
#  'feel',
#  'caused',
#  'war',
#  '(',
#  'see',
#  'Stab-in-the-back',
#  'legend',
#  ')',
#  '.',
#  '[',
#  '10',
#  ']',
#  'Germany',
#  'never',
#  'occupied',
#  'Allied',
#  'troops',
#  ',',
#  'yet',
#  'accept',
#  'liberal',
#  'democratic',
#  'government',
#  'imposed',
#  'victors',
#  'abdication',
#  'Kaiser',
#  'Wilhelm',
#  '.',
#  '[',
#  '11',
#  ']',
#  'Much',
#  'map',
#  'Europe',
#  'redrawn',
#  'victors',
#  'based',
#  'upon',
#  'theory',
#  'future',
#  'wars',
#  'could',
#  'prevented',
#  'ethnic',
#  'groups',
#  '``',
#  'homeland',
#  "''",
#  '.',
#  'New',
#  'states',
#  'like',
#  'Yugoslavia',
#  'Czechoslovakia',
#  'created',
#  'former',
#  'Austro-Hungarian',
#  'Empire',
#  'accommodate',
#  'nationalist',
#  'aspirations',
#  'groups',
#  '.',
#  '[',
#  '12',
#  ']',
#  'An',
#  'international',
#  'body',
#  'called',
#  'League',
#  'Nations',
#  'formed',
#  'mediate',
#  'disputes',
#  'prevent',
#  'future',
#  'wars',
#  ',',
#  'although',
#  'effectiveness',
#  'severely',
#  'limited',
#  ',',
#  'among',
#  'things',
#  ',',
#  'reluctance',
#  'inability',
#  'act',
#  '.',
#  '[',
#  '13',
#  ']',
#  'Spanish',
#  'flu',
#  '[',
#  'edit',
#  ']',
#  'From',
#  '1918',
#  '1920',
#  ',',
#  'remarkably',
#  'deadly',
#  'worldwide',
#  'pandemic',
#  'caused',
#  'flu',
#  'broke',
#  'near',
#  'end',
#  'war',
#  'spread',
#  'globally',
#  '.',
#  'Estimates',
#  'range',
#  'anywhere',
#  '17',
#  '100',
#  'million',
#  'deaths',
#  ',',
#  '[',
#  '14',
#  ']',
#  '[',
#  '15',
#  ']',
#  '[',
#  '16',
#  ']',
#  'staples',
#  'deadliest',
#  'pandemic',
#  'human',
#  'history',
#  '.',
#  'One',
#  'reasons',
#  'exceptionally',
#  'high',
#  'carnage',
#  'wartime',
#  'censorship',
#  'underway',
#  'preserve',
#  'morale',
#  'trenches',
#  ',',
#  'leading',
#  'poor',
#  'hygiene',
#  '.',
#  'Combined',
#  'already',
#  'existing',
#  'malnourishment',
#  'overcrowded',
#  'medical',
#  'facilities',
#  ',',
#  'mix',
#  'made',
#  'deadly',
#  '.',
#  '[',
#  '17',
#  ']',
#  '[',
#  '18',
#  ']',
#  'Russian',
#  'Revolution',
#  'communism',
#  '[',
#  'edit',
#  ']',
#  'Main',
#  'article',
#  ':',
#  'Russian',
#  'Revolution',
#  'The',
#  'Russian',
#  'Revolution',
#  '1917',
#  '(',
#  'ending',
#  'overthrow',
#  'Tsarist',
#  'regime',
#  'execution',
#  'His',
#  'Imperial',
#  'Majesty',
#  'Nicholas',
#  'II',
#  'family',
#  ')',
#  'sparked',
#  'wave',
#  'communist',
#  'revolutions',
#  'across',
#  'Europe',
#  ',',
#  'prompting',
#  'many',
#  'believe',
#  'socialist',
#  'world',
#  'revolution',
#  'could',
#  'realized',
#  'near',
#  'future',
#  '.',
#  '[',
#  '19',
#  ']',
#  'However',
#  ',',
#  'European',
#  'revolutions',
#  'defeated',
#  ',',
#  'Vladimir',
#  'Lenin',
#  'died',
#  '1924',
#  ',',
#  'within',
#  'years',
#  ',',
#  'Joseph',
#  'Stalin',
#  'displaced',
#  'Leon',
#  'Trotsky',
#  'de',
#  'facto',
#  'leader',
#  'Soviet',
#  'Union',
#  '.',
#  'The',
#  'idea',
#  'worldwide',
#  'revolution',
#  'longer',
#  'forefront',
#  ',',
#  'Stalin',
#  'concentrated',
#  '``',
#  'socialism',
#  'one',
#  'country',
#  "''",
#  '[',
#  '20',
#  ']',
#  'embarked',
#  'bold',
#  'plan',
#  'collectivization',
#  'industrialization',
#  '.',
#  '[',
#  '21',
#  ']',
#  'The',
#  'majority',
#  'socialists',
#  'even',
#  'many',
#  'communists',
#  'became',
#  'disillusioned',
#  'Stalin',
#  "'s",
#  'autocratic',
#  'rule',
#  ',',
#  'purges',
#  'assassination',
#  ...]

# %%
# Create a new FreqDist for filtered_words

dist_words_filter = FreqDist(filtered_words)
print(dist_words_filter)
# Out:
# <FreqDist with 3282 samples and 9432 outcomes>

# %%
# Frequency Distribution Plot

plt.figure(figsize=(8, 3))
dist_words_filter.plot(10, cumulative = False)
plt.show()

# %%
dist_words_filter
# Out:
# FreqDist({',': 720, '.': 450, '[': 304, ']': 304, 'The': 147, 'war': 76, 'War': 60, '(': 49, ')': 49, "'s": 47, ...})

# %%
# Substitute all punctuations marks with a space 

sans_punc = re.sub("[^a-zA-Z]",  # Search for all non-letters
                          " ",          # Replace all non-letters with spaces
                          str(filtered_words))

# %%
sans_punc
# Out:
# '  Key    events      th    century         Wikipedia    Jump    content    Main    menu    Main    menu    move    sidebar    hide    Navigation    Main    pageContentsCurrent    eventsRandom    articleAbout    WikipediaContact    us    Contribute    HelpLearn    editCommunity    portalRecent    changesUpload    fileSpecial    pages    Search    Search    Appearance    Donate    Create    account    Log    Personal    tools    Donate    Create    account    Log    Pages    logged    editors    learn    ContributionsTalk    Contents    move    sidebar    hide         Top              Historic    events      th    century    Toggle    Historic    events      th    century    subsection           World    beginning    century                   The    war    end    wars               World    War    I                                  Spanish    flu             Russian    Revolution    communism           Between    wars             Economic    depression             The    rise    dictatorship           Global    war         World    War    II                                    The    war    Europe             Blitzkrieg             Operation    Barbarossa             Turning    tides             Operation    Overlord             Final    days             The    war    Pacific               Background             Japanese    Expansion             Allied    offensive              Final    days              The    Holocaust              The    Nuclear    Age    begins           The    post war    world             The    end    empires         decolonization             The    Cold    War                                    War    proxy             The    space    race             The    end    Cold    War             Information    communications    technology           The    world    end    century         See    also         References         Sources         External    links    Toggle    table    contents    Key    events      th    century         languages                         Edit    links    ArticleTalk    English    ReadEditView    history    Tools    Tools    move    sidebar    hide    Actions    ReadEditView    history    General    What    links    hereRelated    changesUpload    filePermanent    linkPage    informationCite    pageGet    shortened    URLDownload    QR    code    Print export    Download    PDFPrintable    version    In    projects    Wikimedia    CommonsWikidata    item    Appearance    move    sidebar    hide    From    Wikipedia         free    encyclopedia    The      th    century    changed    world    unprecedented    ways         The    World    Wars    sparked    tension    countries    led    creation    atomic    bombs         Cold    War    led    Space    Race    creation    space based    rockets         World    Wide    Web    created         These    advancements    played    significant    role    citizens         lives    shaped      st    century    today         Historic    events      th    century         edit         World    beginning    century         edit         Main    article         Edwardian    era    The    new    beginning      th    century    marked    significant    changes         The        s    saw    decade    herald    series    inventions         including    automobile         airplane    radio    broadcasting                 saw    completion    Panama    Canal         The    Scramble    Africa    continued        s    resulted    wars    genocide    across    continent         The    atrocities    Congo    Free    State    shocked    civilized    world         From                         First    World    War         aftermath         caused    major    changes    power    balance    world         destroying    transforming    powerful    empires               The    war    end    wars               World    War    I                                edit         Main    article         World    War    I    Arrest    suspect    Sarajevo    following    Assa ...

# %%
# Word tokenization

tokenized_word_2 = word_tokenize(sans_punc)
print(tokenized_word_2)
# Out:
# ['Key', 'events', 'th', 'century', 'Wikipedia', 'Jump', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'sidebar', 'hide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'us', 'Contribute', 'HelpLearn', 'editCommunity', 'portalRecent', 'changesUpload', 'fileSpecial', 'pages', 'Search', 'Search', 'Appearance', 'Donate', 'Create', 'account', 'Log', 'Personal', 'tools', 'Donate', 'Create', 'account', 'Log', 'Pages', 'logged', 'editors', 'learn', 'ContributionsTalk', 'Contents', 'move', 'sidebar', 'hide', 'Top', 'Historic', 'events', 'th', 'century', 'Toggle', 'Historic', 'events', 'th', 'century', 'subsection', 'World', 'beginning', 'century', 'The', 'war', 'end', 'wars', 'World', 'War', 'I', 'Spanish', 'flu', 'Russian', 'Revolution', 'communism', 'Between', 'wars', 'Economic', 'depression', 'The', 'rise', 'dictatorship', 'Global', 'war', 'World', 'War', 'II', 'The', 'war', 'Europe', 'Blitzkrieg', 'Operation', 'Barbarossa', 'Turning', 'tides', 'Operation', 'Overlord', 'Final', 'days', 'The', 'war', 'Pacific', 'Background', 'Japanese', 'Expansion', 'Allied', 'offensive', 'Final', 'days', 'The', 'Holocaust', 'The', 'Nuclear', 'Age', 'begins', 'The', 'post', 'war', 'world', 'The', 'end', 'empires', 'decolonization', 'The', 'Cold', 'War', 'War', 'proxy', 'The', 'space', 'race', 'The', 'end', 'Cold', 'War', 'Information', 'communications', 'technology', 'The', 'world', 'end', 'century', 'See', 'also', 'References', 'Sources', 'External', 'links', 'Toggle', 'table', 'contents', 'Key', 'events', 'th', 'century', 'languages', 'Edit', 'links', 'ArticleTalk', 'English', 'ReadEditView', 'history', 'Tools', 'Tools', 'move', 'sidebar', 'hide', 'Actions', 'ReadEditView', 'history', 'General', 'What', 'links', 'hereRelated', 'changesUpload', 'filePermanent', 'linkPage', 'informationCite', 'pageGet', 'shortened', 'URLDownload', 'QR', 'code', 'Print', 'export', 'Download', 'PDFPrintable', 'version', 'In', 'projects', 'Wikimedia', 'CommonsWikidata', 'item', 'Appearance', 'move', 'sidebar', 'hide', 'From', 'Wikipedia', 'free', 'encyclopedia', 'The', 'th', 'century', 'changed', 'world', 'unprecedented', 'ways', 'The', 'World', 'Wars', 'sparked', 'tension', 'countries', 'led', 'creation', 'atomic', 'bombs', 'Cold', 'War', 'led', 'Space', 'Race', 'creation', 'space', 'based', 'rockets', 'World', 'Wide', 'Web', 'created', 'These', 'advancements', 'played', 'significant', 'role', 'citizens', 'lives', 'shaped', 'st', 'century', 'today', 'Historic', 'events', 'th', 'century', 'edit', 'World', 'beginning', 'century', 'edit', 'Main', 'article', 'Edwardian', 'era', 'The', 'new', 'beginning', 'th', 'century', 'marked', 'significant', 'changes', 'The', 's', 'saw', 'decade', 'herald', 'series', 'inventions', 'including', 'automobile', 'airplane', 'radio', 'broadcasting', 'saw', 'completion', 'Panama', 'Canal', 'The', 'Scramble', 'Africa', 'continued', 's', 'resulted', 'wars', 'genocide', 'across', 'continent', 'The', 'atrocities', 'Congo', 'Free', 'State', 'shocked', 'civilized', 'world', 'From', 'First', 'World', 'War', 'aftermath', 'caused', 'major', 'changes', 'power', 'balance', 'world', 'destroying', 'transforming', 'powerful', 'empires', 'The', 'war', 'end', 'wars', 'World', 'War', 'I', 'edit', 'Main', 'article', 'World', 'War', 'I', 'Arrest', 'suspect', 'Sarajevo', 'following', 'Assassination', 'Archduke', 'Franz', 'Ferdinand', 'The', 'First', 'World', 'War', 'simply', 'WWI', 'termed', 'The', 'Great', 'War', 'contemporaries', 'started', 'July', 'ended', 'November', 'The', 'war', 'precipitated', 'Assassination', 'Sarajevo', 'Austro', 'Hungarian', 'Empire', 's', 'heir', 'throne', 'Erzherzog', 'Franz', 'Ferdinand', 'Gavrilo', 'Princip', 'member', 'Young', 'Bosnia', 'liberation', 'movement', 'After', 'period', 'diplomatic', 'military', 'escalation', 'known', 'July', 'Crisis', 'end', 'July', 'two', 'coalitions', 'war', 'Allies', 'comprised', 'initially', 'British', 'Empire', 'France', 'Russian', 'Empire', ' ...

# %%
# Create a new FreqDist

dist_words_filter_2 = FreqDist(tokenized_word_2)

# %%
# Frequency Distribution Plot

plt.figure(figsize=(8, 3))
dist_words_filter_2.plot(30, cumulative = False)
plt.show()

# %%
dist_words_filter_2.most_common(20)
# Out:
# [('The', 148),
#  ('war', 85),
#  ('s', 62),
#  ('War', 60),
#  ('Soviet', 49),
#  ('Hitler', 40),
#  ('first', 37),
#  ('World', 36),
#  ('world', 36),
#  ('would', 35),
#  ('Japanese', 32),
#  ('In', 32),
#  ('Germany', 32),
#  ('German', 31),
#  ('edit', 30),
#  ('century', 29),
#  ('Germans', 29),
#  ('became', 29),
#  ('also', 28),
#  ('Union', 28)]

# %%
words_lower = [word.lower() for word in tokenized_word_2]
from nltk import FreqDist

dist_words_filter_3 = FreqDist(words_lower)
dist_words_filter_3.most_common(20)
# Out:
# [('the', 150),
#  ('war', 145),
#  ('s', 78),
#  ('world', 72),
#  ('soviet', 49),
#  ('first', 40),
#  ('hitler', 40),
#  ('would', 35),
#  ('in', 33),
#  ('new', 33),
#  ('japanese', 32),
#  ('germany', 32),
#  ('edit', 31),
#  ('german', 31),
#  ('century', 29),
#  ('states', 29),
#  ('germans', 29),
#  ('became', 29),
#  ('nuclear', 28),
#  ('also', 28)]

# %% [markdown]
# ## Lowercase & Group similar forms

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/woodoooo/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/woodoooo/nltk_data...
# True

# %%
from textblob import Word
lemmas = [Word(w).lemmatize() for w in words_lower]
from nltk import FreqDist
dist_words_filter_4 = FreqDist(lemmas)
dist_words_filter_4.most_common(20)
# Out:
# [('war', 157),
#  ('the', 150),
#  ('s', 80),
#  ('world', 72),
#  ('german', 60),
#  ('soviet', 53),
#  ('first', 40),
#  ('hitler', 40),
#  ('state', 39),
#  ('would', 35),
#  ('in', 33),
#  ('new', 33),
#  ('japanese', 32),
#  ('germany', 32),
#  ('century', 31),
#  ('edit', 31),
#  ('became', 29),
#  ('weapon', 29),
#  ('u', 28),
#  ('nuclear', 28)]

# %%
new_stopwords = ["the", "s", "would", "edit", "in", "new", "u", "also", "main", "th"]

# %%
filtered = []
for word in lemmas:
    if word not in new_stopwords:
        filtered.append(word)

# %%
from nltk import FreqDist

dist_words_final = FreqDist(filtered)
dist_words_final.most_common(20)
# Out:
# [('war', 157),
#  ('world', 72),
#  ('german', 60),
#  ('soviet', 53),
#  ('first', 40),
#  ('hitler', 40),
#  ('state', 39),
#  ('japanese', 32),
#  ('germany', 32),
#  ('century', 31),
#  ('became', 29),
#  ('weapon', 29),
#  ('nuclear', 28),
#  ('force', 28),
#  ('union', 28),
#  ('attack', 28),
#  ('computer', 28),
#  ('nation', 27),
#  ('battle', 27),
#  ('united', 26)]

# %%
# After cleaning the text by removing stopwords, converting all words to lowercase, 
# and lemmatizing them to their base forms, I created a frequency distribution of the remaining tokens.
# This analysis produced the 20 most frequently used words in the text, 
# revealing the dominant historical themes and key entities mentioned throughout the 20th-century narrative.

# %% [markdown]
# ###  Summary of Most Frequent Words

# %%
# The 20 most frequently used words highlight the dominant historical themes of the twentieth century.
# Terms like “war,” “world,” “battle,” “attack,” “force,” and “weapon” emphasize the prevalence of global conflicts, 
# particularly the two World Wars and the subsequent rise of military power.
# Words such as “german,” “soviet,” “japanese,” “union,” and “united” reflect the key nations and alliances shaping 
# international relations during this period.
# Meanwhile, terms like “nuclear,” “computer,” and “state” point to significant technological and 
# political developments — from the nuclear age to the digital revolution and the expansion of state governance.

# Overall, the frequency distribution reveals a century characterized by warfare, power dynamics, 
# and technological progress that defined modern world history.

# %% [markdown]
# ## POS Tags with TextBlob

# %%
# %%time
text = TextBlob(" ".join(filtered))
# Out:
# CPU times: user 1.03 ms, sys: 68 μs, total: 1.1 ms
# Wall time: 1.11 ms

# %%
text
# Out:
# TextBlob("key event century wikipedia jump content menu menu move sidebar hide navigation pagecontentscurrent eventsrandom articleabout wikipediacontact contribute helplearn editcommunity portalrecent changesupload filespecial page search search appearance donate create account log personal tool donate create account log page logged editor learn contributionstalk content move sidebar hide top historic event century toggle historic event century subsection world beginning century war end war world war i spanish flu russian revolution communism between war economic depression rise dictatorship global war world war ii war europe blitzkrieg operation barbarossa turning tide operation overlord final day war pacific background japanese expansion allied offensive final day holocaust nuclear age begin post war world end empire decolonization cold war war proxy space race end cold war information communication technology world end century see reference source external link toggle table content key event century language link articletalk english readeditview history tool tool move sidebar hide action readeditview history general what link hererelated changesupload filepermanent linkpage informationcite pageget shortened urldownload qr code print export download pdfprintable version project wikimedia commonswikidata item appearance move sidebar hide from wikipedia free encyclopedia century changed world unprecedented way world war sparked tension country led creation atomic bomb cold war led space race creation space based rocket world wide web created these advancement played significant role citizen life shaped st century today historic event century world beginning century article edwardian era beginning century marked significant change saw decade herald series invention including automobile airplane radio broadcasting saw completion panama canal scramble africa continued resulted war genocide across continent atrocity congo free state shocked civilized world from first world war aftermath caused major change power balance world destroying transforming powerful empire war end war world war i article world war i arrest suspect sarajevo following assassination archduke franz ferdinand first world war simply wwi termed great war contemporary started july ended november war precipitated assassination sarajevo austro hungarian empire heir throne erzherzog franz ferdinand gavrilo princip member young bosnia liberation movement after period diplomatic military escalation known july crisis end july two coalition war ally comprised initially british empire france russian empire central power comprised initially german empire austria hungary russia ended hostile action central power fall tsar bolshevik negotiated treaty brest litovsk germany although huge cost russia treaty bolshevik russia ceded baltic state germany province kars oblast south caucasus ottoman empire it recognized independence ukraine although germany shifted huge force eastern western front signing treaty unable stop allied advance especially entrance american troop war chance combatant nation show military strength technological ingenuity german introduced machine gun boat deadly gas british first used tank both side chance test aircraft see could used warfare it widely believed war short unfortunately since trench warfare best form defense advance side slow came terrible cost life division austria hungary world war i when war finally result set stage next twenty year first foremost german forced sign treaty versailles forcing make exorbitant payment repair damage caused war many german felt reparation unfair actually lose war feel caused war see stab back legend germany never occupied allied troop yet accept liberal democratic government imposed victor abdication kaiser wilhelm much map europe redrawn victor based upon theory future war could prevented ethnic group homeland state like yugoslavia czechoslovakia created former austro hungarian empire accommodate nationalist a ...

# %%
tags_list = text.tags

# %%
tags_list
# Out:
# [('key', 'JJ'),
#  ('event', 'NN'),
#  ('century', 'NN'),
#  ('wikipedia', 'VBD'),
#  ('jump', 'NN'),
#  ('content', 'NN'),
#  ('menu', 'NN'),
#  ('menu', 'NN'),
#  ('move', 'NN'),
#  ('sidebar', 'NN'),
#  ('hide', 'NN'),
#  ('navigation', 'NN'),
#  ('pagecontentscurrent', 'NN'),
#  ('eventsrandom', 'NN'),
#  ('articleabout', 'IN'),
#  ('wikipediacontact', 'JJ'),
#  ('contribute', 'NN'),
#  ('helplearn', 'NN'),
#  ('editcommunity', 'NN'),
#  ('portalrecent', 'NN'),
#  ('changesupload', 'NN'),
#  ('filespecial', 'JJ'),
#  ('page', 'NN'),
#  ('search', 'NN'),
#  ('search', 'NN'),
#  ('appearance', 'NN'),
#  ('donate', 'NN'),
#  ('create', 'NN'),
#  ('account', 'NN'),
#  ('log', 'VBD'),
#  ('personal', 'JJ'),
#  ('tool', 'NN'),
#  ('donate', 'NN'),
#  ('create', 'NN'),
#  ('account', 'NN'),
#  ('log', 'JJ'),
#  ('page', 'NN'),
#  ('logged', 'VBD'),
#  ('editor', 'NN'),
#  ('learn', 'NN'),
#  ('contributionstalk', 'NN'),
#  ('content', 'JJ'),
#  ('move', 'NN'),
#  ('sidebar', 'NN'),
#  ('hide', 'NN'),
#  ('top', 'JJ'),
#  ('historic', 'JJ'),
#  ('event', 'NN'),
#  ('century', 'NN'),
#  ('toggle', 'NN'),
#  ('historic', 'JJ'),
#  ('event', 'NN'),
#  ('century', 'NN'),
#  ('subsection', 'NN'),
#  ('world', 'NN'),
#  ('beginning', 'VBG'),
#  ('century', 'NN'),
#  ('war', 'NN'),
#  ('end', 'NN'),
#  ('war', 'NN'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('i', 'VBP'),
#  ('spanish', 'JJ'),
#  ('flu', 'NN'),
#  ('russian', 'JJ'),
#  ('revolution', 'NN'),
#  ('communism', 'NN'),
#  ('between', 'IN'),
#  ('war', 'NN'),
#  ('economic', 'JJ'),
#  ('depression', 'NN'),
#  ('rise', 'NN'),
#  ('dictatorship', 'NN'),
#  ('global', 'JJ'),
#  ('war', 'NN'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('ii', 'JJ'),
#  ('war', 'NN'),
#  ('europe', 'NN'),
#  ('blitzkrieg', 'NN'),
#  ('operation', 'NN'),
#  ('barbarossa', 'IN'),
#  ('turning', 'VBG'),
#  ('tide', 'JJ'),
#  ('operation', 'NN'),
#  ('overlord', 'IN'),
#  ('final', 'JJ'),
#  ('day', 'NN'),
#  ('war', 'NN'),
#  ('pacific', 'NN'),
#  ('background', 'IN'),
#  ('japanese', 'JJ'),
#  ('expansion', 'NN'),
#  ('allied', 'VBD'),
#  ('offensive', 'JJ'),
#  ('final', 'JJ'),
#  ('day', 'NN'),
#  ('holocaust', 'VBD'),
#  ('nuclear', 'JJ'),
#  ('age', 'NN'),
#  ('begin', 'VB'),
#  ('post', 'FW'),
#  ('war', 'NN'),
#  ('world', 'NN'),
#  ('end', 'NN'),
#  ('empire', 'NN'),
#  ('decolonization', 'NN'),
#  ('cold', 'JJ'),
#  ('war', 'NN'),
#  ('war', 'NN'),
#  ('proxy', 'JJ'),
#  ('space', 'NN'),
#  ('race', 'NN'),
#  ('end', 'NN'),
#  ('cold', 'JJ'),
#  ('war', 'NN'),
#  ('information', 'NN'),
#  ('communication', 'NN'),
#  ('technology', 'NN'),
#  ('world', 'NN'),
#  ('end', 'NN'),
#  ('century', 'NN'),
#  ('see', 'VBP'),
#  ('reference', 'NN'),
#  ('source', 'NN'),
#  ('external', 'JJ'),
#  ('link', 'NN'),
#  ('toggle', 'NN'),
#  ('table', 'NN'),
#  ('content', 'NN'),
#  ('key', 'JJ'),
#  ('event', 'NN'),
#  ('century', 'NN'),
#  ('language', 'NN'),
#  ('link', 'VBP'),
#  ('articletalk', 'IN'),
#  ('english', 'JJ'),
#  ('readeditview', 'NN'),
#  ('history', 'NN'),
#  ('tool', 'NN'),
#  ('tool', 'NN'),
#  ('move', 'NN'),
#  ('sidebar', 'NN'),
#  ('hide', 'NN'),
#  ('action', 'NN'),
#  ('readeditview', 'NN'),
#  ('history', 'NN'),
#  ('general', 'JJ'),
#  ('what', 'WP'),
#  ('link', 'VBP'),
#  ('hererelated', 'VBN'),
#  ('changesupload', 'NN'),
#  ('filepermanent', 'NN'),
#  ('linkpage', 'NN'),
#  ('informationcite', 'JJ'),
#  ('pageget', 'NN'),
#  ('shortened', 'VBD'),
#  ('urldownload', 'JJ'),
#  ('qr', 'NN'),
#  ('code', 'NN'),
#  ('print', 'NN'),
#  ('export', 'NN'),
#  ('download', 'NN'),
#  ('pdfprintable', 'JJ'),
#  ('version', 'NN'),
#  ('project', 'NN'),
#  ('wikimedia', 'VBZ'),
#  ('commonswikidata', 'JJ'),
#  ('item', 'NN'),
#  ('appearance', 'NN'),
#  ('move', 'NN'),
#  ('sidebar', 'NN'),
#  ('hide', 'NN'),
#  ('from', 'IN'),
#  ('wikipedia', 'JJ'),
#  ('free', 'JJ'),
#  ('encyclopedia', 'JJ'),
#  ('century', 'NN'),
#  ('changed', 'VBD'),
#  ('world', 'NN'),
#  ('unprecedented', 'JJ'),
#  ('way', 'NN'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('sparked', 'VBD'),
#  ('tension', 'NN'),
#  ('country', 'NN'),
#  ('led', 'VBD'),
#  ('creation', 'NN'),
#  ('atomic', 'JJ'),
#  ('bomb', 'NN'),
#  ('cold', 'VBD'),
#  ('war', 'NN'),
#  ('led', 'VBD'),
#  ('space', 'NN'),
#  ('race', 'NN'),
#  ('creation', 'NN'),
#  ('space', 'NN'),
#  ('based', 'VBN'),
#  ('rocket', 'NN'),
#  ('world', 'NN'),
#  ('wide', 'JJ'),
#  ('web', 'NN'),
#  ('created', 'VBD'),
#  ('these', 'DT'),
#  ('advancement', 'JJ'),
#  ('played', 'VBD'),
#  ('significant', 'JJ'),
#  ('role', 'NN'),
#  ('citizen', 'JJ'),
#  ('life', 'NN'),
#  ('shaped', 'VBD'),
#  ('st', 'JJ'),
#  ('century', 'NN'),
#  ('today', 'NN'),
#  ('historic', 'JJ'),
#  ('event', 'NN'),
#  ('century', 'NN'),
#  ('world', 'NN'),
#  ('beginning', 'VBG'),
#  ('century', 'NN'),
#  ('article', 'NN'),
#  ('edwardian', 'JJ'),
#  ('era', 'NN'),
#  ('beginning', 'VBG'),
#  ('century', 'NN'),
#  ('marked', 'VBD'),
#  ('significant', 'JJ'),
#  ('change', 'NN'),
#  ('saw', 'VBD'),
#  ('decade', 'NN'),
#  ('herald', 'NN'),
#  ('series', 'NN'),
#  ('invention', 'NN'),
#  ('including', 'VBG'),
#  ('automobile', 'NN'),
#  ('airplane', 'NN'),
#  ('radio', 'NN'),
#  ('broadcasting', 'NN'),
#  ('saw', 'VBD'),
#  ('completion', 'NN'),
#  ('panama', 'NN'),
#  ('canal', 'NN'),
#  ('scramble', 'NN'),
#  ('africa', 'NN'),
#  ('continued', 'VBD'),
#  ('resulted', 'JJ'),
#  ('war', 'NN'),
#  ('genocide', 'NN'),
#  ('across', 'IN'),
#  ('continent', 'NN'),
#  ('atrocity', 'NN'),
#  ('congo', 'VBP'),
#  ('free', 'JJ'),
#  ('state', 'NN'),
#  ('shocked', 'VBD'),
#  ('civilized', 'JJ'),
#  ('world', 'NN'),
#  ('from', 'IN'),
#  ('first', 'JJ'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('aftermath', 'NN'),
#  ('caused', 'VBD'),
#  ('major', 'JJ'),
#  ('change', 'NN'),
#  ('power', 'NN'),
#  ('balance', 'NN'),
#  ('world', 'NN'),
#  ('destroying', 'VBG'),
#  ('transforming', 'VBG'),
#  ('powerful', 'JJ'),
#  ('empire', 'NN'),
#  ('war', 'NN'),
#  ('end', 'NN'),
#  ('war', 'NN'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('i', 'NN'),
#  ('article', 'NN'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('i', 'NN'),
#  ('arrest', 'VBP'),
#  ('suspect', 'JJ'),
#  ('sarajevo', 'NN'),
#  ('following', 'VBG'),
#  ('assassination', 'NN'),
#  ('archduke', 'IN'),
#  ('franz', 'NN'),
#  ('ferdinand', 'NN'),
#  ('first', 'JJ'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('simply', 'RB'),
#  ('wwi', 'VBD'),
#  ('termed', 'JJ'),
#  ('great', 'JJ'),
#  ('war', 'NN'),
#  ('contemporary', 'NN'),
#  ('started', 'VBD'),
#  ('july', 'RB'),
#  ('ended', 'JJ'),
#  ('november', 'NNP'),
#  ('war', 'NN'),
#  ('precipitated', 'VBD'),
#  ('assassination', 'NN'),
#  ('sarajevo', 'NN'),
#  ('austro', 'NN'),
#  ('hungarian', 'JJ'),
#  ('empire', 'NN'),
#  ('heir', 'NN'),
#  ('throne', 'NN'),
#  ('erzherzog', 'NN'),
#  ('franz', 'NN'),
#  ('ferdinand', 'NN'),
#  ('gavrilo', 'NN'),
#  ('princip', 'NN'),
#  ('member', 'NN'),
#  ('young', 'JJ'),
#  ('bosnia', 'NN'),
#  ('liberation', 'NN'),
#  ('movement', 'NN'),
#  ('after', 'IN'),
#  ('period', 'NN'),
#  ('diplomatic', 'JJ'),
#  ('military', 'JJ'),
#  ('escalation', 'NN'),
#  ('known', 'VBN'),
#  ('july', 'NN'),
#  ('crisis', 'NN'),
#  ('end', 'NN'),
#  ('july', 'NN'),
#  ('two', 'CD'),
#  ('coalition', 'NN'),
#  ('war', 'NN'),
#  ('ally', 'RB'),
#  ('comprised', 'VBN'),
#  ('initially', 'RB'),
#  ('british', 'JJ'),
#  ('empire', 'NN'),
#  ('france', 'NN'),
#  ('russian', 'JJ'),
#  ('empire', 'NN'),
#  ('central', 'JJ'),
#  ('power', 'NN'),
#  ('comprised', 'VBD'),
#  ('initially', 'RB'),
#  ('german', 'JJ'),
#  ('empire', 'NN'),
#  ('austria', 'NN'),
#  ('hungary', 'JJ'),
#  ('russia', 'NN'),
#  ('ended', 'VBN'),
#  ('hostile', 'JJ'),
#  ('action', 'NN'),
#  ('central', 'JJ'),
#  ('power', 'NN'),
#  ('fall', 'NN'),
#  ('tsar', 'NN'),
#  ('bolshevik', 'NN'),
#  ('negotiated', 'VBN'),
#  ('treaty', 'NN'),
#  ('brest', 'JJS'),
#  ('litovsk', 'RB'),
#  ('germany', 'JJ'),
#  ('although', 'IN'),
#  ('huge', 'JJ'),
#  ('cost', 'NN'),
#  ('russia', 'NN'),
#  ('treaty', 'NN'),
#  ('bolshevik', 'NN'),
#  ('russia', 'NN'),
#  ('ceded', 'VBD'),
#  ('baltic', 'JJ'),
#  ('state', 'NN'),
#  ('germany', 'NN'),
#  ('province', 'NN'),
#  ('kars', 'NNS'),
#  ('oblast', 'IN'),
#  ('south', 'JJ'),
#  ('caucasus', 'NN'),
#  ('ottoman', 'NN'),
#  ('empire', 'NN'),
#  ('it', 'PRP'),
#  ('recognized', 'VBD'),
#  ('independence', 'NN'),
#  ('ukraine', 'NN'),
#  ('although', 'IN'),
#  ('germany', 'NN'),
#  ('shifted', 'VBD'),
#  ('huge', 'JJ'),
#  ('force', 'NN'),
#  ('eastern', 'JJ'),
#  ('western', 'JJ'),
#  ('front', 'NN'),
#  ('signing', 'VBG'),
#  ('treaty', 'NN'),
#  ('unable', 'JJ'),
#  ('stop', 'NN'),
#  ('allied', 'VBD'),
#  ('advance', 'NN'),
#  ('especially', 'RB'),
#  ('entrance', 'JJ'),
#  ('american', 'JJ'),
#  ('troop', 'NN'),
#  ('war', 'NN'),
#  ('chance', 'NN'),
#  ('combatant', 'JJ'),
#  ('nation', 'NN'),
#  ('show', 'NN'),
#  ('military', 'JJ'),
#  ('strength', 'NN'),
#  ('technological', 'JJ'),
#  ('ingenuity', 'NN'),
#  ('german', 'JJ'),
#  ('introduced', 'VBD'),
#  ('machine', 'NN'),
#  ('gun', 'NN'),
#  ('boat', 'NN'),
#  ('deadly', 'RB'),
#  ('gas', 'NN'),
#  ('british', 'JJ'),
#  ('first', 'RB'),
#  ('used', 'VBN'),
#  ('tank', 'NN'),
#  ('both', 'DT'),
#  ('side', 'NN'),
#  ('chance', 'NN'),
#  ('test', 'NN'),
#  ('aircraft', 'NN'),
#  ('see', 'NN'),
#  ('could', 'MD'),
#  ('used', 'VBN'),
#  ('warfare', 'VB'),
#  ('it', 'PRP'),
#  ('widely', 'RB'),
#  ('believed', 'VBD'),
#  ('war', 'NN'),
#  ('short', 'JJ'),
#  ('unfortunately', 'RB'),
#  ('since', 'IN'),
#  ('trench', 'NN'),
#  ('warfare', 'NN'),
#  ('best', 'RBS'),
#  ('form', 'NN'),
#  ('defense', 'NN'),
#  ('advance', 'NN'),
#  ('side', 'NN'),
#  ('slow', 'JJ'),
#  ('came', 'VBD'),
#  ('terrible', 'JJ'),
#  ('cost', 'NN'),
#  ('life', 'NN'),
#  ('division', 'NN'),
#  ('austria', 'IN'),
#  ('hungary', 'JJ'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('i', 'NN'),
#  ('when', 'WRB'),
#  ('war', 'NN'),
#  ('finally', 'RB'),
#  ('result', 'VBZ'),
#  ('set', 'VBN'),
#  ('stage', 'NN'),
#  ('next', 'JJ'),
#  ('twenty', 'NN'),
#  ('year', 'NN'),
#  ('first', 'RB'),
#  ('foremost', 'JJ'),
#  ('german', 'JJ'),
#  ('forced', 'VBN'),
#  ('sign', 'NN'),
#  ('treaty', 'NN'),
#  ('versailles', 'NNS'),
#  ('forcing', 'VBG'),
#  ('make', 'NN'),
#  ('exorbitant', 'JJ'),
#  ('payment', 'NN'),
#  ('repair', 'NN'),
#  ('damage', 'NN'),
#  ('caused', 'VBD'),
#  ('war', 'NN'),
#  ('many', 'JJ'),
#  ('german', 'JJ'),
#  ('felt', 'VBD'),
#  ('reparation', 'NN'),
#  ('unfair', 'NN'),
#  ('actually', 'RB'),
#  ('lose', 'JJ'),
#  ('war', 'NN'),
#  ('feel', 'NN'),
#  ('caused', 'VBD'),
#  ('war', 'NN'),
#  ('see', 'NN'),
#  ('stab', 'VBD'),
#  ('back', 'RB'),
#  ('legend', 'JJ'),
#  ('germany', 'NN'),
#  ('never', 'RB'),
#  ('occupied', 'VBD'),
#  ('allied', 'JJ'),
#  ('troop', 'NN'),
#  ('yet', 'RB'),
#  ('accept', 'JJ'),
#  ('liberal', 'JJ'),
#  ('democratic', 'JJ'),
#  ('government', 'NN'),
#  ('imposed', 'VBD'),
#  ('victor', 'NN'),
#  ('abdication', 'NN'),
#  ('kaiser', 'VBD'),
#  ('wilhelm', 'RB'),
#  ('much', 'JJ'),
#  ('map', 'IN'),
#  ('europe', 'JJ'),
#  ('redrawn', 'NN'),
#  ('victor', 'NN'),
#  ('based', 'VBN'),
#  ('upon', 'IN'),
#  ('theory', 'JJ'),
#  ('future', 'JJ'),
#  ('war', 'NN'),
#  ('could', 'MD'),
#  ('prevented', 'VB'),
#  ('ethnic', 'JJ'),
#  ('group', 'NN'),
#  ('homeland', 'NN'),
#  ('state', 'NN'),
#  ('like', 'IN'),
#  ('yugoslavia', 'NN'),
#  ('czechoslovakia', 'NN'),
#  ('created', 'VBD'),
#  ('former', 'JJ'),
#  ('austro', 'NN'),
#  ('hungarian', 'JJ'),
#  ('empire', 'NN'),
#  ('accommodate', 'NN'),
#  ('nationalist', 'JJ'),
#  ('aspiration', 'NN'),
#  ('group', 'NN'),
#  ('an', 'DT'),
#  ('international', 'JJ'),
#  ('body', 'NN'),
#  ('called', 'VBN'),
#  ('league', 'JJ'),
#  ('nation', 'NN'),
#  ('formed', 'VBD'),
#  ('mediate', 'JJ'),
#  ('dispute', 'NN'),
#  ('prevent', 'JJ'),
#  ('future', 'JJ'),
#  ('war', 'NN'),
#  ('although', 'IN'),
#  ('effectiveness', 'NN'),
#  ('severely', 'RB'),
#  ('limited', 'VBD'),
#  ('among', 'IN'),
#  ('thing', 'NN'),
#  ('reluctance', 'NN'),
#  ('inability', 'NN'),
#  ('act', 'NN'),
#  ('spanish', 'JJ'),
#  ('flu', 'NN'),
#  ('from', 'IN'),
#  ('remarkably', 'RB'),
#  ('deadly', 'JJ'),
#  ('worldwide', 'IN'),
#  ('pandemic', 'JJ'),
#  ('caused', 'VBD'),
#  ('flu', 'JJ'),
#  ('broke', 'VBD'),
#  ('near', 'JJ'),
#  ('end', 'NN'),
#  ('war', 'NN'),
#  ('spread', 'NN'),
#  ('globally', 'RB'),
#  ('estimate', 'JJ'),
#  ('range', 'NN'),
#  ('anywhere', 'RB'),
#  ('million', 'CD'),
#  ('death', 'NN'),
#  ('staple', 'NN'),
#  ('deadliest', 'VBP'),
#  ('pandemic', 'JJ'),
#  ('human', 'JJ'),
#  ('history', 'NN'),
#  ('one', 'CD'),
#  ('reason', 'NN'),
#  ('exceptionally', 'RB'),
#  ('high', 'JJ'),
#  ('carnage', 'NN'),
#  ('wartime', 'NN'),
#  ('censorship', 'NN'),
#  ('underway', 'JJ'),
#  ('preserve', 'NN'),
#  ('morale', 'NN'),
#  ('trench', 'NN'),
#  ('leading', 'VBG'),
#  ('poor', 'JJ'),
#  ('hygiene', 'NN'),
#  ('combined', 'VBN'),
#  ('already', 'RB'),
#  ('existing', 'VBG'),
#  ('malnourishment', 'NN'),
#  ('overcrowded', 'VBD'),
#  ('medical', 'JJ'),
#  ('facility', 'NN'),
#  ('mix', 'NN'),
#  ('made', 'VBD'),
#  ('deadly', 'RB'),
#  ('russian', 'JJ'),
#  ('revolution', 'NN'),
#  ('communism', 'NN'),
#  ('article', 'NN'),
#  ('russian', 'JJ'),
#  ('revolution', 'NN'),
#  ('russian', 'JJ'),
#  ('revolution', 'NN'),
#  ('ending', 'VBG'),
#  ('overthrow', 'JJ'),
#  ('tsarist', 'NN'),
#  ('regime', 'NN'),
#  ('execution', 'NN'),
#  ('his', 'PRP$'),
#  ('imperial', 'JJ'),
#  ('majesty', 'NN'),
#  ('nicholas', 'NNS'),
#  ('ii', 'VBP'),
#  ('family', 'NN'),
#  ('sparked', 'VBN'),
#  ('wave', 'VBP'),
#  ('communist', 'JJ'),
#  ('revolution', 'NN'),
#  ('across', 'IN'),
#  ('europe', 'NN'),
#  ('prompting', 'VBG'),
#  ('many', 'JJ'),
#  ('believe', 'VBP'),
#  ('socialist', 'JJ'),
#  ('world', 'NN'),
#  ('revolution', 'NN'),
#  ('could', 'MD'),
#  ('realized', 'VB'),
#  ('near', 'IN'),
#  ('future', 'JJ'),
#  ('however', 'RB'),
#  ('european', 'JJ'),
#  ('revolution', 'NN'),
#  ('defeated', 'VBD'),
#  ('vladimir', 'JJ'),
#  ('lenin', 'NN'),
#  ('died', 'VBD'),
#  ('within', 'IN'),
#  ('year', 'NN'),
#  ('joseph', 'NN'),
#  ('stalin', 'NN'),
#  ('displaced', 'VBD'),
#  ('leon', 'JJ'),
#  ('trotsky', 'NN'),
#  ('de', 'FW'),
#  ('facto', 'FW'),
#  ('leader', 'NN'),
#  ('soviet', 'JJ'),
#  ('union', 'NN'),
#  ('idea', 'NN'),
#  ('worldwide', 'IN'),
#  ('revolution', 'NN'),
#  ('longer', 'RB'),
#  ('forefront', 'JJ'),
#  ('stalin', 'NN'),
#  ('concentrated', 'VBD'),
#  ('socialism', 'NN'),
#  ('one', 'CD'),
#  ('country', 'NN'),
#  ('embarked', 'VBD'),
#  ('bold', 'JJ'),
#  ('plan', 'NN'),
#  ('collectivization', 'NN'),
#  ('industrialization', 'NN'),
#  ('majority', 'NN'),
#  ('socialist', 'VBD'),
#  ('even', 'RB'),
#  ('many', 'JJ'),
#  ('communist', 'JJ'),
#  ('became', 'VBD'),
#  ('disillusioned', 'JJ'),
#  ('stalin', 'NN'),
#  ('autocratic', 'JJ'),
#  ('rule', 'NN'),
#  ('purge', 'NN'),
#  ('assassination', 'NN'),
#  ('enemy', 'NN'),
#  ('well', 'RB'),
#  ('news', 'NN'),
#  ('famine', 'NN'),
#  ('imposed', 'VBN'),
#  ('people', 'NNS'),
#  ('communism', 'NN'),
#  ('strengthened', 'VBN'),
#  ('force', 'NN'),
#  ('western', 'JJ'),
#  ('democracy', 'NN'),
#  ('global', 'JJ'),
#  ('economy', 'NN'),
#  ('crashed', 'VBD'),
#  ('became', 'VBD'),
#  ('known', 'JJ'),
#  ('great', 'JJ'),
#  ('depression', 'NN'),
#  ('many', 'JJ'),
#  ('people', 'NNS'),
#  ('saw', 'VBD'),
#  ('first', 'JJ'),
#  ('stage', 'JJ'),
#  ('end', 'NN'),
#  ('capitalist', 'NN'),
#  ('system', 'NN'),
#  ('attracted', 'VBD'),
#  ('communism', 'NN'),
#  ('solution', 'NN'),
#  ('economic', 'JJ'),
#  ('crisis', 'NN'),
#  ('especially', 'RB'),
#  ('soviet', 'JJ'),
#  ('union', 'NN'),
#  ('economic', 'JJ'),
#  ('development', 'NN'),
#  ('strong', 'JJ'),
#  ('unaffected', 'JJ'),
#  ('capitalist', 'NN'),
#  ('world', 'NN'),
#  ('crisis', 'NN'),
#  ('between', 'IN'),
#  ('war', 'NN'),
#  ('dorothea', 'NN'),
#  ('lange', 'NN'),
#  ('photo', 'NN'),
#  ('migrant', 'NN'),
#  ('mother', 'NN'),
#  ('one', 'CD'),
#  ('iconic', 'NN'),
#  ('photo', 'NN'),
#  ('associated', 'VBN'),
#  ('great', 'JJ'),
#  ('depression', 'NN'),
#  ('article', 'NN'),
#  ('interwar', 'JJ'),
#  ('period', 'NN'),
#  ('economic', 'JJ'),
#  ('depression', 'NN'),
#  ('article', 'NN'),
#  ('roaring', 'VBG'),
#  ('twenty', 'JJ'),
#  ('great', 'JJ'),
#  ('depression', 'NN'),
#  ('after', 'IN'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('i', 'NN'),
#  ('global', 'JJ'),
#  ('economy', 'NN'),
#  ('remained', 'VBD'),
#  ('strong', 'JJ'),
#  ('war', 'NN'),
#  ('provided', 'VBD'),
#  ('stimulus', 'NN'),
#  ('industry', 'NN'),
#  ('economic', 'JJ'),
#  ('activity', 'NN'),
#  ('general', 'NN'),
#  ('there', 'RB'),
#  ('many', 'JJ'),
#  ('warning', 'VBG'),
#  ('sign', 'NN'),
#  ('foretelling', 'VBG'),
#  ('crash', 'NN'),
#  ('global', 'JJ'),
#  ('economic', 'JJ'),
#  ('system', 'NN'),
#  ('end', 'NN'),
#  ('decade', 'NN'),
#  ('generally', 'RB'),
#  ('understood', 'JJ'),
#  ('political', 'JJ'),
#  ('leadership', 'NN'),
#  ('time', 'NN'),
#  ('response', 'NN'),
#  ('crisis', 'NN'),
#  ('often', 'RB'),
#  ('made', 'VBD'),
#  ('situation', 'NN'),
#  ('worse', 'CD'),
#  ('million', 'CD'),
#  ('people', 'NNS'),
#  ('watched', 'VBD'),
#  ('saving', 'VBG'),
#  ('become', 'VBN'),
#  ('next', 'JJ'),
#  ('worthless', 'JJ'),
#  ('idea', 'NN'),
#  ('steady', 'JJ'),
#  ('job', 'NN'),
#  ('reasonable', 'JJ'),
#  ('income', 'NN'),
#  ('fading', 'VBG'),
#  ('away', 'RB'),
#  ('many', 'JJ'),
#  ('sought', 'JJ'),
#  ('answer', 'NN'),
#  ('alternative', 'JJ'),
#  ('ideology', 'NN'),
#  ('communism', 'NN'),
#  ('fascism', 'NN'),
#  ('they', 'PRP'),
#  ('believed', 'VBD'),
#  ('capitalist', 'JJ'),
#  ('economic', 'JJ'),
#  ('system', 'NN'),
#  ('collapsing', 'VBG'),
#  ('idea', 'NN'),
#  ('required', 'VBN'),
#  ('meet', 'JJ'),
#  ('crisis', 'NN'),
#  ('early', 'JJ'),
#  ('response', 'NN'),
#  ('crisis', 'NN'),
#  ('based', 'VBN'),
#  ('assumption', 'NN'),
#  ('free', 'JJ'),
#  ('market', 'NN'),
#  ('correct', 'NN'),
#  ('this', 'DT'),
#  ('however', 'RB'),
#  ('little', 'JJ'),
#  ('correct', 'JJ'),
#  ('crisis', 'NN'),
#  ('alleviate', 'NN'),
#  ('suffering', 'VBG'),
#  ('many', 'JJ'),
#  ('ordinary', 'JJ'),
#  ('people', 'NNS'),
#  ('thus', 'RB'),
#  ('idea', 'NN'),
#  ('existing', 'VBG'),
#  ('system', 'NN'),
#  ('could', 'MD'),
#  ('reformed', 'VB'),
#  ('government', 'NN'),
#  ('intervention', 'NN'),
#  ('economy', 'NN'),
#  ('rather', 'RB'),
#  ('continuing', 'VBG'),
#  ('laissez', 'JJ'),
#  ('faire', 'JJ'),
#  ('approach', 'NN'),
#  ('became', 'VBD'),
#  ('prominent', 'JJ'),
#  ('solution', 'NN'),
#  ('crisis', 'NN'),
#  ('democratic', 'JJ'),
#  ('government', 'NN'),
#  ('assumed', 'VBD'),
#  ('responsibility', 'NN'),
#  ('provide', 'RB'),
#  ('needed', 'VBD'),
#  ('service', 'NN'),
#  ('society', 'NN'),
#  ('alleviate', 'VBP'),
#  ('poverty', 'NN'),
#  ('soon', 'RB'),
#  ('gave', 'VBD'),
#  ('birth', 'NN'),
#  ('welfare', 'NN'),
#  ('state', 'NN'),
#  ('these', 'DT'),
#  ('two', 'CD'),
#  ('politico', 'VBP'),
#  ('economic', 'JJ'),
#  ('principle', 'NN'),
#  ('belief', 'JJ'),
#  ('government', 'NN'),
#  ('intervention', 'NN'),
#  ('welfare', 'NN'),
#  ('state', 'NN'),
#  ('opposed', 'VBD'),
#  ('belief', 'JJ'),
#  ('free', 'JJ'),
#  ('market', 'NN'),
#  ('private', 'JJ'),
#  ('institution', 'NN'),
#  ('define', 'VB'),
#  ('many', 'JJ'),
#  ('political', 'JJ'),
#  ('battle', 'NN'),
#  ('rest', 'JJ'),
#  ('century', 'NN'),
#  ('rise', 'NN'),
#  ('dictatorship', 'NN'),
#  ('article', 'NN'),
#  ('fascism', 'NN'),
#  ('totalitarianism', 'NN'),
#  ('dictatorship', 'NN'),
#  ('nazi', 'JJ'),
#  ('soldier', 'JJR'),
#  ('hang', 'NN'),
#  ('poster', 'NN'),
#  ('window', 'VBP'),
#  ('jewish', 'JJ'),
#  ('owned', 'JJ'),
#  ('business', 'NN'),
#  ('say', 'VBP'),
#  ('german', 'JJ'),
#  ('defend', 'NN'),
#  ('do', 'VBP'),
#  ('buy', 'VB'),
#  ('jew', 'NNP'),
#  ('germany', 'NN'),
#  ('fascism', 'NN'),
#  ('first', 'RB'),
#  ('appeared', 'VBD'),
#  ('italy', 'JJ'),
#  ('rise', 'NN'),
#  ('power', 'NN'),
#  ('benito', 'NN'),
#  ('mussolini', 'NN'),
#  ('ideology', 'NN'),
#  ('supported', 'VBD'),
#  ('large', 'JJ'),
#  ('proportion', 'NN'),
#  ('upper', 'JJ'),
#  ('class', 'NN'),
#  ('strong', 'JJ'),
#  ('challenge', 'NN'),
#  ('threat', 'NN'),
#  ('communism', 'NN'),
#  ('when', 'WRB'),
#  ('adolf', 'NN'),
#  ('hitler', 'NN'),
#  ('came', 'VBD'),
#  ('power', 'NN'),
#  ('germany', 'NN'),
#  ('variant', 'JJ'),
#  ('fascism', 'NN'),
#  ('called', 'VBN'),
#  ('nazism', 'NN'),
#  ('took', 'VBD'),
#  ('germany', 'NN'),
#  ('ended', 'JJ'),
#  ('german', 'JJ'),
#  ('experiment', 'JJ'),
#  ('democracy', 'NN'),
#  ('nazi', 'JJ'),
#  ('party', 'NN'),
#  ('germany', 'NN'),
#  ('dedicated', 'VBN'),
#  ('restoration', 'JJ'),
#  ('german', 'JJ'),
#  ('honor', 'NN'),
#  ('prestige', 'NN'),
#  ('unification', 'JJ'),
#  ('german', 'JJ'),
#  ('speaking', 'VBG'),
#  ('people', 'NNS'),
#  ('annexation', 'JJ'),
#  ('central', 'JJ'),
#  ('eastern', 'JJ'),
#  ('europe', 'NN'),
#  ('vassal', 'NN'),
#  ('state', 'NN'),
#  ('slavic', 'JJ'),
#  ('population', 'NN'),
#  ('act', 'NN'),
#  ('slave', 'VBP'),
#  ('labor', 'NN'),
#  ('serve', 'VBP'),
#  ('german', 'JJ'),
#  ('economic', 'JJ'),
#  ('interest', 'NN'),
#  ('there', 'RB'),
#  ('strong', 'JJ'),
#  ('appeal', 'NN'),
#  ('mythical', 'JJ'),
#  ('racial', 'JJ'),
#  ('purity', 'NN'),
#  ('idea', 'NN'),
#  ('german', 'JJ'),
#  ('herrenvolk', 'NN'),
#  ('master', 'NN'),
#  ('race', 'NN'),
#  ('vicious', 'JJ'),
#  ('antisemitism', 'NN'),
#  ('promoted', 'VBN'),
#  ('idea', 'NN'),
#  ('jew', 'NN'),
#  ('subhuman', 'JJ'),
#  ('untermensch', 'JJ'),
#  ...]

# %%
df_text = pd.DataFrame(tags_list)
df_text.columns = ['Words', "Word type"]

# %%
df_text.head()
# Out:
#        Words Word type
# 0        key        JJ
# 1      event        NN
# 2    century        NN
# 3  wikipedia       VBD
# 4       jump        NN

# %%
df_t = df_text.groupby('Word type').count().reset_index()

# %%
df_t.head()
# Out:
#   Word type  Words
# 0        CD     74
# 1        DT     49
# 2        FW     12
# 3        IN    188
# 4        JJ   1547

# %%
top10 = df_t.nlargest(10, 'Words')

# %%
plt.figure(figsize=(10, 5))
ax = sns.barplot(
    x="Words",
    y="Word type",
    data=top10
)
ax.set_title("Key events of the 20th century - Top 10 word types used")
plt.show()

# %% [markdown]
# ## Nouns

# %%
df = df_text[(df_text['Word type'] == "NN") | (df_text['Word type'] == "NNS") | (df_text['Word type'] == "NNP")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top15 = y.nlargest(15, 'Occurences')

# %%
top15
# Out:
#           Word  Occurences
# 1164       war         157
# 1190     world          72
# 1029     state          39
# 495     hitler          39
# 176    century          31
# 1134     union          28
# 217   computer          28
# 94      battle          27
# 722     nation          27
# 413      force          26
# 247    country          25
# 572      japan          24
# 448    germany          22
# 1174    weapon          22
# 833      power          22

# %%
plt.figure(figsize=(12, 5))
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x="Word", y="Occurences",
    saturation=0.9, data = top15).set_title("Key events of the 20th century - most frequently used nouns")

# %% [markdown]
# ## Verbs

# %%
df = df_text[(df_text['Word type'] == "VB")  | (df_text['Word type'] == "VBD")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top15 = y.nlargest(15, 'Occurences')

# %%
top15
# Out:
#          Word  Occurences
# 27     became          29
# 162       led          14
# 28      began          13
# 41       came          12
# 170      made          10
# 159  launched           8
# 285      took           7
# 288    turned           7
# 44     caused           6
# 135      held           6
# 9      allied           6
# 268  suffered           6
# 184  occupied           5
# 64    created           5
# 119  followed           5

# %%
# Create the plot
plt.figure(figsize=(12, 5))
sns.barplot(
    x="Word",
    y="Occurences",
    data=top15
)

# Add title
plt.title("Key events of the 20th century - most frequently used verbs")
plt.show()

# %% [markdown]
# ## Adjectives

# %%
df = df_text[df_text['Word type'] == "JJ"]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by=['Occurences'], ascending=False)
top15 = y.nlargest(15, 'Occurences')

# %%
top15
# Out:
#          Word  Occurences
# 265    german          59
# 580    soviet          53
# 341  japanese          32
# 441   nuclear          28
# 387      many          24
# 656    united          23
# 230     first          19
# 81    british          19
# 24   american          19
# 183  economic          14
# 272     great          13
# 262   general          12
# 106      cold          12
# 552    second          12
# 385     major          11

# %%
# Create the plot
plt.figure(figsize=(13, 5))
sns.barplot(
    x="Word",
    y="Occurences",
    data=top15
)

# Add title
plt.title("Key events of the 20th century - most frequently used adjectives")
plt.show()

# %%
# What stands out most in these frequencies is how strongly they reflect the dominant forces that shaped the twentieth century — 
# war, nations, and power.

# The nouns (war, world, state, union, nation, force) show that global conflict and political structures were central themes — 
# the century was defined by wars and the emergence or collapse of powerful states and alliances.

# The verbs (became, led, began, made, launched) emphasize change and action, suggesting a period marked by transformation, 
# leadership, and innovation.

# The adjectives (german, soviet, japanese, nuclear, british, american) reveal the key actors and 
# technologies driving world events — major nations and the rise of nuclear power.

# What stands out is how the language of the text mirrors history itself — 
# a century dominated by wars, nations, and technological advancement, 
# all interconnected through constant movement and transformation.

# %% [markdown]
# ## Counting country names occurences

# %%
listToStr = ' '.join([str(elem) for elem in filtered])
 
print(listToStr)
# Out:
# key event century wikipedia jump content menu menu move sidebar hide navigation pagecontentscurrent eventsrandom articleabout wikipediacontact contribute helplearn editcommunity portalrecent changesupload filespecial page search search appearance donate create account log personal tool donate create account log page logged editor learn contributionstalk content move sidebar hide top historic event century toggle historic event century subsection world beginning century war end war world war i spanish flu russian revolution communism between war economic depression rise dictatorship global war world war ii war europe blitzkrieg operation barbarossa turning tide operation overlord final day war pacific background japanese expansion allied offensive final day holocaust nuclear age begin post war world end empire decolonization cold war war proxy space race end cold war information communication technology world end century see reference source external link toggle table content key event century language link articletalk english readeditview history tool tool move sidebar hide action readeditview history general what link hererelated changesupload filepermanent linkpage informationcite pageget shortened urldownload qr code print export download pdfprintable version project wikimedia commonswikidata item appearance move sidebar hide from wikipedia free encyclopedia century changed world unprecedented way world war sparked tension country led creation atomic bomb cold war led space race creation space based rocket world wide web created these advancement played significant role citizen life shaped st century today historic event century world beginning century article edwardian era beginning century marked significant change saw decade herald series invention including automobile airplane radio broadcasting saw completion panama canal scramble africa continued resulted war genocide across continent atrocity congo free state shocked civilized world from first world war aftermath caused major change power balance world destroying transforming powerful empire war end war world war i article world war i arrest suspect sarajevo following assassination archduke franz ferdinand first world war simply wwi termed great war contemporary started july ended november war precipitated assassination sarajevo austro hungarian empire heir throne erzherzog franz ferdinand gavrilo princip member young bosnia liberation movement after period diplomatic military escalation known july crisis end july two coalition war ally comprised initially british empire france russian empire central power comprised initially german empire austria hungary russia ended hostile action central power fall tsar bolshevik negotiated treaty brest litovsk germany although huge cost russia treaty bolshevik russia ceded baltic state germany province kars oblast south caucasus ottoman empire it recognized independence ukraine although germany shifted huge force eastern western front signing treaty unable stop allied advance especially entrance american troop war chance combatant nation show military strength technological ingenuity german introduced machine gun boat deadly gas british first used tank both side chance test aircraft see could used warfare it widely believed war short unfortunately since trench warfare best form defense advance side slow came terrible cost life division austria hungary world war i when war finally result set stage next twenty year first foremost german forced sign treaty versailles forcing make exorbitant payment repair damage caused war many german felt reparation unfair actually lose war feel caused war see stab back legend germany never occupied allied troop yet accept liberal democratic government imposed victor abdication kaiser wilhelm much map europe redrawn victor based upon theory future war could prevented ethnic group homeland state like yugoslavia czechoslovakia created former austro hungarian empire accommodate nationalist aspiration  ...

# %%
# Create a count for countries

all_counts = Counter(re.sub(r'\W+', ' ', listToStr).split())

# %%
all_counts
# Out:
# Counter({'war': 157,
#          'world': 72,
#          'german': 60,
#          'soviet': 53,
#          'first': 40,
#          'hitler': 40,
#          'state': 39,
#          'japanese': 32,
#          'germany': 32,
#          'century': 31,
#          'became': 29,
#          'weapon': 29,
#          'nuclear': 28,
#          'force': 28,
#          'union': 28,
#          'attack': 28,
#          'computer': 28,
#          'nation': 27,
#          'battle': 27,
#          'united': 26,
#          'japan': 26,
#          'country': 25,
#          'end': 24,
#          'europe': 24,
#          'many': 24,
#          'ally': 23,
#          'day': 22,
#          'power': 22,
#          'army': 21,
#          'allied': 20,
#          'article': 20,
#          'this': 20,
#          'ii': 19,
#          'british': 19,
#          'american': 19,
#          'one': 19,
#          'however': 19,
#          'people': 19,
#          'two': 18,
#          'could': 18,
#          'space': 17,
#          'jew': 17,
#          'later': 17,
#          'stalin': 16,
#          'on': 16,
#          'island': 16,
#          'led': 15,
#          'nazi': 15,
#          'east': 15,
#          'north': 15,
#          'economic': 14,
#          'cold': 14,
#          'general': 14,
#          'july': 14,
#          'known': 14,
#          'france': 14,
#          'time': 14,
#          'city': 14,
#          'history': 13,
#          'africa': 13,
#          'great': 13,
#          'south': 13,
#          'troop': 13,
#          'used': 13,
#          'government': 13,
#          'made': 13,
#          'system': 13,
#          'began': 13,
#          'invasion': 13,
#          'came': 12,
#          'million': 12,
#          'early': 12,
#          'britain': 12,
#          'poland': 12,
#          'air': 12,
#          'second': 12,
#          'berlin': 12,
#          'despite': 12,
#          'network': 12,
#          'empire': 11,
#          'bomb': 11,
#          'major': 11,
#          'after': 11,
#          'eastern': 11,
#          'western': 11,
#          'advance': 11,
#          'year': 11,
#          'group': 11,
#          'human': 11,
#          'communist': 11,
#          'use': 11,
#          'launched': 11,
#          'several': 11,
#          'event': 10,
#          'operation': 10,
#          'pacific': 10,
#          'see': 10,
#          'free': 10,
#          'military': 10,
#          'crisis': 10,
#          'area': 10,
#          'part': 10,
#          'a': 10,
#          'by': 10,
#          'west': 10,
#          'revolution': 9,
#          'communism': 9,
#          'offensive': 9,
#          'race': 9,
#          'including': 9,
#          'next': 9,
#          'plan': 9,
#          'almost': 9,
#          'august': 9,
#          'territory': 9,
#          'republic': 9,
#          'victory': 9,
#          'china': 9,
#          'camp': 9,
#          'korea': 9,
#          'beginning': 8,
#          'i': 8,
#          'holocaust': 8,
#          'post': 8,
#          'creation': 8,
#          'decade': 8,
#          'treaty': 8,
#          'independence': 8,
#          'aircraft': 8,
#          'form': 8,
#          'set': 8,
#          'forced': 8,
#          'leading': 8,
#          'already': 8,
#          'italy': 8,
#          'population': 8,
#          'june': 8,
#          'bombing': 8,
#          'campaign': 8,
#          'largest': 8,
#          'controlled': 8,
#          'naval': 8,
#          'influence': 8,
#          'conflict': 8,
#          'vietnam': 8,
#          'internet': 8,
#          'rise': 7,
#          'global': 7,
#          'russia': 7,
#          'although': 7,
#          'since': 7,
#          'like': 7,
#          'among': 7,
#          'economy': 7,
#          'mussolini': 7,
#          'large': 7,
#          'took': 7,
#          'pact': 7,
#          'september': 7,
#          'defeat': 7,
#          'surrendered': 7,
#          'throughout': 7,
#          'french': 7,
#          'independent': 7,
#          'italian': 7,
#          'turned': 7,
#          'launch': 7,
#          'eventually': 7,
#          'v': 7,
#          'last': 7,
#          'half': 7,
#          'place': 7,
#          'chinese': 7,
#          'surrender': 7,
#          'program': 7,
#          'ssr': 7,
#          'software': 7,
#          'russian': 6,
#          'depression': 6,
#          'dictatorship': 6,
#          'turning': 6,
#          'action': 6,
#          'created': 6,
#          'change': 6,
#          'continued': 6,
#          'caused': 6,
#          'powerful': 6,
#          'following': 6,
#          'ended': 6,
#          'cost': 6,
#          'warfare': 6,
#          'occupied': 6,
#          'upon': 6,
#          'regime': 6,
#          'european': 6,
#          'leader': 6,
#          'idea': 6,
#          'even': 6,
#          'well': 6,
#          'capitalist': 6,
#          'soon': 6,
#          'soldier': 6,
#          'he': 6,
#          'held': 6,
#          'winter': 6,
#          'important': 6,
#          'may': 6,
#          'massive': 6,
#          'with': 6,
#          'third': 6,
#          'at': 6,
#          'suffered': 6,
#          'turn': 6,
#          'planned': 6,
#          'rommel': 6,
#          'effort': 6,
#          'long': 6,
#          'another': 6,
#          'india': 6,
#          'organization': 6,
#          'create': 5,
#          'tide': 5,
#          'final': 5,
#          'expansion': 5,
#          'information': 5,
#          'technology': 5,
#          'project': 5,
#          'from': 5,
#          'way': 5,
#          'marked': 5,
#          'saw': 5,
#          'member': 5,
#          'period': 5,
#          'central': 5,
#          'it': 5,
#          'boat': 5,
#          'finally': 5,
#          'sign': 5,
#          'much': 5,
#          'international': 5,
#          'range': 5,
#          'death': 5,
#          'medical': 5,
#          'ending': 5,
#          'within': 5,
#          'joseph': 5,
#          'rule': 5,
#          'development': 5,
#          'strong': 5,
#          'political': 5,
#          'become': 5,
#          'fascism': 5,
#          'they': 5,
#          'put': 5,
#          'control': 5,
#          'moscow': 5,
#          'week': 5,
#          'ussr': 5,
#          'april': 5,
#          'sea': 5,
#          'six': 5,
#          'border': 5,
#          'entire': 5,
#          'three': 5,
#          'refused': 5,
#          'managed': 5,
#          'taking': 5,
#          'number': 5,
#          'divided': 5,
#          'axis': 5,
#          'harbor': 5,
#          'ground': 5,
#          'churchill': 5,
#          'followed': 5,
#          'possible': 5,
#          'lead': 5,
#          'still': 5,
#          'relation': 5,
#          'occupation': 5,
#          'base': 5,
#          'colony': 5,
#          'killed': 5,
#          'home': 5,
#          'term': 5,
#          'president': 5,
#          'develop': 5,
#          'success': 5,
#          'missile': 5,
#          'developed': 5,
#          'peace': 5,
#          'formation': 5,
#          'problem': 5,
#          'pc': 5,
#          'game': 5,
#          'content': 4,
#          'move': 4,
#          'sidebar': 4,
#          'hide': 4,
#          'personal': 4,
#          'decolonization': 4,
#          'communication': 4,
#          'link': 4,
#          'code': 4,
#          'changed': 4,
#          'atomic': 4,
#          'based': 4,
#          'web': 4,
#          'these': 4,
#          'life': 4,
#          'st': 4,
#          'across': 4,
#          'started': 4,
#          'initially': 4,
#          'austria': 4,
#          'especially': 4,
#          'tank': 4,
#          'division': 4,
#          'when': 4,
#          'back': 4,
#          'never': 4,
#          'future': 4,
#          'ethnic': 4,
#          'yugoslavia': 4,
#          'czechoslovakia': 4,
#          'former': 4,
#          'called': 4,
#          'league': 4,
#          'limited': 4,
#          'near': 4,
#          'spread': 4,
#          'high': 4,
#          'poor': 4,
#          'socialist': 4,
#          'remained': 4,
#          'warning': 4,
#          'often': 4,
#          'market': 4,
#          'ordinary': 4,
#          'intervention': 4,
#          'needed': 4,
#          'rest': 4,
#          'business': 4,
#          'threat': 4,
#          'slave': 4,
#          'take': 4,
#          'theater': 4,
#          'declared': 4,
#          'attacked': 4,
#          'possession': 4,
#          'line': 4,
#          'considered': 4,
#          'paris': 4,
#          'luftwaffe': 4,
#          'core': 4,
#          'atlantic': 4,
#          'bomber': 4,
#          'loss': 4,
#          'station': 4,
#          'using': 4,
#          'small': 4,
#          'quickly': 4,
#          'taken': 4,
#          'signed': 4,
#          'non': 4,
#          'coup': 4,
#          'pearl': 4,
#          'december': 4,
#          'prisoner': 4,
#          'captured': 4,
#          'casualty': 4,
#          'invaded': 4,
#          'assault': 4,
#          'propaganda': 4,
#          'newly': 4,
#          'went': 4,
#          'devastating': 4,
#          'commander': 4,
#          'suicide': 4,
#          'incident': 4,
#          'philippine': 4,
#          'guinea': 4,
#          'strategic': 4,
#          'attacking': 4,
#          'given': 4,
#          'asia': 4,
#          'achieved': 4,
#          'tokyo': 4,
#          'concentration': 4,
#          'rapidly': 4,
#          'involved': 4,
#          'backed': 4,
#          'astronaut': 4,
#          'ibm': 4,
#          'company': 4,
#          'key': 3,
#          'page': 3,
#          'tool': 3,
#          'top': 3,
#          'historic': 3,
#          'spanish': 3,
#          'flu': 3,
#          'between': 3,
#          'blitzkrieg': 3,
#          'overlord': 3,
#          'age': 3,
#          'begin': 3,
#          'tension': 3,
#          'wide': 3,
#          'today': 3,
#          'invention': 3,
#          'airplane': 3,
#          'continent': 3,
#          'assassination': 3,
#          'hungary': 3,
#          'fall': 3,
#          'baltic': 3,
#          'front': 3,
#          'unable': 3,
#          'machine': 3,
#          'deadly': 3,
#          'gas': 3,
#          'side': 3,
#          'widely': 3,
#          'believed': 3,
#          'trench': 3,
#          'defense': 3,
#          'stage': 3,
#          'democratic': 3,
#          'map': 3,
#          'formed': 3,
#          'act': 3,
#          'worldwide': 3,
#          'combined': 3,
#          'imperial': 3,
#          'wave': 3,
#          'majority': 3,
#          'democracy': 3,
#          'solution': 3,
#          'industry': 3,
#          'there': 3,
#          'leadership': 3,
#          'steady': 3,
#          'ideology': 3,
#          'little': 3,
#          'provide': 3,
#          'service': 3,
#          'gave': 3,
#          'appeared': 3,
#          'adolf': 3,
#          'experiment': 3,
#          'party': 3,
#          'speaking': 3,
#          'widespread': 3,
#          'conference': 3,
#          'civil': 3,
#          'attempted': 3,
#          'worst': 3,
#          'help': 3,
#          'secret': 3,
#          'polish': 3,
#          'strategy': 3,
#          'wehrmacht': 3,
#          'panzer': 3,
#          'lithuania': 3,
#          'remain': 3,
#          'hoped': 3,
#          'met': 3,
#          'cause': 3,
#          'land': 3,
#          'norway': 3,
#          'crucial': 3,
#          'low': 3,
#          'marshal': 3,
#          'hermann': 3,
#          'g': 3,
#          'ring': 3,
#          'allowing': 3,
#          'men': 3,
#          'beach': 3,
#          'normandy': 3,
#          'occupy': 3,
#          'around': 3,
#          'greece': 3,
#          'ordered': 3,
#          'named': 3,
#          'successful': 3,
#          'radar': 3,
#          'civilian': 3,
#          'decision': 3,
#          'modern': 3,
#          'ever': 3,
#          'seen': 3,
#          'order': 3,
#          'b': 3,
#          'present': 3,
#          'advanced': 3,
#          'mile': 3,
#          'libya': 3,
#          'thousand': 3,
#          'capturing': 3,
#          'stalingrad': 3,
#          'assured': 3,
#          'supply': 3,
#          'reality': 3,
#          'october': 3,
#          'fight': 3,
#          'lost': 3,
#          'struggling': 3,
#          'winston': 3,
#          'southern': 3,
#          'hand': 3,
#          'though': 3,
#          'described': 3,
#          'd': 3,
#          'landing': 3,
#          'carried': 3,
#          'late': 3,
#          'real': 3,
#          'bloodiest': 3,
#          'yalta': 3,
#          'agreed': 3,
#          'four': 3,
#          'sphere': 3,
#          'mainly': 3,
#          'committed': 3,
#          'rivalry': 3,
#          'iron': 3,
#          'curtain': 3,
#          'usually': 3,
#          'manchuria': 3,
#          'region': 3,
#          'manchukuo': 3,
#          'left': 3,
#          'march': 3,
#          'placed': 3,
#          'reached': 3,
#          'mean': 3,
#          'official': 3,
#          'douglas': 3,
#          'macarthur': 3,
#          'aerial': 3,
#          'australian': 3,
#          'foreign': 3,
#          'midway': 3,
#          'planning': 3,
#          'mainland': 3,
#          'fighting': 3,
#          'gulf': 3,
#          'organized': 3,
#          'meant': 3,
#          'historian': 3,
#          'okinawa': 3,
#          'estimated': 3,
#          'threatened': 3,
#          'destruction': 3,
#          'dropped': 3,
#          'armed': 3,
#          'devised': 3,
#          'work': 3,
#          'case': 3,
#          'scientist': 3,
#          'close': 3,
#          'detonated': 3,
#          'produced': 3,
#          'brought': 3,
#          'tense': 3,
#          'proliferation': 3,
#          'trial': 3,
#          'violent': 3,
#          'cuba': 3,
#          'korean': 3,
#          'along': 3,
#          'vietnamese': 3,
#          'nixon': 3,
#          'moon': 3,
#          'apollo': 3,
#          'memory': 3,
#          'commercial': 3,
#          'convenient': 3,
#          'warming': 3,
#          'emission': 3,
#          'virus': 3,
#          'wikipedia': 2,
#          'menu': 2,
#          'changesupload': 2,
#          'search': 2,
#          'appearance': 2,
#          'donate': 2,
#          'account': 2,
#          'log': 2,
#          'toggle': 2,
#          'barbarossa': 2,
#          'background': 2,
#          'proxy': 2,
#          'table': 2,
#          'language': 2,
#          'readeditview': 2,
#          'sparked': 2,
#          'rocket': 2,
#          'significant': 2,
#          'role': 2,
#          'genocide': 2,
#          'congo': 2,
#          'sarajevo': 2,
#          'franz': 2,
#          'ferdinand': 2,
#          'termed': 2,
#          'november': 2,
#          'austro': 2,
#          'hungarian': 2,
#          'throne': 2,
#          'young': 2,
#          'liberation': 2,
#          'movement': 2,
#          'escalation': 2,
#          'comprised': 2,
#          'bolshevik': 2,
#          'negotiated': 2,
#          'huge': 2,
#          'ukraine': 2,
#          'signing': 2,
#          'entrance': 2,
#          'chance': 2,
#          'strength': 2,
#          'technological': 2,
#          'introduced': 2,
#          'both': 2,
#          'best': 2,
#          'slow': 2,
#          'result': 2,
#          'twenty': 2,
#          'forcing': 2,
#          'damage': 2,
#          'accept': 2,
#          'imposed': 2,
#          'victor': 2,
#          'theory': 2,
#          'prevented': 2,
#          'homeland': 2,
#          'nationalist': 2,
#          'an': 2,
#          'body': 2,
#          'dispute': 2,
#          'prevent': 2,
#          'thing': 2,
#          'pandemic': 2,
#          'broke': 2,
#          'globally': 2,
#          'estimate': 2,
#          'deadliest': 2,
#          'reason': 2,
#          'existing': 2,
#          'overthrow': 2,
#          'believe': 2,
#          'defeated': 2,
#          'died': 2,
#          'de': 2,
#          'longer': 2,
#          'concentrated': 2,
#          'purge': 2,
#          'enemy': 2,
#          'news': 2,
#          'photo': 2,
#          'provided': 2,
#          'activity': 2,
#          'crash': 2,
#          'generally': 2,
#          'response': 2,
#          'situation': 2,
#          'job': 2,
#          'away': 2,
#          'correct': 2,
#          'alleviate': 2,
#          'suffering': 2,
#          'thus': 2,
#          'rather': 2,
#          'continuing': 2,
#          'assumed': 2,
#          'birth': 2,
#          'welfare': 2,
#          'belief': 2,
#          'defend': 2,
#          'benito': 2,
#          'challenge': 2,
#          'annexation': 2,
#          'labor': 2,
#          'interest': 2,
#          'racial': 2,
#          'antisemitism': 2,
#          'extermination': 2,
#          'blame': 2,
#          'causing': 2,
#          'avoid': 2,
#          'assurance': 2,
#          'protect': 2,
#          'czech': 2,
#          'annexed': 2,
#          'collapsed': 2,
#          'francisco': 2,
#          'franco': 2,
#          'achieve': 2,
#          'total': 2,
#          'subject': 2,
#          'individual': 2,
#          'perpetrated': 2,
#          'section': 2,
#          'molotov': 2,
#          'ribbentrop': 2,
#          'officially': 2,
#          'unleashed': 2,
#          'surprise': 2,
#          'immediately': 2,
#          'acting': 2,
#          'alliance': 2,
#          'exile': 2,
#          'starting': 2,
#          'type': 2,
#          'mobile': 2,
#          'smashed': 2,
#          'fought': 2,
#          'estonia': 2,
#          'latvia': 2,
#          'finland': 2,
#          'puppet': 2,
#          'staunch': 2,
#          'finnish': 2,
#          'resistance': 2,
#          'finn': 2,
#          'denmark': 2,
#          'supplied': 2,
#          'hour': 2,
#          'successfully': 2,
#          'maintain': 2,
#          'neutrality': 2,
#          'belgium': 2,
#          'netherlands': 2,
#          'incredible': 2,
#          'belgian': 2,
#          'paratrooper': 2,
#          'without': 2,
#          'p': 2,
#          'tain': 2,
#          'blunder': 2,
#          'dunkirk': 2,
#          'trapped': 2,
#          'craft': 2,
#          'risk': 2,
#          'minister': 2,
#          'escaped': 2,
#          'invade': 2,
#          'continue': 2,
#          'moment': 2,
#          'eye': 2,
#          'alone': 2,
#          'lion': 2,
#          'come': 2,
#          'plane': 2,
#          'raf': 2,
#          'point': 2,
#          'command': 2,
#          'sound': 2,
#          'switch': 2,
#          'focus': 2,
#          'allowed': 2,
#          'importance': 2,
#          'squadron': 2,
#          'incoming': 2,
#          'target': 2,
#          'friendly': 2,
#          'spring': 2,
#          'disastrous': 2,
#          'utter': 2,
#          'albania': 2,
#          'prompted': 2,
#          'revenge': 2,
#          'over': 2,
#          'largely': 2,
#          'c': 2,
#          'laid': 2,
#          'decided': 2,
#          'drove': 2,
#          'egypt': 2,
#          'verge': 2,
#          'rate': 2,
#          'repeatedly': 2,
#          'preventing': 2,
#          'middle': 2,
#          'iran': 2,
#          'oil': 2,
#          'rich': 2,
#          'break': 2,
#          'insisted': 2,
#          'blow': 2,
#          'meanwhile': 2,
#          'tripartite': 2,
#          'n': 2,
#          'able': 2,
#          'attention': 2,
#          'el': 2,
#          'alamein': 2,
#          'gain': 2,
#          'decisive': 2,
#          'serious': 2,
#          'replace': 2,
#          'hold': 2,
#          'policy': 2,
#          'man': 2,
#          'acted': 2,
#          'support': 2,
#          'formally': 2,
#          'america': 2,
#          'submarine': 2,
#          'destroyer': 2,
#          'effective': 2,
#          'weather': 2,
#          'thought': 2,
#          'expecting': 2,
#          'calais': 2,
#          'site': 2,
#          'arresting': 2,
#          'goebbels': 2,
#          'wake': 2,
#          'fast': 2,
#          'effect': 2,
#          'terrifying': 2,
#          'allow': 2,
#          'effectively': 2,
#          'all': 2,
#          'failed': 2,
#          'failure': 2,
#          'nevertheless': 2,
#          'february': 2,
#          'roosevelt': 2,
#          'divide': 2,
#          'split': 2,
#          'dominate': 2,
#          'supreme': 2,
#          'report': 2,
#          'unconditionally': 2,
#          'begun': 2,
#          'foundation': 2,
#          'mukden': 2,
#          'withdrawing': 2,
#          'emperor': 2,
#          'out': 2,
#          'hostility': 2,
#          'sino': 2,
#          'capital': 2,
#          'somewhat': 2,
#          'stalemate': 2,
#          'us': 2,
#          'fleet': 2,
#          'speech': 2,
#          'guam': 2,
#          'month': 2,
#          'burma': 2,
#          'solomon': 2,
#          'far': 2,
#          'australia': 2,
#          'proved': 2,
#          'navy': 2,
#          'bay': 2,
#          'trying': 2,
#          'tinian': 2,
#          'ability': 2,
#          'leyte': 2,
#          'stated': 2,
#          'goal': 2,
#          'fuel': 2,
#          'notable': 2,
#          'iwo': 2,
#          'jima': 2,
#          'marine': 2,
#          'downfall': 2,
#          'least': 2,
#          'enola': 2,
#          'gay': 2,
#          'mission': 2,
#          'truman': 2,
#          'fire': 2,
#          'potsdam': 2,
#          'bombardment': 2,
#          'hiroshima': 2,
#          'nagasaki': 2,
#          'cabinet': 2,
#          'formal': 2,
#          'whether': 2,
#          'night': 2,
#          'feeling': 2,
#          'suddenly': 2,
#          'ghetto': 2,
#          'nuremberg': 2,
#          'controversy': 2,
#          'knew': 2,
#          'occurred': 2,
#          'entirely': 2,
#          'claim': 2,
#          'discredited': 2,
#          'reaction': 2,
#          'feared': 2,
#          'kingdom': 2,
#          'team': 2,
#          'trinity': 2,
#          'possibility': 2,
#          'extinction': 2,
#          'overnight': 2,
#          'while': 2,
#          'assistance': 2,
#          'dubbed': 2,
#          'thermonuclear': 2,
#          'full': 2,
#          'increased': 2,
#          'superpower': 2,
#          'developing': 2,
#          'concern': 2,
#          'rising': 2,
#          'regional': 2,
#          'arm': 2,
#          'increasing': 2,
#          'pakistan': 2,
#          'israel': 2,
#          'attempt': 2,
#          'rebuilt': 2,
#          'dominant': 2,
#          'rose': 2,
#          'numerous': 2,
#          'crime': 2,
#          'le': 2,
#          'nearly': 2,
#          'enough': 2,
#          'process': 2,
#          'struggle': 2,
#          'indian': 2,
#          'separate': 2,
#          'partition': 2,
#          'bangladesh': 2,
#          'cambodia': 2,
#          'african': 2,
#          'others': 2,
#          'territorial': 2,
#          'some': 2,
#          'bloc': 2,
#          'mutual': 2,
#          'five': 2,
#          'famous': 2,
#          'lie': 2,
#          'ancient': 2,
#          'warsaw': 2,
#          'romania': 2,
#          'authority': 2,
#          'considering': 2,
#          'rival': 2,
#          'limit': 2,
#          'cuban': 2,
#          'peninsula': 2,
#          'parallel': 2,
#          'canada': 2,
#          'pushed': 2,
#          'perhaps': 2,
#          'aid': 2,
#          'supposed': 2,
#          'doctrine': 2,
#          'richard': 2,
#          'flight': 2,
#          'launcher': 2,
#          'f': 2,
#          'removed': 2,
#          'culminated': 2,
#          'video': 2,
#          'transfer': 2,
#          'surface': 2,
#          'planet': 2,
#          'wall': 2,
#          'fell': 2,
#          'gorbachev': 2,
#          'hard': 2,
#          'computing': 2,
#          'hardware': 2,
#          'transistor': 2,
#          'device': 2,
#          'fixed': 2,
#          'purpose': 2,
#          'programming': 2,
#          'operating': 2,
#          'improved': 2,
#          'productivity': 2,
#          'user': 2,
#          'simple': 2,
#          'paper': 2,
#          'tape': 2,
#          'disk': 2,
#          'office': 2,
#          'old': 2,
#          'advantage': 2,
#          'open': 2,
#          'architecture': 2,
#          'proprietary': 2,
#          'bios': 2,
#          'physical': 2,
#          'issue': 2,
#          ...})

# %%
countries = pd.read_csv("List of Countries_2.0.csv", index_col = 0)

# %%
countries.head()
# Out:
#        Country
# 0  Afghanistan
# 1      Albania
# 2      Algeria
# 3      Andorra
# 4       Angola

# %%
# lowercase country names
countries_list = [c.lower() for c in countries['Country'].to_list()]

# %%
dict_of_counts = {d : all_counts[d] for d in countries_list}

# %%
dict_of_counts
# Out:
# {'afghanistan': 0,
#  'albania': 2,
#  'algeria': 1,
#  'andorra': 0,
#  'angola': 1,
#  'antigua and barbuda': 0,
#  'argentina': 0,
#  'armenia': 0,
#  'australia': 2,
#  'austria': 4,
#  'azerbaijan': 0,
#  'bahamas': 0,
#  'bahrain': 0,
#  'bangladesh': 2,
#  'barbados': 0,
#  'belarus': 1,
#  'belgium': 2,
#  'belize': 0,
#  'benin': 0,
#  'bhutan': 0,
#  'bolivia': 0,
#  'bosnia and herzegovina': 0,
#  'botswana': 0,
#  'brazil': 0,
#  'brunei': 0,
#  'bulgaria': 1,
#  'burkina faso': 0,
#  'burundi': 0,
#  'cabo verde': 0,
#  'cambodia': 2,
#  'cameroon': 0,
#  'canada': 2,
#  'central african republic': 0,
#  'chad': 0,
#  'chile': 0,
#  'china': 9,
#  'colombia': 0,
#  'comoros': 0,
#  'costa rica': 0,
#  "côte d'ivoire": 0,
#  'croatia': 0,
#  'cuba': 3,
#  'cyprus': 0,
#  'czechia': 0,
#  'democratic republic of the congo': 0,
#  'denmark': 2,
#  'djibouti': 0,
#  'dominica': 0,
#  'dominican republic': 0,
#  'ecuador': 0,
#  'egypt': 2,
#  'el salvador': 0,
#  'equatorial guinea': 0,
#  'eritrea': 0,
#  'estonia': 2,
#  'eswatini': 0,
#  'ethiopia': 0,
#  'fiji': 0,
#  'finland': 2,
#  'france': 14,
#  'gabon': 0,
#  'gambia': 0,
#  'georgia': 0,
#  'germany': 32,
#  'ghana': 1,
#  'greece': 3,
#  'grenada': 0,
#  'guatemala': 0,
#  'guinea': 4,
#  'guinea-bissau': 0,
#  'guyana': 0,
#  'haiti': 0,
#  'honduras': 0,
#  'hungary': 3,
#  'iceland': 0,
#  'india': 6,
#  'indonesia': 0,
#  'iran': 2,
#  'iraq': 1,
#  'ireland': 0,
#  'israel': 2,
#  'italy': 8,
#  'jamaica': 0,
#  'japan': 26,
#  'jordan': 0,
#  'kazakhstan': 0,
#  'kenya': 1,
#  'kiribati': 0,
#  'kuwait': 0,
#  'kyrgyzstan': 0,
#  'laos': 0,
#  'latvia': 2,
#  'lebanon': 0,
#  'lesotho': 0,
#  'liberia': 0,
#  'libya': 3,
#  'liechtenstein': 0,
#  'lithuania': 3,
#  'luxembourg': 1,
#  'madagascar': 0,
#  'malawi': 0,
#  'malaysia': 0,
#  'maldives': 0,
#  'mali': 0,
#  'malta': 0,
#  'marshall islands': 0,
#  'mauritania': 0,
#  'mauritius': 0,
#  'mexico': 1,
#  'micronesia': 0,
#  'moldova': 0,
#  'monaco': 0,
#  'mongolia': 1,
#  'montenegro': 0,
#  'morocco': 1,
#  'mozambique': 1,
#  'myanmar': 0,
#  'namibia': 0,
#  'nauru': 0,
#  'nepal': 0,
#  'netherlands': 2,
#  'new zealand': 0,
#  'nicaragua': 0,
#  'niger': 0,
#  'nigeria': 0,
#  'north macedonia': 0,
#  'north korea': 0,
#  'norway': 3,
#  'oman': 0,
#  'pakistan': 2,
#  'palau': 0,
#  'palestine': 0,
#  'panama': 1,
#  'papua new guinea': 0,
#  'paraguay': 0,
#  'peru': 0,
#  'philippines': 0,
#  'poland': 12,
#  'portugal': 0,
#  'qatar': 0,
#  'republic of the congo': 0,
#  'romania': 2,
#  'russia': 7,
#  'rwanda': 1,
#  'saint kitts and nevis': 0,
#  'saint lucia': 0,
#  'saint vincent and the grenadines': 0,
#  'samoa': 0,
#  'san marino': 0,
#  'são tomé and príncipe': 0,
#  'saudi arabia': 0,
#  'senegal': 0,
#  'serbia': 0,
#  'seychelles': 1,
#  'sierra leone': 0,
#  'singapore': 1,
#  'slovakia': 0,
#  'slovenia': 0,
#  'solomon islands': 0,
#  'somalia': 0,
#  'south africa': 0,
#  'south korea': 0,
#  'south sudan': 0,
#  'spain': 1,
#  'sri lanka': 0,
#  'sudan': 0,
#  'suriname': 0,
#  'sweden': 1,
#  'switzerland': 0,
#  'syria': 0,
#  'tajikistan': 0,
#  'tanzania': 0,
#  'thailand': 1,
#  'timor leste': 0,
#  'togo': 0,
#  'tonga': 0,
#  'trinidad and tobago': 0,
#  'tunisia': 0,
#  'türkiye': 0,
#  'turkmenistan': 0,
#  'tuvalu': 0,
#  'uganda': 0,
#  'ukraine': 2,
#  'united arab emirates': 0,
#  'united kingdom': 0,
#  'united states': 0,
#  'uruguay': 0,
#  'uzbekistan': 0,
#  'vanuatu': 0,
#  'vatican city': 0,
#  'venezuela': 0,
#  'vietnam': 8,
#  'yemen': 0,
#  'zambia': 0,
#  'zimbabwe': 0}

# %%
# Search for the countries from the list in the dictionary

dct = {v:[k] for v,k in dict_of_counts.items()}  
df = pd.DataFrame(dct)

# %%
df
# Out:
#    afghanistan  albania  algeria  andorra  angola  antigua and barbuda  \
# 0            0        2        1        0       1                    0
#
#    argentina  armenia  australia  austria  ...  united states  uruguay  \
# 0          0        0          2        4  ...              0        0
#
#    uzbekistan  vanuatu  vatican city  venezuela  vietnam  yemen  zambia  \
# 0           0        0             0          0        8      0       0
#
#    zimbabwe
# 0         0
#
# [1 rows x 195 columns]

# %%
df = df.transpose().reset_index()

# %%
df.dtypes
# Out:
# index    object
# 0         int64
# dtype: object

# %%
df.head()
# Out:
#          index  0
# 0  afghanistan  0
# 1      albania  2
# 2      algeria  1
# 3      andorra  0
# 4       angola  1

# %%
df.rename(columns = {"index":"Country", 0:"Times mentioned"}, inplace = True)

# %%
df.head()
# Out:
#        Country  Times mentioned
# 0  afghanistan                0
# 1      albania                2
# 2      algeria                1
# 3      andorra                0
# 4       angola                1

# %%
df.shape
# Out:
# (195, 2)

# %%
df = df.groupby("Country")["Times mentioned"].sum().reset_index()

# %%
df_top10 = df.sort_values("Times mentioned", ascending=False).head(10)

# %%
df_top10.head(10)
# Out:
#      Country  Times mentioned
# 63   germany               32
# 83     japan               26
# 59    france               14
# 137   poland               12
# 35     china                9
# 81     italy                8
# 191  vietnam                8
# 142   russia                7
# 75     india                6
# 9    austria                4

# %%
# Plot
plt.figure(figsize=(10, 5))
ax = sns.barplot(
    x="Times mentioned",
    y="Country",
    data=df_top10
)

# Add title
ax.set_title("Most frequently mentioned countries")
plt.show()

# %%
# The frequency distribution of country mentions highlights the key players in twentieth-century global history. 
# Germany stands out with the highest number of mentions, followed by Japan, France, Poland, and China — 
# all nations that were central to major conflicts and geopolitical events such as the two World Wars and their aftermath.

# The appearance of Vietnam and Russia points to the importance of later Cold War–era conflicts and ideological divisions, 
# while India and Austria reflect the broader global reach of historical developments, 
# from decolonization to shifting European alliances.

# Overall, the plot clearly shows that the narrative of the twentieth century is dominated by countries involved in wars, 
# reconstruction, and ideological rivalry, with Europe and Asia emerging as the main centers of historical activity.

# %%
df_top10.to_csv("top10_mentioned_countries.csv")

# %%
df.to_csv("mentioned_countries.csv")

# %% [markdown]
# ## Sentiment Analysis

# %%
text_sent = TextBlob(str(filtered))

# %%
print(text_sent.sentiment)
# Out:
# Sentiment(polarity=0.0317773988764555, subjectivity=0.33937400387872074)

# %%
# Polarity = 0.041 → this is very close to 0, meaning the text is basically neutral (slightly leaning positive, but tiny).

# Subjectivity = 0.34 indicates a moderately objective text. It’s not purely factual (like a data table), 
# but it doesn’t express strong personal opinions either — typical for historical or encyclopedic writing.
