# %% [markdown]
# # Text mining LOTR

# %%
from textblob import TextBlob 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import nltk
import re
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from collections import Counter
sns.set()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/woodoooo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/woodoooo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/woodoooo/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ## Tokenization

# %%
myfile = open('Key events of the 20th century.txt', encoding='utf-8')

# %%
# Import txt file

with open('Key events of the 20th century.txt', 'r', errors='ignore') as file:
    data = file.read().replace('\n', ' ').replace('\t', ' ')

# %%
# Sentence tokenization 

from nltk.tokenize import sent_tokenize
tokenized_sent = sent_tokenize(data)
print(tokenized_sent)
# Out:
# ['    Key events of the 20th century - Wikipedia                            Jump to content        Main menu      Main menu move to sidebar hide      Navigation     Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us        Contribute     HelpLearn to editCommunity portalRecent changesUpload fileSpecial pages                    Search            Search                       Appearance                 Donate  Create account  Log in         Personal tools      Donate Create account Log in        Pages for logged out editors learn more    ContributionsTalk                             Contents move to sidebar hide     (Top)      1 Historic events in the 20th century     Toggle Historic events in the 20th century subsection      1.1 World at the beginning of the century       1.1.1 "The war to end all wars": World War I (1914–1918)           1.2 Spanish flu       1.2.1 Russian Revolution and communism           1.3 Between the wars       1.3.1 Economic depression         1.3.2 The rise of dictatorship           1.4 Global war: World War II (1939–1945)       1.4.1 The war in Europe         1.4.2 Blitzkrieg         1.4.3 Operation Barbarossa         1.4.4 Turning tides         1.4.5 Operation Overlord         1.4.6 Final days         1.4.7 The war in the Pacific       1.4.7.1 Background           1.4.8 Japanese Expansion         1.4.9 Allied offensive         1.4.10 Final days         1.4.11 The Holocaust         1.4.12 The Nuclear Age begins           1.5 The post-war world       1.5.1 The end of empires: decolonization         1.5.2 The Cold War (1947–1991)         1.5.3 War by proxy         1.5.4 The space race         1.5.5 The end of the Cold War         1.5.6 Information and communications technology           1.6 The world at the end of the century           2 See also         3 References         4 Sources         5 External links                   Toggle the table of contents        Key events of the 20th century    2 languages     العربيةУкраїнська  Edit links            ArticleTalk      English                  ReadEditView history        Tools      Tools move to sidebar hide      Actions     ReadEditView history        General     What links hereRelated changesUpload filePermanent linkPage informationCite this pageGet shortened URLDownload QR code        Print/export     Download as PDFPrintable version        In other projects     Wikimedia CommonsWikidata item                      Appearance move to sidebar hide           From Wikipedia, the free encyclopedia    The 20th century changed the world in unprecedented ways.', 'The World Wars sparked tension between countries and led to the creation of atomic bombs, the Cold War led to the Space Race and the creation of space-based rockets, and the World Wide Web was created.', "These advancements have played a significant role in citizens' lives and shaped the 21st century into what it is today.", 'Historic events in the 20th century[edit] World at the beginning of the century[edit] Main article: Edwardian era The new beginning of the 20th century marked significant changes.', 'The 1900s saw the decade herald a series of inventions, including the automobile, airplane and radio broadcasting.', '1914 saw the completion of the Panama Canal.', 'The Scramble for Africa continued in the 1900s and resulted in wars and genocide across the continent.', 'The atrocities in the Congo Free State shocked the civilized world.', 'From 1914 to 1918, the First World War, and its aftermath, caused major changes in the power balance of the world, destroying or transforming some of the most powerful empires.', '"The war to end all wars": World War I (1914–1918)[edit] Main article: World War I Arrest of a suspect in Sarajevo following the Assassination of Archduke Franz Ferdinand The First World War (or simply WWI), termed "The Great War" by contemporaries, started in July 1914 and ended in November 1918.', "The war was precipitated by the Assassination in Sarajevo of the Austr ...

# %%
# Word tokenization

from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(data)
print(tokenized_word)
# Out:
# ['Key', 'events', 'of', 'the', '20th', 'century', '-', 'Wikipedia', 'Jump', 'to', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'to', 'sidebar', 'hide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'us', 'Contribute', 'HelpLearn', 'to', 'editCommunity', 'portalRecent', 'changesUpload', 'fileSpecial', 'pages', 'Search', 'Search', 'Appearance', 'Donate', 'Create', 'account', 'Log', 'in', 'Personal', 'tools', 'Donate', 'Create', 'account', 'Log', 'in', 'Pages', 'for', 'logged', 'out', 'editors', 'learn', 'more', 'ContributionsTalk', 'Contents', 'move', 'to', 'sidebar', 'hide', '(', 'Top', ')', '1', 'Historic', 'events', 'in', 'the', '20th', 'century', 'Toggle', 'Historic', 'events', 'in', 'the', '20th', 'century', 'subsection', '1.1', 'World', 'at', 'the', 'beginning', 'of', 'the', 'century', '1.1.1', '``', 'The', 'war', 'to', 'end', 'all', 'wars', "''", ':', 'World', 'War', 'I', '(', '1914–1918', ')', '1.2', 'Spanish', 'flu', '1.2.1', 'Russian', 'Revolution', 'and', 'communism', '1.3', 'Between', 'the', 'wars', '1.3.1', 'Economic', 'depression', '1.3.2', 'The', 'rise', 'of', 'dictatorship', '1.4', 'Global', 'war', ':', 'World', 'War', 'II', '(', '1939–1945', ')', '1.4.1', 'The', 'war', 'in', 'Europe', '1.4.2', 'Blitzkrieg', '1.4.3', 'Operation', 'Barbarossa', '1.4.4', 'Turning', 'tides', '1.4.5', 'Operation', 'Overlord', '1.4.6', 'Final', 'days', '1.4.7', 'The', 'war', 'in', 'the', 'Pacific', '1.4.7.1', 'Background', '1.4.8', 'Japanese', 'Expansion', '1.4.9', 'Allied', 'offensive', '1.4.10', 'Final', 'days', '1.4.11', 'The', 'Holocaust', '1.4.12', 'The', 'Nuclear', 'Age', 'begins', '1.5', 'The', 'post-war', 'world', '1.5.1', 'The', 'end', 'of', 'empires', ':', 'decolonization', '1.5.2', 'The', 'Cold', 'War', '(', '1947–1991', ')', '1.5.3', 'War', 'by', 'proxy', '1.5.4', 'The', 'space', 'race', '1.5.5', 'The', 'end', 'of', 'the', 'Cold', 'War', '1.5.6', 'Information', 'and', 'communications', 'technology', '1.6', 'The', 'world', 'at', 'the', 'end', 'of', 'the', 'century', '2', 'See', 'also', '3', 'References', '4', 'Sources', '5', 'External', 'links', 'Toggle', 'the', 'table', 'of', 'contents', 'Key', 'events', 'of', 'the', '20th', 'century', '2', 'languages', 'العربيةУкраїнська', 'Edit', 'links', 'ArticleTalk', 'English', 'ReadEditView', 'history', 'Tools', 'Tools', 'move', 'to', 'sidebar', 'hide', 'Actions', 'ReadEditView', 'history', 'General', 'What', 'links', 'hereRelated', 'changesUpload', 'filePermanent', 'linkPage', 'informationCite', 'this', 'pageGet', 'shortened', 'URLDownload', 'QR', 'code', 'Print/export', 'Download', 'as', 'PDFPrintable', 'version', 'In', 'other', 'projects', 'Wikimedia', 'CommonsWikidata', 'item', 'Appearance', 'move', 'to', 'sidebar', 'hide', 'From', 'Wikipedia', ',', 'the', 'free', 'encyclopedia', 'The', '20th', 'century', 'changed', 'the', 'world', 'in', 'unprecedented', 'ways', '.', 'The', 'World', 'Wars', 'sparked', 'tension', 'between', 'countries', 'and', 'led', 'to', 'the', 'creation', 'of', 'atomic', 'bombs', ',', 'the', 'Cold', 'War', 'led', 'to', 'the', 'Space', 'Race', 'and', 'the', 'creation', 'of', 'space-based', 'rockets', ',', 'and', 'the', 'World', 'Wide', 'Web', 'was', 'created', '.', 'These', 'advancements', 'have', 'played', 'a', 'significant', 'role', 'in', 'citizens', "'", 'lives', 'and', 'shaped', 'the', '21st', 'century', 'into', 'what', 'it', 'is', 'today', '.', 'Historic', 'events', 'in', 'the', '20th', 'century', '[', 'edit', ']', 'World', 'at', 'the', 'beginning', 'of', 'the', 'century', '[', 'edit', ']', 'Main', 'article', ':', 'Edwardian', 'era', 'The', 'new', 'beginning', 'of', 'the', '20th', 'century', 'marked', 'significant', 'changes', '.', 'The', '1900s', 'saw', 'the', 'decade', 'herald', 'a', 'series', 'of', 'inventions', ',', 'including', 'the', 'automobile', ',', 'airplane', 'and', 'radio', 'broadcasting', '.', '1914', 'saw', 'the', 'completion', 'of', 'the', 'Panama', 'Canal', '.', 'The', 'Scramble', 'for ...

# %%
# Create frequency distribution

from nltk.probability import FreqDist
dist_words = FreqDist(tokenized_word)
print(dist_words)
# Out:
# <FreqDist with 4909 samples and 22297 outcomes>

# %%
dist_words.most_common(10)
# Out:
# [('.', 1627),
#  ('the', 1134),
#  (',', 980),
#  ('of', 625),
#  ('and', 410),
#  ('to', 333),
#  ('The', 330),
#  ('[', 309),
#  (']', 309),
#  ('in', 304)]

# %%
# Frequency Distribution Plot

plt.figure(figsize=(8, 3))
dist_words.plot(10,cumulative = False)
plt.show()

# %% [markdown]
# ## Stopwords

# %%
# Defining stopwords

from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# {'on', 'him', 'during', 'here', 'couldn', 'each', "weren't", "he's", 'myself', 'there', 'needn', 'm', 'once', 'won', 'me', 'such', 'does', 'wouldn', 'been', 'below', 'doesn', 'did', 'of', 'mightn', 'them', 've', 'both', 'didn', 'i', 'be', 'off', 'same', 'themselves', 'yourselves', 'down', 'they', 't', 'd', 'those', 'should', 'was', 'had', 'that', "we'll", 'this', 'up', "that'll", 'is', 'after', 'no', 'some', "she's", 'own', 'has', 're', 'shan', 'yourself', 'an', "she'll", 'at', 'hers', 'again', "should've", 'don', 'then', "wouldn't", 'other', 'am', 'having', 'so', 'because', 'do', "don't", 'too', 'yours', 'herself', 'as', 'are', "i'm", 'if', 'in', 'while', 'only', 'their', 'shouldn', 'through', 'his', 'my', 'nor', "she'd", 'have', 'few', 'ain', 'not', 'further', 'above', 'a', 'from', "they've", "they're", 'were', 'to', "you're", 'wasn', 'where', 'most', 'but', 'what', 'when', 'very', 'he', 'its', "we'd", "we're", 'before', "mightn't", 'by', "he'd", 'all', 'mustn', 'o', 'why', 'with', "you'll", 'her', 'ourselves', 'theirs', 'itself', "they'd", 'isn', 'who', 'y', 'being', 'until', "won't", 'against', "aren't", 'haven', "couldn't", 'the', 'will', "didn't", "shouldn't", "hasn't", 'now', 'can', "needn't", 'your', 'over', "you'd", 'and', 'just', 'than', "hadn't", 'between', "doesn't", 'ma', 'these', 'it', 'our', "haven't", 'for', 'doing', 'more', 'or', "i'll", 'into', 'about', "wasn't", "he'll", 'hasn', "they'll", 'aren', 'himself', 'you', 'she', 'out', "isn't", "it's", 'll', 'which', "it'll", 's', "you've", "mustn't", 'under', "shan't", 'hadn', 'whom', "we've", 'how', 'weren', 'ours', "i'd", "i've", 'any', 'we', "it'd"}

# %%
# Removing stopwords in words

filtered_words = [] # creates an empty list
for word in tokenized_word:
    if word not in stop_words:
        filtered_words.append(word)

# %%
filtered_words
# Out:
# ['Key',
#  'events',
#  '20th',
#  'century',
#  '-',
#  'Wikipedia',
#  'Jump',
#  'content',
#  'Main',
#  'menu',
#  'Main',
#  'menu',
#  'move',
#  'sidebar',
#  'hide',
#  'Navigation',
#  'Main',
#  'pageContentsCurrent',
#  'eventsRandom',
#  'articleAbout',
#  'WikipediaContact',
#  'us',
#  'Contribute',
#  'HelpLearn',
#  'editCommunity',
#  'portalRecent',
#  'changesUpload',
#  'fileSpecial',
#  'pages',
#  'Search',
#  'Search',
#  'Appearance',
#  'Donate',
#  'Create',
#  'account',
#  'Log',
#  'Personal',
#  'tools',
#  'Donate',
#  'Create',
#  'account',
#  'Log',
#  'Pages',
#  'logged',
#  'editors',
#  'learn',
#  'ContributionsTalk',
#  'Contents',
#  'move',
#  'sidebar',
#  'hide',
#  '(',
#  'Top',
#  ')',
#  '1',
#  'Historic',
#  'events',
#  '20th',
#  'century',
#  'Toggle',
#  'Historic',
#  'events',
#  '20th',
#  'century',
#  'subsection',
#  '1.1',
#  'World',
#  'beginning',
#  'century',
#  '1.1.1',
#  '``',
#  'The',
#  'war',
#  'end',
#  'wars',
#  "''",
#  ':',
#  'World',
#  'War',
#  'I',
#  '(',
#  '1914–1918',
#  ')',
#  '1.2',
#  'Spanish',
#  'flu',
#  '1.2.1',
#  'Russian',
#  'Revolution',
#  'communism',
#  '1.3',
#  'Between',
#  'wars',
#  '1.3.1',
#  'Economic',
#  'depression',
#  '1.3.2',
#  'The',
#  'rise',
#  'dictatorship',
#  '1.4',
#  'Global',
#  'war',
#  ':',
#  'World',
#  'War',
#  'II',
#  '(',
#  '1939–1945',
#  ')',
#  '1.4.1',
#  'The',
#  'war',
#  'Europe',
#  '1.4.2',
#  'Blitzkrieg',
#  '1.4.3',
#  'Operation',
#  'Barbarossa',
#  '1.4.4',
#  'Turning',
#  'tides',
#  '1.4.5',
#  'Operation',
#  'Overlord',
#  '1.4.6',
#  'Final',
#  'days',
#  '1.4.7',
#  'The',
#  'war',
#  'Pacific',
#  '1.4.7.1',
#  'Background',
#  '1.4.8',
#  'Japanese',
#  'Expansion',
#  '1.4.9',
#  'Allied',
#  'offensive',
#  '1.4.10',
#  'Final',
#  'days',
#  '1.4.11',
#  'The',
#  'Holocaust',
#  '1.4.12',
#  'The',
#  'Nuclear',
#  'Age',
#  'begins',
#  '1.5',
#  'The',
#  'post-war',
#  'world',
#  '1.5.1',
#  'The',
#  'end',
#  'empires',
#  ':',
#  'decolonization',
#  '1.5.2',
#  'The',
#  'Cold',
#  'War',
#  '(',
#  '1947–1991',
#  ')',
#  '1.5.3',
#  'War',
#  'proxy',
#  '1.5.4',
#  'The',
#  'space',
#  'race',
#  '1.5.5',
#  'The',
#  'end',
#  'Cold',
#  'War',
#  '1.5.6',
#  'Information',
#  'communications',
#  'technology',
#  '1.6',
#  'The',
#  'world',
#  'end',
#  'century',
#  '2',
#  'See',
#  'also',
#  '3',
#  'References',
#  '4',
#  'Sources',
#  '5',
#  'External',
#  'links',
#  'Toggle',
#  'table',
#  'contents',
#  'Key',
#  'events',
#  '20th',
#  'century',
#  '2',
#  'languages',
#  'العربيةУкраїнська',
#  'Edit',
#  'links',
#  'ArticleTalk',
#  'English',
#  'ReadEditView',
#  'history',
#  'Tools',
#  'Tools',
#  'move',
#  'sidebar',
#  'hide',
#  'Actions',
#  'ReadEditView',
#  'history',
#  'General',
#  'What',
#  'links',
#  'hereRelated',
#  'changesUpload',
#  'filePermanent',
#  'linkPage',
#  'informationCite',
#  'pageGet',
#  'shortened',
#  'URLDownload',
#  'QR',
#  'code',
#  'Print/export',
#  'Download',
#  'PDFPrintable',
#  'version',
#  'In',
#  'projects',
#  'Wikimedia',
#  'CommonsWikidata',
#  'item',
#  'Appearance',
#  'move',
#  'sidebar',
#  'hide',
#  'From',
#  'Wikipedia',
#  ',',
#  'free',
#  'encyclopedia',
#  'The',
#  '20th',
#  'century',
#  'changed',
#  'world',
#  'unprecedented',
#  'ways',
#  '.',
#  'The',
#  'World',
#  'Wars',
#  'sparked',
#  'tension',
#  'countries',
#  'led',
#  'creation',
#  'atomic',
#  'bombs',
#  ',',
#  'Cold',
#  'War',
#  'led',
#  'Space',
#  'Race',
#  'creation',
#  'space-based',
#  'rockets',
#  ',',
#  'World',
#  'Wide',
#  'Web',
#  'created',
#  '.',
#  'These',
#  'advancements',
#  'played',
#  'significant',
#  'role',
#  'citizens',
#  "'",
#  'lives',
#  'shaped',
#  '21st',
#  'century',
#  'today',
#  '.',
#  'Historic',
#  'events',
#  '20th',
#  'century',
#  '[',
#  'edit',
#  ']',
#  'World',
#  'beginning',
#  'century',
#  '[',
#  'edit',
#  ']',
#  'Main',
#  'article',
#  ':',
#  'Edwardian',
#  'era',
#  'The',
#  'new',
#  'beginning',
#  '20th',
#  'century',
#  'marked',
#  'significant',
#  'changes',
#  '.',
#  'The',
#  '1900s',
#  'saw',
#  'decade',
#  'herald',
#  'series',
#  'inventions',
#  ',',
#  'including',
#  'automobile',
#  ',',
#  'airplane',
#  'radio',
#  'broadcasting',
#  '.',
#  '1914',
#  'saw',
#  'completion',
#  'Panama',
#  'Canal',
#  '.',
#  'The',
#  'Scramble',
#  'Africa',
#  'continued',
#  '1900s',
#  'resulted',
#  'wars',
#  'genocide',
#  'across',
#  'continent',
#  '.',
#  'The',
#  'atrocities',
#  'Congo',
#  'Free',
#  'State',
#  'shocked',
#  'civilized',
#  'world',
#  '.',
#  'From',
#  '1914',
#  '1918',
#  ',',
#  'First',
#  'World',
#  'War',
#  ',',
#  'aftermath',
#  ',',
#  'caused',
#  'major',
#  'changes',
#  'power',
#  'balance',
#  'world',
#  ',',
#  'destroying',
#  'transforming',
#  'powerful',
#  'empires',
#  '.',
#  '``',
#  'The',
#  'war',
#  'end',
#  'wars',
#  "''",
#  ':',
#  'World',
#  'War',
#  'I',
#  '(',
#  '1914–1918',
#  ')',
#  '[',
#  'edit',
#  ']',
#  'Main',
#  'article',
#  ':',
#  'World',
#  'War',
#  'I',
#  'Arrest',
#  'suspect',
#  'Sarajevo',
#  'following',
#  'Assassination',
#  'Archduke',
#  'Franz',
#  'Ferdinand',
#  'The',
#  'First',
#  'World',
#  'War',
#  '(',
#  'simply',
#  'WWI',
#  ')',
#  ',',
#  'termed',
#  '``',
#  'The',
#  'Great',
#  'War',
#  "''",
#  'contemporaries',
#  ',',
#  'started',
#  'July',
#  '1914',
#  'ended',
#  'November',
#  '1918',
#  '.',
#  'The',
#  'war',
#  'precipitated',
#  'Assassination',
#  'Sarajevo',
#  'Austro-Hungarian',
#  'Empire',
#  "'s",
#  'heir',
#  'throne',
#  ',',
#  'Erzherzog',
#  'Franz',
#  'Ferdinand',
#  ',',
#  'Gavrilo',
#  'Princip',
#  ',',
#  'member',
#  'Young',
#  'Bosnia',
#  'liberation',
#  'movement',
#  '.',
#  'After',
#  'period',
#  'diplomatic',
#  'military',
#  'escalation',
#  'known',
#  'July',
#  'Crisis',
#  ',',
#  'end',
#  'July',
#  '1914',
#  'two',
#  'coalitions',
#  'war',
#  ':',
#  'Allies',
#  ',',
#  'comprised',
#  'initially',
#  'British',
#  'Empire',
#  ',',
#  'France',
#  ',',
#  'Russian',
#  'Empire',
#  ';',
#  'Central',
#  'Powers',
#  ',',
#  'comprised',
#  'initially',
#  'German',
#  'Empire',
#  'Austria-Hungary',
#  '.',
#  '[',
#  '1',
#  ']',
#  '[',
#  '2',
#  ']',
#  'In',
#  '1917',
#  ',',
#  'Russia',
#  'ended',
#  'hostile',
#  'actions',
#  'Central',
#  'Powers',
#  'fall',
#  'Tsar',
#  '.',
#  'The',
#  'Bolsheviks',
#  'negotiated',
#  'Treaty',
#  'Brest-Litovsk',
#  'Germany',
#  ',',
#  'although',
#  'huge',
#  'cost',
#  'Russia',
#  '.',
#  'In',
#  'treaty',
#  ',',
#  'Bolshevik',
#  'Russia',
#  'ceded',
#  'Baltic',
#  'states',
#  'Germany',
#  ',',
#  'province',
#  'Kars',
#  'Oblast',
#  'South',
#  'Caucasus',
#  'Ottoman',
#  'Empire',
#  '.',
#  'It',
#  'also',
#  'recognized',
#  'independence',
#  'Ukraine',
#  '.',
#  '[',
#  '3',
#  ']',
#  'Although',
#  'Germany',
#  'shifted',
#  'huge',
#  'forces',
#  'eastern',
#  'western',
#  'front',
#  'signing',
#  'treaty',
#  ',',
#  'unable',
#  'stop',
#  'Allied',
#  'advance',
#  ',',
#  'especially',
#  'entrance',
#  'American',
#  'troops',
#  '1918',
#  '.',
#  '[',
#  '4',
#  ']',
#  'The',
#  'war',
#  'also',
#  'chance',
#  'combatant',
#  'nations',
#  'show',
#  'military',
#  'strength',
#  'technological',
#  'ingenuity',
#  '.',
#  'The',
#  'Germans',
#  'introduced',
#  'machine',
#  'gun',
#  ',',
#  '[',
#  '5',
#  ']',
#  'U-boats',
#  '[',
#  '6',
#  ']',
#  'deadly',
#  'gases',
#  '.',
#  '[',
#  '7',
#  ']',
#  'The',
#  'British',
#  'first',
#  'used',
#  'tank',
#  '.',
#  '[',
#  '8',
#  ']',
#  'Both',
#  'sides',
#  'chance',
#  'test',
#  'new',
#  'aircraft',
#  'see',
#  'could',
#  'used',
#  'warfare',
#  '.',
#  'It',
#  'widely',
#  'believed',
#  'war',
#  'would',
#  'short',
#  '.',
#  'Unfortunately',
#  ',',
#  'since',
#  'trench',
#  'warfare',
#  'best',
#  'form',
#  'defense',
#  ',',
#  'advances',
#  'sides',
#  'slow',
#  'came',
#  'terrible',
#  'cost',
#  'lives',
#  '.',
#  '[',
#  '9',
#  ']',
#  'Division',
#  'Austria-Hungary',
#  'World',
#  'War',
#  'I',
#  'When',
#  'war',
#  'finally',
#  '1918',
#  ',',
#  'results',
#  'would',
#  'set',
#  'stage',
#  'next',
#  'twenty',
#  'years',
#  '.',
#  'First',
#  'foremost',
#  ',',
#  'Germans',
#  'forced',
#  'sign',
#  'Treaty',
#  'Versailles',
#  ',',
#  'forcing',
#  'make',
#  'exorbitant',
#  'payments',
#  'repair',
#  'damages',
#  'caused',
#  'War',
#  '.',
#  'Many',
#  'Germans',
#  'felt',
#  'reparations',
#  'unfair',
#  'actually',
#  '``',
#  'lose',
#  "''",
#  'war',
#  'feel',
#  'caused',
#  'war',
#  '(',
#  'see',
#  'Stab-in-the-back',
#  'legend',
#  ')',
#  '.',
#  '[',
#  '10',
#  ']',
#  'Germany',
#  'never',
#  'occupied',
#  'Allied',
#  'troops',
#  ',',
#  'yet',
#  'accept',
#  'liberal',
#  'democratic',
#  'government',
#  'imposed',
#  'victors',
#  'abdication',
#  'Kaiser',
#  'Wilhelm',
#  '.',
#  '[',
#  '11',
#  ']',
#  'Much',
#  'map',
#  'Europe',
#  'redrawn',
#  'victors',
#  'based',
#  'upon',
#  'theory',
#  'future',
#  'wars',
#  'could',
#  'prevented',
#  'ethnic',
#  'groups',
#  '``',
#  'homeland',
#  "''",
#  '.',
#  'New',
#  'states',
#  'like',
#  'Yugoslavia',
#  'Czechoslovakia',
#  'created',
#  'former',
#  'Austro-Hungarian',
#  'Empire',
#  'accommodate',
#  'nationalist',
#  'aspirations',
#  'groups',
#  '.',
#  '[',
#  '12',
#  ']',
#  'An',
#  'international',
#  'body',
#  'called',
#  'League',
#  'Nations',
#  'formed',
#  'mediate',
#  'disputes',
#  'prevent',
#  'future',
#  'wars',
#  ',',
#  'although',
#  'effectiveness',
#  'severely',
#  'limited',
#  ',',
#  'among',
#  'things',
#  ',',
#  'reluctance',
#  'inability',
#  'act',
#  '.',
#  '[',
#  '13',
#  ']',
#  'Spanish',
#  'flu',
#  '[',
#  'edit',
#  ']',
#  'From',
#  '1918',
#  '1920',
#  ',',
#  'remarkably',
#  'deadly',
#  'worldwide',
#  'pandemic',
#  'caused',
#  'flu',
#  'broke',
#  'near',
#  'end',
#  'war',
#  'spread',
#  'globally',
#  '.',
#  'Estimates',
#  'range',
#  'anywhere',
#  '17',
#  '100',
#  'million',
#  'deaths',
#  ',',
#  '[',
#  '14',
#  ']',
#  '[',
#  '15',
#  ']',
#  '[',
#  '16',
#  ']',
#  'staples',
#  'deadliest',
#  'pandemic',
#  'human',
#  'history',
#  '.',
#  'One',
#  'reasons',
#  'exceptionally',
#  'high',
#  'carnage',
#  'wartime',
#  'censorship',
#  'underway',
#  'preserve',
#  'morale',
#  'trenches',
#  ',',
#  'leading',
#  'poor',
#  'hygiene',
#  '.',
#  'Combined',
#  'already',
#  'existing',
#  'malnourishment',
#  'overcrowded',
#  'medical',
#  'facilities',
#  ',',
#  'mix',
#  'made',
#  'deadly',
#  '.',
#  '[',
#  '17',
#  ']',
#  '[',
#  '18',
#  ']',
#  'Russian',
#  'Revolution',
#  'communism',
#  '[',
#  'edit',
#  ']',
#  'Main',
#  'article',
#  ':',
#  'Russian',
#  'Revolution',
#  'The',
#  'Russian',
#  'Revolution',
#  '1917',
#  '(',
#  'ending',
#  'overthrow',
#  'Tsarist',
#  'regime',
#  'execution',
#  'His',
#  'Imperial',
#  'Majesty',
#  'Nicholas',
#  'II',
#  'family',
#  ')',
#  'sparked',
#  'wave',
#  'communist',
#  'revolutions',
#  'across',
#  'Europe',
#  ',',
#  'prompting',
#  'many',
#  'believe',
#  'socialist',
#  'world',
#  'revolution',
#  'could',
#  'realized',
#  'near',
#  'future',
#  '.',
#  '[',
#  '19',
#  ']',
#  'However',
#  ',',
#  'European',
#  'revolutions',
#  'defeated',
#  ',',
#  'Vladimir',
#  'Lenin',
#  'died',
#  '1924',
#  ',',
#  'within',
#  'years',
#  ',',
#  'Joseph',
#  'Stalin',
#  'displaced',
#  'Leon',
#  'Trotsky',
#  'de',
#  'facto',
#  'leader',
#  'Soviet',
#  'Union',
#  '.',
#  'The',
#  'idea',
#  'worldwide',
#  'revolution',
#  'longer',
#  'forefront',
#  ',',
#  'Stalin',
#  'concentrated',
#  '``',
#  'socialism',
#  'one',
#  'country',
#  "''",
#  '[',
#  '20',
#  ']',
#  'embarked',
#  'bold',
#  'plan',
#  'collectivization',
#  'industrialization',
#  '.',
#  '[',
#  '21',
#  ']',
#  'The',
#  'majority',
#  'socialists',
#  'even',
#  'many',
#  'communists',
#  'became',
#  'disillusioned',
#  'Stalin',
#  "'s",
#  'autocratic',
#  'rule',
#  ',',
#  'purges',
#  'assassination',
#  ...]

# %%
# Create a new FreqDist for filtered_words

dist_words_filter = FreqDist(filtered_words)
print(dist_words_filter)
# Out:
# <FreqDist with 4805 samples and 17508 outcomes>

# %%
# Frequency Distribution Plot

plt.figure(figsize=(8, 3))
dist_words_filter.plot(10, cumulative = False)
plt.show()

# %%
dist_words_filter
# Out:
# FreqDist({'.': 1627, ',': 980, 'The': 330, '[': 309, ']': 309, "''": 277, '^': 274, '``': 273, '(': 259, ')': 259, ...})

# %%
# Substitute all punctuations marks with a space 

sans_punc = re.sub("[^a-zA-Z]",  # Search for all non-letters
                          " ",          # Replace all non-letters with spaces
                          str(filtered_words))

# %%
sans_punc
# Out:
# '  Key    events      th    century         Wikipedia    Jump    content    Main    menu    Main    menu    move    sidebar    hide    Navigation    Main    pageContentsCurrent    eventsRandom    articleAbout    WikipediaContact    us    Contribute    HelpLearn    editCommunity    portalRecent    changesUpload    fileSpecial    pages    Search    Search    Appearance    Donate    Create    account    Log    Personal    tools    Donate    Create    account    Log    Pages    logged    editors    learn    ContributionsTalk    Contents    move    sidebar    hide         Top              Historic    events      th    century    Toggle    Historic    events      th    century    subsection           World    beginning    century                   The    war    end    wars               World    War    I                                  Spanish    flu             Russian    Revolution    communism           Between    wars             Economic    depression             The    rise    dictatorship           Global    war         World    War    II                                    The    war    Europe             Blitzkrieg             Operation    Barbarossa             Turning    tides             Operation    Overlord             Final    days             The    war    Pacific               Background             Japanese    Expansion             Allied    offensive              Final    days              The    Holocaust              The    Nuclear    Age    begins           The    post war    world             The    end    empires         decolonization             The    Cold    War                                    War    proxy             The    space    race             The    end    Cold    War             Information    communications    technology           The    world    end    century         See    also         References         Sources         External    links    Toggle    table    contents    Key    events      th    century         languages                         Edit    links    ArticleTalk    English    ReadEditView    history    Tools    Tools    move    sidebar    hide    Actions    ReadEditView    history    General    What    links    hereRelated    changesUpload    filePermanent    linkPage    informationCite    pageGet    shortened    URLDownload    QR    code    Print export    Download    PDFPrintable    version    In    projects    Wikimedia    CommonsWikidata    item    Appearance    move    sidebar    hide    From    Wikipedia         free    encyclopedia    The      th    century    changed    world    unprecedented    ways         The    World    Wars    sparked    tension    countries    led    creation    atomic    bombs         Cold    War    led    Space    Race    creation    space based    rockets         World    Wide    Web    created         These    advancements    played    significant    role    citizens         lives    shaped      st    century    today         Historic    events      th    century         edit         World    beginning    century         edit         Main    article         Edwardian    era    The    new    beginning      th    century    marked    significant    changes         The        s    saw    decade    herald    series    inventions         including    automobile         airplane    radio    broadcasting                 saw    completion    Panama    Canal         The    Scramble    Africa    continued        s    resulted    wars    genocide    across    continent         The    atrocities    Congo    Free    State    shocked    civilized    world         From                         First    World    War         aftermath         caused    major    changes    power    balance    world         destroying    transforming    powerful    empires               The    war    end    wars               World    War    I                                edit         Main    article         World    War    I    Arrest    suspect    Sarajevo    following    Assa ...

# %%
# Word tokenization

tokenized_word_2 = word_tokenize(sans_punc)
print(tokenized_word_2)
# Out:
# ['Key', 'events', 'th', 'century', 'Wikipedia', 'Jump', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'sidebar', 'hide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'us', 'Contribute', 'HelpLearn', 'editCommunity', 'portalRecent', 'changesUpload', 'fileSpecial', 'pages', 'Search', 'Search', 'Appearance', 'Donate', 'Create', 'account', 'Log', 'Personal', 'tools', 'Donate', 'Create', 'account', 'Log', 'Pages', 'logged', 'editors', 'learn', 'ContributionsTalk', 'Contents', 'move', 'sidebar', 'hide', 'Top', 'Historic', 'events', 'th', 'century', 'Toggle', 'Historic', 'events', 'th', 'century', 'subsection', 'World', 'beginning', 'century', 'The', 'war', 'end', 'wars', 'World', 'War', 'I', 'Spanish', 'flu', 'Russian', 'Revolution', 'communism', 'Between', 'wars', 'Economic', 'depression', 'The', 'rise', 'dictatorship', 'Global', 'war', 'World', 'War', 'II', 'The', 'war', 'Europe', 'Blitzkrieg', 'Operation', 'Barbarossa', 'Turning', 'tides', 'Operation', 'Overlord', 'Final', 'days', 'The', 'war', 'Pacific', 'Background', 'Japanese', 'Expansion', 'Allied', 'offensive', 'Final', 'days', 'The', 'Holocaust', 'The', 'Nuclear', 'Age', 'begins', 'The', 'post', 'war', 'world', 'The', 'end', 'empires', 'decolonization', 'The', 'Cold', 'War', 'War', 'proxy', 'The', 'space', 'race', 'The', 'end', 'Cold', 'War', 'Information', 'communications', 'technology', 'The', 'world', 'end', 'century', 'See', 'also', 'References', 'Sources', 'External', 'links', 'Toggle', 'table', 'contents', 'Key', 'events', 'th', 'century', 'languages', 'Edit', 'links', 'ArticleTalk', 'English', 'ReadEditView', 'history', 'Tools', 'Tools', 'move', 'sidebar', 'hide', 'Actions', 'ReadEditView', 'history', 'General', 'What', 'links', 'hereRelated', 'changesUpload', 'filePermanent', 'linkPage', 'informationCite', 'pageGet', 'shortened', 'URLDownload', 'QR', 'code', 'Print', 'export', 'Download', 'PDFPrintable', 'version', 'In', 'projects', 'Wikimedia', 'CommonsWikidata', 'item', 'Appearance', 'move', 'sidebar', 'hide', 'From', 'Wikipedia', 'free', 'encyclopedia', 'The', 'th', 'century', 'changed', 'world', 'unprecedented', 'ways', 'The', 'World', 'Wars', 'sparked', 'tension', 'countries', 'led', 'creation', 'atomic', 'bombs', 'Cold', 'War', 'led', 'Space', 'Race', 'creation', 'space', 'based', 'rockets', 'World', 'Wide', 'Web', 'created', 'These', 'advancements', 'played', 'significant', 'role', 'citizens', 'lives', 'shaped', 'st', 'century', 'today', 'Historic', 'events', 'th', 'century', 'edit', 'World', 'beginning', 'century', 'edit', 'Main', 'article', 'Edwardian', 'era', 'The', 'new', 'beginning', 'th', 'century', 'marked', 'significant', 'changes', 'The', 's', 'saw', 'decade', 'herald', 'series', 'inventions', 'including', 'automobile', 'airplane', 'radio', 'broadcasting', 'saw', 'completion', 'Panama', 'Canal', 'The', 'Scramble', 'Africa', 'continued', 's', 'resulted', 'wars', 'genocide', 'across', 'continent', 'The', 'atrocities', 'Congo', 'Free', 'State', 'shocked', 'civilized', 'world', 'From', 'First', 'World', 'War', 'aftermath', 'caused', 'major', 'changes', 'power', 'balance', 'world', 'destroying', 'transforming', 'powerful', 'empires', 'The', 'war', 'end', 'wars', 'World', 'War', 'I', 'edit', 'Main', 'article', 'World', 'War', 'I', 'Arrest', 'suspect', 'Sarajevo', 'following', 'Assassination', 'Archduke', 'Franz', 'Ferdinand', 'The', 'First', 'World', 'War', 'simply', 'WWI', 'termed', 'The', 'Great', 'War', 'contemporaries', 'started', 'July', 'ended', 'November', 'The', 'war', 'precipitated', 'Assassination', 'Sarajevo', 'Austro', 'Hungarian', 'Empire', 's', 'heir', 'throne', 'Erzherzog', 'Franz', 'Ferdinand', 'Gavrilo', 'Princip', 'member', 'Young', 'Bosnia', 'liberation', 'movement', 'After', 'period', 'diplomatic', 'military', 'escalation', 'known', 'July', 'Crisis', 'end', 'July', 'two', 'coalitions', 'war', 'Allies', 'comprised', 'initially', 'British', 'Empire', 'France', 'Russian', 'Empire', ' ...

# %%
# Create a new FreqDist

dist_words_filter_2 = FreqDist(tokenized_word_2)

# %%
# Frequency Distribution Plot

plt.figure(figsize=(8, 3))
dist_words_filter_2.plot(30, cumulative = False)
plt.show()

# %%
dist_words_filter_2.most_common(20)
# Out:
# [('The', 331),
#  ('December', 225),
#  ('Retrieved', 209),
#  ('War', 127),
#  ('s', 103),
#  ('war', 92),
#  ('th', 88),
#  ('World', 78),
#  ('Soviet', 62),
#  ('Hitler', 51),
#  ('century', 42),
#  ('History', 42),
#  ('Germany', 41),
#  ('first', 41),
#  ('ISBN', 40),
#  ('world', 39),
#  ('Japanese', 36),
#  ('In', 35),
#  ('German', 35),
#  ('would', 35)]

# %% [markdown]
# ## POS Tags with TextBlob

# %%
new_stopwords = ["th", "s", 'In', 'would', 'ISBN', 'The']

# %%
filtered = []
for word in tokenized_word_2:
    if word not in new_stopwords:
        filtered.append(word)

# %%
# %%time
text = TextBlob(str(filtered))
# Out:
# CPU times: user 10.6 ms, sys: 1.48 ms, total: 12 ms
# Wall time: 11.4 ms

# %%
text
# Out:
# TextBlob("['Key', 'events', 'century', 'Wikipedia', 'Jump', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'sidebar', 'hide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'us', 'Contribute', 'HelpLearn', 'editCommunity', 'portalRecent', 'changesUpload', 'fileSpecial', 'pages', 'Search', 'Search', 'Appearance', 'Donate', 'Create', 'account', 'Log', 'Personal', 'tools', 'Donate', 'Create', 'account', 'Log', 'Pages', 'logged', 'editors', 'learn', 'ContributionsTalk', 'Contents', 'move', 'sidebar', 'hide', 'Top', 'Historic', 'events', 'century', 'Toggle', 'Historic', 'events', 'century', 'subsection', 'World', 'beginning', 'century', 'war', 'end', 'wars', 'World', 'War', 'I', 'Spanish', 'flu', 'Russian', 'Revolution', 'communism', 'Between', 'wars', 'Economic', 'depression', 'rise', 'dictatorship', 'Global', 'war', 'World', 'War', 'II', 'war', 'Europe', 'Blitzkrieg', 'Operation', 'Barbarossa', 'Turning', 'tides', 'Operation', 'Overlord', 'Final', 'days', 'war', 'Pacific', 'Background', 'Japanese', 'Expansion', 'Allied', 'offensive', 'Final', 'days', 'Holocaust', 'Nuclear', 'Age', 'begins', 'post', 'war', 'world', 'end', 'empires', 'decolonization', 'Cold', 'War', 'War', 'proxy', 'space', 'race', 'end', 'Cold', 'War', 'Information', 'communications', 'technology', 'world', 'end', 'century', 'See', 'also', 'References', 'Sources', 'External', 'links', 'Toggle', 'table', 'contents', 'Key', 'events', 'century', 'languages', 'Edit', 'links', 'ArticleTalk', 'English', 'ReadEditView', 'history', 'Tools', 'Tools', 'move', 'sidebar', 'hide', 'Actions', 'ReadEditView', 'history', 'General', 'What', 'links', 'hereRelated', 'changesUpload', 'filePermanent', 'linkPage', 'informationCite', 'pageGet', 'shortened', 'URLDownload', 'QR', 'code', 'Print', 'export', 'Download', 'PDFPrintable', 'version', 'projects', 'Wikimedia', 'CommonsWikidata', 'item', 'Appearance', 'move', 'sidebar', 'hide', 'From', 'Wikipedia', 'free', 'encyclopedia', 'century', 'changed', 'world', 'unprecedented', 'ways', 'World', 'Wars', 'sparked', 'tension', 'countries', 'led', 'creation', 'atomic', 'bombs', 'Cold', 'War', 'led', 'Space', 'Race', 'creation', 'space', 'based', 'rockets', 'World', 'Wide', 'Web', 'created', 'These', 'advancements', 'played', 'significant', 'role', 'citizens', 'lives', 'shaped', 'st', 'century', 'today', 'Historic', 'events', 'century', 'edit', 'World', 'beginning', 'century', 'edit', 'Main', 'article', 'Edwardian', 'era', 'new', 'beginning', 'century', 'marked', 'significant', 'changes', 'saw', 'decade', 'herald', 'series', 'inventions', 'including', 'automobile', 'airplane', 'radio', 'broadcasting', 'saw', 'completion', 'Panama', 'Canal', 'Scramble', 'Africa', 'continued', 'resulted', 'wars', 'genocide', 'across', 'continent', 'atrocities', 'Congo', 'Free', 'State', 'shocked', 'civilized', 'world', 'From', 'First', 'World', 'War', 'aftermath', 'caused', 'major', 'changes', 'power', 'balance', 'world', 'destroying', 'transforming', 'powerful', 'empires', 'war', 'end', 'wars', 'World', 'War', 'I', 'edit', 'Main', 'article', 'World', 'War', 'I', 'Arrest', 'suspect', 'Sarajevo', 'following', 'Assassination', 'Archduke', 'Franz', 'Ferdinand', 'First', 'World', 'War', 'simply', 'WWI', 'termed', 'Great', 'War', 'contemporaries', 'started', 'July', 'ended', 'November', 'war', 'precipitated', 'Assassination', 'Sarajevo', 'Austro', 'Hungarian', 'Empire', 'heir', 'throne', 'Erzherzog', 'Franz', 'Ferdinand', 'Gavrilo', 'Princip', 'member', 'Young', 'Bosnia', 'liberation', 'movement', 'After', 'period', 'diplomatic', 'military', 'escalation', 'known', 'July', 'Crisis', 'end', 'July', 'two', 'coalitions', 'war', 'Allies', 'comprised', 'initially', 'British', 'Empire', 'France', 'Russian', 'Empire', 'Central', 'Powers', 'comprised', 'initially', 'German', 'Empire', 'Austria', 'Hungary', 'Russia', 'ended', 'hostile', 'actions', 'Central', 'Powers', 'fall', 'Tsar', 'Bolsheviks', 'negotiated', 'Treaty', 'Br ...

# %%
tags_list = text.tags

# %%
tags_list
# Out:
# [('[', 'JJ'),
#  ("'Key", 'NNP'),
#  ("'", 'POS'),
#  ("'events", 'NNS'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'Wikipedia", 'NNP'),
#  ("'", 'POS'),
#  ("'Jump", 'NNP'),
#  ("'", 'POS'),
#  ("'content", 'NNP'),
#  ("'", 'POS'),
#  ("'menu", 'NNP'),
#  ("'", 'POS'),
#  ("'menu", 'NNP'),
#  ("'", 'POS'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'Navigation", 'NN'),
#  ("'pageContentsCurrent", 'NNP'),
#  ("'", 'POS'),
#  ("'eventsRandom", 'NNP'),
#  ("'", 'POS'),
#  ("'articleAbout", 'IN'),
#  ("'WikipediaContact", 'NNP'),
#  ("'", 'POS'),
#  ("'us", 'NNP'),
#  ("'", 'POS'),
#  ("'HelpLearn", 'NNP'),
#  ("'", 'POS'),
#  ("'editCommunity", 'NNP'),
#  ("'", 'POS'),
#  ("'portalRecent", 'NNP'),
#  ("'", 'POS'),
#  ("'fileSpecial", 'NNP'),
#  ("'", 'POS'),
#  ("'pages", 'NNS'),
#  ("'", 'POS'),
#  ("'Search", 'NNP'),
#  ("'", 'POS'),
#  ("'Search", 'NNP'),
#  ("'", 'POS'),
#  ("'Appearance", 'NN'),
#  ("'Donate", 'NNP'),
#  ("'", 'POS'),
#  ("'Create", 'NNP'),
#  ("'", 'POS'),
#  ("'account", 'NNP'),
#  ("'", 'POS'),
#  ("'Log", 'NNP'),
#  ("'", 'POS'),
#  ("'Personal", 'NNP'),
#  ("'", 'POS'),
#  ("'tools", 'NNS'),
#  ("'", 'POS'),
#  ("'Donate", 'NNP'),
#  ("'", 'POS'),
#  ("'Create", 'NNP'),
#  ("'", 'POS'),
#  ("'account", 'NNP'),
#  ("'", 'POS'),
#  ("'Log", 'NNP'),
#  ("'", 'POS'),
#  ("'Pages", 'NNS'),
#  ("'", 'POS'),
#  ("'logged", 'VBD'),
#  ("'editors", 'NNS'),
#  ("'", 'POS'),
#  ("'learn", 'NNP'),
#  ("'", 'POS'),
#  ("'Contents", 'NNS'),
#  ("'", 'POS'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'Historic", 'NNP'),
#  ("'", 'POS'),
#  ("'events", 'NNS'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'Historic", 'NNP'),
#  ("'", 'POS'),
#  ("'events", 'NNS'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'subsection", 'NN'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'beginning", 'VBG'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'flu", 'NNP'),
#  ("'", 'POS'),
#  ("'Russian", 'JJ'),
#  ("'Revolution", 'NNP'),
#  ("'", 'POS'),
#  ("'communism", 'NN'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'Economic", 'NNP'),
#  ("'", 'POS'),
#  ("'depression", 'NN'),
#  ("'rise", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'II", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'Blitzkrieg", 'NNP'),
#  ("'", 'POS'),
#  ("'Operation", 'NN'),
#  ("'Turning", 'VBG'),
#  ("'tides", 'NNS'),
#  ("'", 'POS'),
#  ("'Operation", 'NN'),
#  ("'Overlord", 'NNP'),
#  ("'", 'POS'),
#  ("'Final", 'NNP'),
#  ("'", 'POS'),
#  ("'days", 'NNS'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'Pacific", 'NNP'),
#  ("'", 'POS'),
#  ("'Background", 'IN'),
#  ("'Japanese", 'JJ'),
#  ("'Expansion", 'NNP'),
#  ("'", 'POS'),
#  ("'Allied", 'VBD'),
#  ("'offensive", 'CD'),
#  ("'Final", 'NNP'),
#  ("'", 'POS'),
#  ("'days", 'NNS'),
#  ("'", 'POS'),
#  ("'Holocaust", 'NNP'),
#  ("'", 'POS'),
#  ("'Age", 'NNP'),
#  ("'", 'POS'),
#  ("'begins", 'NNS'),
#  ("'", 'POS'),
#  ("'post", 'FW'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'empires", 'NNS'),
#  ("'", 'POS'),
#  ("'decolonization", 'NN'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'proxy", 'NNP'),
#  ("'", 'POS'),
#  ("'space", 'NNP'),
#  ("'", 'POS'),
#  ("'race", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'Information", 'NN'),
#  ("'communications", 'NNS'),
#  ("'", 'POS'),
#  ("'technology", 'NNP'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'References", 'NNS'),
#  ("'", 'POS'),
#  ("'Sources", 'NNS'),
#  ("'", 'POS'),
#  ("'External", 'NNP'),
#  ("'", 'POS'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'table", 'JJ'),
#  ("'contents", 'NNS'),
#  ("'", 'POS'),
#  ("'Key", 'NNP'),
#  ("'", 'POS'),
#  ("'events", 'NNS'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'languages", 'NNS'),
#  ("'", 'POS'),
#  ("'Edit", 'NNP'),
#  ("'", 'POS'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'ReadEditView", 'NNP'),
#  ("'", 'POS'),
#  ("'history", 'NNP'),
#  ("'", 'POS'),
#  ("'Tools", 'NNS'),
#  ("'", 'POS'),
#  ("'Tools", 'NNS'),
#  ("'", 'POS'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'Actions", 'NNS'),
#  ("'", 'POS'),
#  ("'ReadEditView", 'NNP'),
#  ("'", 'POS'),
#  ("'history", 'NNP'),
#  ("'", 'POS'),
#  ("'General", 'NNP'),
#  ("'", 'POS'),
#  ("'What", 'WP'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'hereRelated", 'VBD'),
#  ("'filePermanent", 'NNP'),
#  ("'", 'POS'),
#  ("'linkPage", 'NN'),
#  ("'informationCite", 'NNP'),
#  ("'", 'POS'),
#  ("'shortened", 'VBD'),
#  ("'QR", 'NNP'),
#  ("'", 'POS'),
#  ("'code", 'NNP'),
#  ("'", 'POS'),
#  ("'Print", 'NNP'),
#  ("'", 'POS'),
#  ("'export", 'NNP'),
#  ("'", 'POS'),
#  ("'PDFPrintable", 'JJ'),
#  ("'version", 'NNP'),
#  ("'", 'POS'),
#  ("'projects", 'NNS'),
#  ("'", 'POS'),
#  ("'Wikimedia", 'NNP'),
#  ("'", 'POS'),
#  ("'CommonsWikidata", 'NNP'),
#  ("'", 'POS'),
#  ("'item", 'NNP'),
#  ("'", 'POS'),
#  ("'Appearance", 'NN'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'From", 'IN'),
#  ("'Wikipedia", 'NNP'),
#  ("'", 'POS'),
#  ("'encyclopedia", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'changed", 'VBD'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'unprecedented", 'VBD'),
#  ("'ways", 'NNS'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'Wars", 'NNS'),
#  ("'", 'POS'),
#  ("'sparked", 'VBD'),
#  ("'tension", 'NNP'),
#  ("'", 'POS'),
#  ("'countries", 'NNS'),
#  ("'", 'POS'),
#  ("'led", 'VBD'),
#  ("'creation", 'NNP'),
#  ("'", 'POS'),
#  ("'atomic", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'led", 'VBD'),
#  ("'Space", 'NNP'),
#  ("'", 'POS'),
#  ("'Race", 'NNP'),
#  ("'", 'POS'),
#  ("'creation", 'NN'),
#  ("'space", 'NNP'),
#  ("'", 'POS'),
#  ("'based", 'VBD'),
#  ("'rockets", 'NNS'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'Wide", 'NNP'),
#  ("'", 'POS'),
#  ("'Web", 'NNP'),
#  ("'", 'POS'),
#  ("'created", 'VBD'),
#  ("'These", 'JJ'),
#  ("'advancements", 'NNS'),
#  ("'", 'POS'),
#  ("'significant", 'NNP'),
#  ("'", 'POS'),
#  ("'role", 'NNP'),
#  ("'", 'POS'),
#  ("'citizens", 'NNS'),
#  ("'", 'POS'),
#  ("'lives", 'NNS'),
#  ("'", 'POS'),
#  ("'shaped", 'VBD'),
#  ("'st", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'Historic", 'NNP'),
#  ("'", 'POS'),
#  ("'events", 'NNS'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'beginning", 'VBG'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'article", 'NNP'),
#  ("'", 'POS'),
#  ("'Edwardian", 'JJ'),
#  ("'new", 'NNP'),
#  ("'", 'POS'),
#  ("'beginning", 'VBG'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'marked", 'VBD'),
#  ("'significant", 'NNP'),
#  ("'", 'POS'),
#  ("'changes", 'NNS'),
#  ("'", 'POS'),
#  ("'saw", 'NNP'),
#  ("'", 'POS'),
#  ("'herald", 'NNP'),
#  ("'", 'POS'),
#  ("'series", 'NNS'),
#  ("'", 'POS'),
#  ("'inventions", 'NNS'),
#  ("'", 'POS'),
#  ("'including", 'VBG'),
#  ("'automobile", 'IN'),
#  ("'airplane", 'NNP'),
#  ("'", 'POS'),
#  ("'radio", 'NNP'),
#  ("'", 'POS'),
#  ("'broadcasting", 'VBG'),
#  ("'saw", 'NNP'),
#  ("'", 'POS'),
#  ("'completion", 'NN'),
#  ("'Panama", 'NNP'),
#  ("'", 'POS'),
#  ("'Canal", 'NNP'),
#  ("'", 'POS'),
#  ("'Scramble", 'JJ'),
#  ("'Africa", 'NNP'),
#  ("'", 'POS'),
#  ("'continued", 'VBN'),
#  ("'resulted", 'VBD'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'genocide", 'NNP'),
#  ("'", 'POS'),
#  ("'across", 'IN'),
#  ("'continent", 'NNP'),
#  ("'", 'POS'),
#  ("'atrocities", 'NNS'),
#  ("'", 'POS'),
#  ("'Congo", 'NNP'),
#  ("'", 'POS'),
#  ("'State", 'NNP'),
#  ("'", 'POS'),
#  ("'shocked", 'VBD'),
#  ("'civilized", 'VBN'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'From", 'IN'),
#  ("'First", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'aftermath", 'NNP'),
#  ("'", 'POS'),
#  ("'caused", 'VBD'),
#  ("'changes", 'NNS'),
#  ("'", 'POS'),
#  ("'power", 'NNP'),
#  ("'", 'POS'),
#  ("'balance", 'NN'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'destroying", 'VBG'),
#  ("'transforming", 'VBG'),
#  ("'empires", 'NNS'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'article", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'Arrest", 'JJS'),
#  ("'suspect", 'NNP'),
#  ("'", 'POS'),
#  ("'Sarajevo", 'NNP'),
#  ("'", 'POS'),
#  ("'following", 'VBG'),
#  ("'Assassination", 'NNP'),
#  ("'", 'POS'),
#  ("'Archduke", 'NNP'),
#  ("'", 'POS'),
#  ("'Franz", 'NNP'),
#  ("'", 'POS'),
#  ("'Ferdinand", 'NNP'),
#  ("'", 'POS'),
#  ("'First", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'simply", 'NNP'),
#  ("'", 'POS'),
#  ("'WWI", 'NNP'),
#  ("'", 'POS'),
#  ("'termed", 'VBD'),
#  ("'Great", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'contemporaries", 'NNS'),
#  ("'", 'POS'),
#  ("'started", 'VBD'),
#  ("'July", 'NNP'),
#  ("'", 'POS'),
#  ("'ended", 'VBD'),
#  ("'November", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'precipitated", 'VBD'),
#  ("'Assassination", 'NNP'),
#  ("'", 'POS'),
#  ("'Sarajevo", 'NNP'),
#  ("'", 'POS'),
#  ("'Austro", 'NNP'),
#  ("'", 'POS'),
#  ("'Hungarian", 'JJ'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'throne", 'CD'),
#  ("'Erzherzog", 'NNP'),
#  ("'", 'POS'),
#  ("'Franz", 'NNP'),
#  ("'", 'POS'),
#  ("'Ferdinand", 'NNP'),
#  ("'", 'POS'),
#  ("'Gavrilo", 'NNP'),
#  ("'", 'POS'),
#  ("'Princip", 'NNP'),
#  ("'", 'POS'),
#  ("'member", 'NNP'),
#  ("'", 'POS'),
#  ("'Young", 'NNP'),
#  ("'", 'POS'),
#  ("'Bosnia", 'NNP'),
#  ("'", 'POS'),
#  ("'liberation", 'NN'),
#  ("'movement", 'NNP'),
#  ("'", 'POS'),
#  ("'After", 'NNP'),
#  ("'", 'POS'),
#  ("'period", 'NNP'),
#  ("'", 'POS'),
#  ("'diplomatic", 'JJ'),
#  ("'military", 'NNP'),
#  ("'", 'POS'),
#  ("'escalation", 'NN'),
#  ("'July", 'NNP'),
#  ("'", 'POS'),
#  ("'Crisis", 'NN'),
#  ("'July", 'NNP'),
#  ("'", 'POS'),
#  ("'two", 'NNP'),
#  ("'", 'POS'),
#  ("'coalitions", 'NNS'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'Allies", 'NNS'),
#  ("'", 'POS'),
#  ("'comprised", 'VBD'),
#  ("'initially", 'RB'),
#  ("'", 'POS'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'France", 'NN'),
#  ("'Russian", 'JJ'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'Central", 'NNP'),
#  ("'", 'POS'),
#  ("'Powers", 'NNS'),
#  ("'", 'POS'),
#  ("'comprised", 'VBD'),
#  ("'initially", 'RB'),
#  ("'", 'POS'),
#  ("'German", 'NNP'),
#  ("'", 'POS'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'Austria", 'NNP'),
#  ("'", 'POS'),
#  ("'Hungary", 'NNP'),
#  ("'", 'POS'),
#  ("'ended", 'VBD'),
#  ("'hostile", 'IN'),
#  ("'actions", 'NNS'),
#  ("'", 'POS'),
#  ("'Central", 'NNP'),
#  ("'", 'POS'),
#  ("'Powers", 'NNS'),
#  ("'", 'POS'),
#  ("'Tsar", 'NNP'),
#  ("'", 'POS'),
#  ("'Bolsheviks", 'NNP'),
#  ("'", 'POS'),
#  ("'negotiated", 'VBD'),
#  ("'Treaty", 'NNP'),
#  ("'", 'POS'),
#  ("'Brest", 'JJS'),
#  ("'Litovsk", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'although", 'IN'),
#  ("'cost", 'FW'),
#  ("'", 'POS'),
#  ("'treaty", 'NNP'),
#  ("'", 'POS'),
#  ("'Bolshevik", 'NNP'),
#  ("'", 'POS'),
#  ("'ceded", 'VBD'),
#  ("'Baltic", 'JJ'),
#  ("'states", 'VBZ'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'province", 'NN'),
#  ("'Kars", 'NNS'),
#  ("'", 'POS'),
#  ("'South", 'NNP'),
#  ("'", 'POS'),
#  ("'Caucasus", 'NNP'),
#  ("'", 'POS'),
#  ("'Ottoman", 'NNP'),
#  ("'", 'POS'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'It", 'NNP'),
#  ("'", 'POS'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'recognized", 'VBN'),
#  ("'independence", 'NNP'),
#  ("'", 'POS'),
#  ("'Ukraine", 'NNP'),
#  ("'", 'POS'),
#  ("'Although", 'IN'),
#  ("'", 'POS'),
#  ("'shifted", 'VBD'),
#  ("'forces", 'NNS'),
#  ("'", 'POS'),
#  ("'eastern", 'NNP'),
#  ("'", 'POS'),
#  ("'western", 'NNP'),
#  ("'", 'POS'),
#  ("'front", 'NNP'),
#  ("'", 'POS'),
#  ("'signing", 'VBG'),
#  ("'treaty", 'NNP'),
#  ("'", 'POS'),
#  ("'unable", 'JJ'),
#  ("'stop", 'NNP'),
#  ("'", 'POS'),
#  ("'Allied", 'VBD'),
#  ("'advance", 'NNP'),
#  ("'", 'POS'),
#  ("'especially", 'RB'),
#  ("'", 'POS'),
#  ("'entrance", 'NN'),
#  ("'American", 'JJ'),
#  ("'troops", 'NNS'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'chance", 'NN'),
#  ("'combatant", 'NNP'),
#  ("'", 'POS'),
#  ("'nations", 'NNS'),
#  ("'", 'POS'),
#  ("'show", 'NNP'),
#  ("'", 'POS'),
#  ("'military", 'NNP'),
#  ("'", 'POS'),
#  ("'strength", 'NNP'),
#  ("'", 'POS'),
#  ("'technological", 'JJ'),
#  ("'ingenuity", 'NNP'),
#  ("'", 'POS'),
#  ("'Germans", 'NNS'),
#  ("'", 'POS'),
#  ("'introduced", 'VBD'),
#  ("'machine", 'NNP'),
#  ("'", 'POS'),
#  ("'gun", 'NNP'),
#  ("'", 'POS'),
#  ('U', 'NNP'),
#  ("'", 'POS'),
#  ("'boats", 'NNS'),
#  ("'", 'POS'),
#  ("'deadly", 'RB'),
#  ("'gases", 'NNS'),
#  ("'", 'POS'),
#  ("'first", 'NNP'),
#  ("'", 'POS'),
#  ("'used", 'VBD'),
#  ("'tank", 'NNP'),
#  ("'", 'POS'),
#  ("'Both", 'NNP'),
#  ("'", 'POS'),
#  ("'sides", 'NNS'),
#  ("'", 'POS'),
#  ("'chance", 'NN'),
#  ("'test", 'JJS'),
#  ("'new", 'NNP'),
#  ("'", 'POS'),
#  ("'aircraft", 'NNP'),
#  ("'", 'POS'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'could", 'MD'),
#  ("'used", 'VBD'),
#  ("'warfare", 'NNP'),
#  ("'", 'POS'),
#  ("'It", 'NNP'),
#  ("'", 'POS'),
#  ("'widely", 'RB'),
#  ("'believed", 'VBD'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'short", 'NNP'),
#  ("'", 'POS'),
#  ("'Unfortunately", 'RB'),
#  ("'since", 'NNP'),
#  ("'", 'POS'),
#  ("'warfare", 'NNP'),
#  ("'", 'POS'),
#  ("'best", 'JJS'),
#  ("'advances", 'NNS'),
#  ("'", 'POS'),
#  ("'sides", 'NNS'),
#  ("'", 'POS'),
#  ("'slow", 'NNP'),
#  ("'", 'POS'),
#  ("'terrible", 'JJ'),
#  ("'cost", 'FW'),
#  ("'", 'POS'),
#  ("'lives", 'NNS'),
#  ("'", 'POS'),
#  ("'Division", 'NN'),
#  ("'Austria", 'NNP'),
#  ("'", 'POS'),
#  ("'Hungary", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'When", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'finally", 'RB'),
#  ("'", 'POS'),
#  ("'results", 'NNS'),
#  ("'", 'POS'),
#  ("'set", 'NNP'),
#  ("'", 'POS'),
#  ("'stage", 'NN'),
#  ("'twenty", 'NNP'),
#  ("'", 'POS'),
#  ("'years", 'NNS'),
#  ("'", 'POS'),
#  ("'First", 'NNP'),
#  ("'", 'POS'),
#  ("'foremost", 'FW'),
#  ("'", 'POS'),
#  ("'Germans", 'NNS'),
#  ("'", 'POS'),
#  ("'forced", 'VBD'),
#  ("'sign", 'NNP'),
#  ("'", 'POS'),
#  ("'Treaty", 'NNP'),
#  ("'", 'POS'),
#  ("'Versailles", 'NNS'),
#  ("'", 'POS'),
#  ("'forcing", 'VBG'),
#  ("'make", 'NNP'),
#  ("'", 'POS'),
#  ("'exorbitant", 'NNP'),
#  ("'", 'POS'),
#  ("'payments", 'NNS'),
#  ("'", 'POS'),
#  ("'repair", 'NNP'),
#  ("'", 'POS'),
#  ("'damages", 'NNS'),
#  ("'", 'POS'),
#  ("'caused", 'VBD'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'Germans", 'NNS'),
#  ("'", 'POS'),
#  ("'felt", 'NNP'),
#  ("'", 'POS'),
#  ("'reparations", 'NNS'),
#  ("'", 'POS'),
#  ("'unfair", 'NNP'),
#  ("'", 'POS'),
#  ("'actually", 'RB'),
#  ("'", 'POS'),
#  ("'lose", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'feel", 'NNP'),
#  ("'", 'POS'),
#  ("'caused", 'VBD'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'in", 'NNP'),
#  ("'", 'POS'),
#  ("'the", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'occupied", 'VBD'),
#  ("'Allied", 'VBD'),
#  ("'troops", 'NNS'),
#  ("'", 'POS'),
#  ("'yet", 'NNP'),
#  ("'", 'POS'),
#  ("'accept", 'IN'),
#  ("'liberal", 'NNP'),
#  ("'", 'POS'),
#  ("'democratic", 'JJ'),
#  ("'government", 'NNP'),
#  ("'", 'POS'),
#  ("'imposed", 'VBD'),
#  ("'victors", 'NNS'),
#  ("'", 'POS'),
#  ("'abdication", 'NN'),
#  ("'Kaiser", 'NNP'),
#  ("'", 'POS'),
#  ("'Wilhelm", 'NNP'),
#  ("'", 'POS'),
#  ("'Much", 'JJ'),
#  ("'map", 'NNP'),
#  ("'", 'POS'),
#  ("'redrawn", 'NNP'),
#  ("'", 'POS'),
#  ("'victors", 'NNS'),
#  ("'", 'POS'),
#  ("'based", 'VBD'),
#  ("'theory", 'NNP'),
#  ("'", 'POS'),
#  ("'future", 'NN'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'could", 'MD'),
#  ("'prevented", 'VBD'),
#  ("'ethnic", 'NNP'),
#  ("'", 'POS'),
#  ("'groups", 'NNS'),
#  ("'", 'POS'),
#  ("'homeland", 'NNP'),
#  ("'", 'POS'),
#  ("'New", 'NNP'),
#  ("'", 'POS'),
#  ("'states", 'NNS'),
#  ("'", 'POS'),
#  ("'like", 'IN'),
#  ("'Yugoslavia", 'NNP'),
#  ("'", 'POS'),
#  ("'Czechoslovakia", 'NNP'),
#  ("'", 'POS'),
#  ("'created", 'VBD'),
#  ("'Austro", 'NNP'),
#  ("'", 'POS'),
#  ("'Hungarian", 'JJ'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'accommodate", 'NNP'),
#  ("'", 'POS'),
#  ("'aspirations", 'NNS'),
#  ("'", 'POS'),
#  ("'groups", 'NNS'),
#  ("'", 'POS'),
#  ("'An", 'NNP'),
#  ("'", 'POS'),
#  ("'international", 'NNP'),
#  ("'", 'POS'),
#  ("'body", 'NN'),
#  ("'called", 'VBD'),
#  ("'League", 'NNP'),
#  ("'", 'POS'),
#  ("'Nations", 'NNS'),
#  ("'", 'POS'),
#  ("'formed", 'VBD'),
#  ("'mediate", 'NNP'),
#  ("'", 'POS'),
#  ("'disputes", 'NNS'),
#  ("'", 'POS'),
#  ("'prevent", 'NNP'),
#  ("'", 'POS'),
#  ("'future", 'NN'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'although", 'IN'),
#  ("'effectiveness", 'NNP'),
#  ("'", 'POS'),
#  ("'severely", 'RB'),
#  ("'limited", 'VBD'),
#  ("'among", 'NNP'),
#  ("'", 'POS'),
#  ("'things", 'NNS'),
#  ("'", 'POS'),
#  ("'reluctance", 'NN'),
#  ("'inability", 'NNP'),
#  ("'", 'POS'),
#  ("'act", 'NNP'),
#  ("'", 'POS'),
#  ("'flu", 'NNP'),
#  ("'", 'POS'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'From", 'IN'),
#  ("'remarkably", 'RB'),
#  ("'deadly", 'RB'),
#  ("'worldwide", 'NNP'),
#  ("'", 'POS'),
#  ("'pandemic", 'NNP'),
#  ("'", 'POS'),
#  ("'caused", 'VBD'),
#  ("'flu", 'NNP'),
#  ("'", 'POS'),
#  ("'broke", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'globally", 'RB'),
#  ("'", 'POS'),
#  ("'Estimates", 'NNS'),
#  ("'", 'POS'),
#  ("'range", 'NNP'),
#  ("'", 'POS'),
#  ("'anywhere", 'EX'),
#  ("'million", 'NNP'),
#  ("'", 'POS'),
#  ("'deaths", 'NNS'),
#  ("'", 'POS'),
#  ("'staples", 'NNS'),
#  ("'", 'POS'),
#  ("'deadliest", 'JJS'),
#  ("'pandemic", 'NNP'),
#  ("'", 'POS'),
#  ("'human", 'NNP'),
#  ("'", 'POS'),
#  ("'history", 'NNP'),
#  ("'", 'POS'),
#  ("'reasons", 'NNS'),
#  ("'", 'POS'),
#  ("'exceptionally", 'RB'),
#  ("'", 'POS'),
#  ("'high", 'NNP'),
#  ("'", 'POS'),
#  ("'carnage", 'NN'),
#  ("'wartime", 'NNP'),
#  ("'", 'POS'),
#  ("'underway", 'NNP'),
#  ("'", 'POS'),
#  ("'preserve", 'NNP'),
#  ("'", 'POS'),
#  ("'morale", 'NNP'),
#  ("'", 'POS'),
#  ("'trenches", 'NNS'),
#  ("'", 'POS'),
#  ("'leading", 'VBG'),
#  ("'poor", 'NNP'),
#  ("'", 'POS'),
#  ("'hygiene", 'NNP'),
#  ("'", 'POS'),
#  ("'Combined", 'VBD'),
#  ("'existing", 'VBG'),
#  ("'malnourishment", 'NNP'),
#  ("'", 'POS'),
#  ("'overcrowded", 'VBD'),
#  ("'medical", 'JJ'),
#  ("'facilities", 'NNS'),
#  ("'", 'POS'),
#  ("'mix", 'NNP'),
#  ("'", 'POS'),
#  ("'deadly", 'RB'),
#  ("'Russian", 'JJ'),
#  ("'Revolution", 'NNP'),
#  ("'", 'POS'),
#  ("'communism", 'NN'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'article", 'NNP'),
#  ("'", 'POS'),
#  ("'Russian", 'JJ'),
#  ("'Revolution", 'NNP'),
#  ("'", 'POS'),
#  ("'Russian", 'JJ'),
#  ("'Revolution", 'NNP'),
#  ("'", 'POS'),
#  ("'ending", 'VBG'),
#  ("'regime", 'NNP'),
#  ("'", 'POS'),
#  ("'execution", 'NN'),
#  ("'His", 'NNP'),
#  ("'", 'POS'),
#  ("'Imperial", 'NNP'),
#  ("'", 'POS'),
#  ("'Majesty", 'NNP'),
#  ("'", 'POS'),
#  ("'Nicholas", 'NNS'),
#  ("'", 'POS'),
#  ("'II", 'NNP'),
#  ("'", 'POS'),
#  ...]

# %%
df_text = pd.DataFrame(tags_list)
df_text.columns = ['Words', "Word type"]

# %%
df_text.head()
# Out:
#      Words Word type
# 0        [        JJ
# 1     'Key       NNP
# 2        '       POS
# 3  'events       NNS
# 4        '       POS

# %%
df_t = df_text.groupby('Word type').count().reset_index()

# %%
df_t.head()
# Out:
#   Word type  Words
# 0        CC      1
# 1        CD     78
# 2        DT     12
# 3        EX     13
# 4        FW     43

# %%
top20 = df_t.nlargest(20, 'Words')

# %%
plt.figure(figsize=(10, 5))
ax = sns.barplot(
    x="Words",
    y="Word type",
    data=top20,
    saturation=0.9
)
ax.set_title("Key events of the 20th century - Top 20 word types used")
plt.show()

# %% [markdown]
# ## Nouns

# %%
df = df_text[(df_text['Word type'] == "NN") | (df_text['Word type'] == "NNS") | (df_text['Word type'] == "NNP")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top10 = y.nlargest(10, 'Occurences')

# %%
top10
# Out:
#            Word  Occurences
# 306   'December         225
# 1310       'War         127
# 2655       'war          92
# 1357     'World          78
# 1150    'Soviet          62
# 562     'Hitler          51
# 1548   'century          42
# 561    'History          42
# 1835     'first          41
# 2682     'world          39

# %%
plt.figure(figsize=(10, 5))
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x="Word", y="Occurences",
    saturation=0.9, data = top10).set_title("Key events of the 20th century - most frequently used nouns")

# %% [markdown]
# ## Verbs

# %%
df = df_text[(df_text['Word type'] == "VB")  | (df_text['Word type'] == "VBD")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top10 = y.nlargest(10, 'Occurences')

# %%
top10
# Out:
#             Word  Occurences
# 27    'Retrieved         209
# 36       'United          31
# 0        'Allied          19
# 196         'led          15
# 1      'Archived          14
# 323        'used          13
# 194    'launched          12
# 92   'controlled           9
# 159      'forced           8
# 76      'changed           7

# %%
# Create the plot
plt.figure(figsize=(10, 5))
sns.barplot(
    x="Word",
    y="Occurences",
    data=top10
)

# Add title
plt.title("Key events of the 20th century - most frequently used verbs")
plt.show()

# %% [markdown]
# ## Adjectives

# %%
df = df_text[df_text['Word type'] == "JJ"]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by=['Occurences'], ascending=False)
top10 = y.nlargest(10, 'Occurences')

# %%
top10
# Out:
#            Word  Occurences
# 27    'Japanese          36
# 2     'American          24
# 5     'Atlantic          13
# 19    'Guardian          10
# 42     'Russian           7
# 13     'Chinese           7
# 1      'African           6
# 106  'political           6
# 107   'possible           5
# 7       'Baltic           5

# %%
# Create the plot
plt.figure(figsize=(10, 5))
sns.barplot(
    x="Word",
    y="Occurences",
    data=top10
)

# Add title
plt.title("Key events of the 20th century - most frequently used adjectives")
plt.show()

# %% [markdown]
# ## Counting country names occurences

# %%
listToStr = ' '.join([str(elem) for elem in filtered])
 
print(listToStr)
# Out:
# Key events century Wikipedia Jump content Main menu Main menu move sidebar hide Navigation Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us Contribute HelpLearn editCommunity portalRecent changesUpload fileSpecial pages Search Search Appearance Donate Create account Log Personal tools Donate Create account Log Pages logged editors learn ContributionsTalk Contents move sidebar hide Top Historic events century Toggle Historic events century subsection World beginning century war end wars World War I Spanish flu Russian Revolution communism Between wars Economic depression rise dictatorship Global war World War II war Europe Blitzkrieg Operation Barbarossa Turning tides Operation Overlord Final days war Pacific Background Japanese Expansion Allied offensive Final days Holocaust Nuclear Age begins post war world end empires decolonization Cold War War proxy space race end Cold War Information communications technology world end century See also References Sources External links Toggle table contents Key events century languages Edit links ArticleTalk English ReadEditView history Tools Tools move sidebar hide Actions ReadEditView history General What links hereRelated changesUpload filePermanent linkPage informationCite pageGet shortened URLDownload QR code Print export Download PDFPrintable version projects Wikimedia CommonsWikidata item Appearance move sidebar hide From Wikipedia free encyclopedia century changed world unprecedented ways World Wars sparked tension countries led creation atomic bombs Cold War led Space Race creation space based rockets World Wide Web created These advancements played significant role citizens lives shaped st century today Historic events century edit World beginning century edit Main article Edwardian era new beginning century marked significant changes saw decade herald series inventions including automobile airplane radio broadcasting saw completion Panama Canal Scramble Africa continued resulted wars genocide across continent atrocities Congo Free State shocked civilized world From First World War aftermath caused major changes power balance world destroying transforming powerful empires war end wars World War I edit Main article World War I Arrest suspect Sarajevo following Assassination Archduke Franz Ferdinand First World War simply WWI termed Great War contemporaries started July ended November war precipitated Assassination Sarajevo Austro Hungarian Empire heir throne Erzherzog Franz Ferdinand Gavrilo Princip member Young Bosnia liberation movement After period diplomatic military escalation known July Crisis end July two coalitions war Allies comprised initially British Empire France Russian Empire Central Powers comprised initially German Empire Austria Hungary Russia ended hostile actions Central Powers fall Tsar Bolsheviks negotiated Treaty Brest Litovsk Germany although huge cost Russia treaty Bolshevik Russia ceded Baltic states Germany province Kars Oblast South Caucasus Ottoman Empire It also recognized independence Ukraine Although Germany shifted huge forces eastern western front signing treaty unable stop Allied advance especially entrance American troops war also chance combatant nations show military strength technological ingenuity Germans introduced machine gun U boats deadly gases British first used tank Both sides chance test new aircraft see could used warfare It widely believed war short Unfortunately since trench warfare best form defense advances sides slow came terrible cost lives Division Austria Hungary World War I When war finally results set stage next twenty years First foremost Germans forced sign Treaty Versailles forcing make exorbitant payments repair damages caused War Many Germans felt reparations unfair actually lose war feel caused war see Stab in the back legend Germany never occupied Allied troops yet accept liberal democratic government imposed victors abdication Kaiser Wilhelm Much map Europe redrawn victors based upon theory fut ...

# %%
# Create a count for the main characters

all_counts = Counter(re.sub(r'\W+', ' ', listToStr).split())

# %%
all_counts
# Out:
# Counter({'December': 225,
#          'Retrieved': 209,
#          'War': 127,
#          'war': 92,
#          'World': 78,
#          'Soviet': 62,
#          'Hitler': 51,
#          'century': 42,
#          'History': 42,
#          'Germany': 41,
#          'first': 41,
#          'world': 39,
#          'Japanese': 36,
#          'German': 35,
#          'edit': 34,
#          'September': 33,
#          'Japan': 33,
#          'II': 32,
#          'Germans': 32,
#          'New': 31,
#          'Union': 31,
#          'United': 31,
#          'S': 30,
#          'ISSN': 30,
#          'also': 29,
#          'became': 29,
#          'Europe': 28,
#          'July': 28,
#          'August': 28,
#          'end': 27,
#          'U': 26,
#          'States': 26,
#          'A': 26,
#          'nuclear': 26,
#          'history': 25,
#          'June': 25,
#          'Battle': 25,
#          'American': 24,
#          'This': 24,
#          'April': 24,
#          'weapons': 24,
#          'October': 24,
#          'com': 24,
#          'new': 23,
#          'Africa': 23,
#          'attack': 23,
#          'Main': 22,
#          'Holocaust': 22,
#          'Stalin': 21,
#          'BBC': 21,
#          'British': 20,
#          'one': 20,
#          'Britain': 20,
#          'May': 20,
#          'North': 20,
#          'Allied': 19,
#          'Allies': 19,
#          'many': 19,
#          'Nazi': 19,
#          'Cold': 18,
#          'two': 18,
#          'forces': 18,
#          'could': 18,
#          'January': 18,
#          'doi': 18,
#          'p': 18,
#          'countries': 17,
#          'France': 17,
#          'However': 17,
#          'Jews': 17,
#          'later': 17,
#          'On': 17,
#          'Space': 16,
#          'South': 16,
#          'Berlin': 16,
#          'February': 16,
#          'computer': 16,
#          'Operation': 15,
#          'Pacific': 15,
#          'From': 15,
#          'led': 15,
#          'November': 15,
#          'people': 15,
#          'invasion': 15,
#          'Internet': 15,
#          'How': 15,
#          'Press': 15,
#          'York': 15,
#          'Nuclear': 14,
#          'article': 14,
#          'Great': 14,
#          'known': 14,
#          'nations': 14,
#          'made': 14,
#          'state': 14,
#          'Italy': 14,
#          'Army': 14,
#          'battle': 14,
#          'National': 14,
#          'Archived': 14,
#          'original': 14,
#          'space': 13,
#          'First': 13,
#          'power': 13,
#          'After': 13,
#          'used': 13,
#          'government': 13,
#          'time': 13,
#          'began': 13,
#          'Poland': 13,
#          'Second': 13,
#          'Atlantic': 13,
#          'March': 13,
#          'Vietnam': 13,
#          'wars': 12,
#          'days': 12,
#          'st': 12,
#          'troops': 12,
#          'came': 12,
#          'Nations': 12,
#          'economic': 12,
#          'early': 12,
#          'East': 12,
#          'launched': 12,
#          'French': 12,
#          'University': 12,
#          'I': 11,
#          'major': 11,
#          'Imperial': 11,
#          'use': 11,
#          'day': 11,
#          'US': 11,
#          'By': 11,
#          'Richard': 11,
#          'HISTORY': 11,
#          'org': 11,
#          'events': 10,
#          'including': 10,
#          'Empire': 10,
#          'military': 10,
#          'It': 10,
#          'Western': 10,
#          'army': 10,
#          'bomb': 10,
#          'several': 10,
#          'V': 10,
#          'West': 10,
#          'China': 10,
#          'island': 10,
#          'camps': 10,
#          'Project': 10,
#          'John': 10,
#          'International': 10,
#          'Why': 10,
#          'gov': 10,
#          'Guardian': 10,
#          'Russia': 9,
#          'Treaty': 9,
#          'states': 9,
#          'independence': 9,
#          'next': 9,
#          'million': 9,
#          'human': 9,
#          'European': 9,
#          'crisis': 9,
#          'Mussolini': 9,
#          'Pact': 9,
#          'air': 9,
#          'launch': 9,
#          'largest': 9,
#          'controlled': 9,
#          'Churchill': 9,
#          'surrender': 9,
#          'India': 9,
#          'Korea': 9,
#          'News': 9,
#          'beginning': 8,
#          'communism': 8,
#          'offensive': 8,
#          'What': 8,
#          'creation': 8,
#          'Free': 8,
#          'aircraft': 8,
#          'see': 8,
#          'years': 8,
#          'forced': 8,
#          'leading': 8,
#          'already': 8,
#          'communist': 8,
#          'Joseph': 8,
#          'force': 8,
#          'Eastern': 8,
#          'attacks': 8,
#          'part': 8,
#          'territory': 8,
#          'With': 8,
#          'Nazis': 8,
#          'Sea': 8,
#          'city': 8,
#          'last': 8,
#          'naval': 8,
#          'second': 8,
#          'influence': 8,
#          'Day': 8,
#          'Korean': 8,
#          'Computer': 8,
#          'Foundation': 8,
#          'Museums': 8,
#          'pp': 8,
#          'Journal': 8,
#          'Was': 8,
#          'Times': 8,
#          'nd': 8,
#          'Russian': 7,
#          'Revolution': 7,
#          'rise': 7,
#          'General': 7,
#          'free': 7,
#          'changed': 7,
#          'Wars': 7,
#          'Central': 7,
#          'advance': 7,
#          'warfare': 7,
#          'form': 7,
#          'set': 7,
#          'groups': 7,
#          'among': 7,
#          'Depression': 7,
#          'system': 7,
#          'general': 7,
#          'large': 7,
#          'took': 7,
#          'He': 7,
#          'USSR': 7,
#          'surrendered': 7,
#          'independent': 7,
#          'almost': 7,
#          'turned': 7,
#          'despite': 7,
#          'B': 7,
#          'Rommel': 7,
#          'powers': 7,
#          'Chinese': 7,
#          'MacArthur': 7,
#          'Robert': 7,
#          'computers': 7,
#          'Michael': 7,
#          'SSR': 7,
#          'PC': 7,
#          'Year': 7,
#          'PMID': 7,
#          'Rise': 7,
#          'Interest': 7,
#          'CID': 7,
#          'Publishing': 7,
#          'And': 7,
#          'rd': 7,
#          'Between': 6,
#          'Economic': 6,
#          'Final': 6,
#          'race': 6,
#          'created': 6,
#          'continued': 6,
#          'State': 6,
#          'caused': 6,
#          'powerful': 6,
#          'ended': 6,
#          'Crisis': 6,
#          'Many': 6,
#          'occupied': 6,
#          'upon': 6,
#          'League': 6,
#          'de': 6,
#          'country': 6,
#          'plan': 6,
#          'even': 6,
#          'rule': 6,
#          'well': 6,
#          'capitalist': 6,
#          'development': 6,
#          'articles': 6,
#          'political': 6,
#          'They': 6,
#          'east': 6,
#          'area': 6,
#          'Conference': 6,
#          'held': 6,
#          'Moscow': 6,
#          'defeat': 6,
#          'important': 6,
#          'massive': 6,
#          'Paris': 6,
#          'Air': 6,
#          'At': 6,
#          'suffered': 6,
#          'turn': 6,
#          'bombing': 6,
#          'weapon': 6,
#          'planned': 6,
#          'campaign': 6,
#          'network': 6,
#          'half': 6,
#          'place': 6,
#          'long': 6,
#          'another': 6,
#          'Asia': 6,
#          'nation': 6,
#          'concentration': 6,
#          'systems': 6,
#          'peace': 6,
#          'decades': 6,
#          'People': 6,
#          'African': 6,
#          'Cuban': 6,
#          'IBM': 6,
#          'software': 6,
#          'networks': 6,
#          'Research': 6,
#          'Atomic': 6,
#          'Century': 6,
#          'Wikipedia': 5,
#          'post': 5,
#          'Information': 5,
#          'technology': 5,
#          'atomic': 5,
#          'lives': 5,
#          'marked': 5,
#          'saw': 5,
#          'period': 5,
#          'Austria': 5,
#          'fall': 5,
#          'Baltic': 5,
#          'boats': 5,
#          'since': 5,
#          'advances': 5,
#          'finally': 5,
#          'back': 5,
#          'like': 5,
#          'Yugoslavia': 5,
#          'Czechoslovakia': 5,
#          'range': 5,
#          'medical': 5,
#          'ending': 5,
#          'within': 5,
#          'idea': 5,
#          'global': 5,
#          'strong': 5,
#          'become': 5,
#          'Fascism': 5,
#          'soldiers': 5,
#          'population': 5,
#          'put': 5,
#          'Civil': 5,
#          'control': 5,
#          'winter': 5,
#          'Norway': 5,
#          'six': 5,
#          'entire': 5,
#          'Three': 5,
#          'refused': 5,
#          'managed': 5,
#          'Italians': 5,
#          'taking': 5,
#          'using': 5,
#          'number': 5,
#          'Despite': 5,
#          'divided': 5,
#          'Group': 5,
#          'Libya': 5,
#          'Axis': 5,
#          'Pearl': 5,
#          'Harbor': 5,
#          'ground': 5,
#          'victories': 5,
#          'followed': 5,
#          'possible': 5,
#          'still': 5,
#          'leaders': 5,
#          'Yalta': 5,
#          'Post': 5,
#          'E': 5,
#          'cities': 5,
#          'Philippines': 5,
#          'Islands': 5,
#          'Tokyo': 5,
#          'killed': 5,
#          'home': 5,
#          'terms': 5,
#          'death': 5,
#          'During': 5,
#          'develop': 5,
#          'efforts': 5,
#          'developed': 5,
#          'Non': 5,
#          'organization': 5,
#          'involved': 5,
#          'formation': 5,
#          'Missile': 5,
#          'Apollo': 5,
#          'Online': 5,
#          'Timeline': 5,
#          'Weapons': 5,
#          'Archives': 5,
#          'Years': 5,
#          'Daniel': 5,
#          'Museum': 5,
#          'David': 5,
#          'Company': 5,
#          'Heritage': 5,
#          'W': 5,
#          'Military': 5,
#          'Science': 5,
#          'Key': 4,
#          'move': 4,
#          'sidebar': 4,
#          'hide': 4,
#          'Search': 4,
#          'Historic': 4,
#          'Spanish': 4,
#          'dictatorship': 4,
#          'Global': 4,
#          'Barbarossa': 4,
#          'Overlord': 4,
#          'links': 4,
#          'based': 4,
#          'Web': 4,
#          'These': 4,
#          'across': 4,
#          'started': 4,
#          'although': 4,
#          'cost': 4,
#          'treaty': 4,
#          'especially': 4,
#          'tank': 4,
#          'short': 4,
#          'When': 4,
#          'sign': 4,
#          'never': 4,
#          'future': 4,
#          'ethnic': 4,
#          'former': 4,
#          'An': 4,
#          'international': 4,
#          'called': 4,
#          'limited': 4,
#          'pandemic': 4,
#          'near': 4,
#          'spread': 4,
#          'high': 4,
#          'poor': 4,
#          'regime': 4,
#          'leader': 4,
#          'news': 4,
#          'economy': 4,
#          'remained': 4,
#          'warning': 4,
#          'often': 4,
#          'market': 4,
#          'ordinary': 4,
#          'intervention': 4,
#          'needed': 4,
#          'soon': 4,
#          'battles': 4,
#          'rest': 4,
#          'threat': 4,
#          'Adolf': 4,
#          'take': 4,
#          'Almost': 4,
#          'worst': 4,
#          'main': 4,
#          'declared': 4,
#          'attacked': 4,
#          'secret': 4,
#          'weeks': 4,
#          'London': 4,
#          'strategy': 4,
#          'change': 4,
#          'Finland': 4,
#          'hoped': 4,
#          'action': 4,
#          'throughout': 4,
#          'considered': 4,
#          'great': 4,
#          'third': 4,
#          'G': 4,
#          'Luftwaffe': 4,
#          'Greece': 4,
#          'losses': 4,
#          'eventually': 4,
#          'turning': 4,
#          'small': 4,
#          'modern': 4,
#          'quickly': 4,
#          'taken': 4,
#          'signed': 4,
#          'non': 4,
#          'coup': 4,
#          'Italian': 4,
#          'Middle': 4,
#          'Iran': 4,
#          'Stalingrad': 4,
#          'way': 4,
#          'captured': 4,
#          'Soviets': 4,
#          'victory': 4,
#          'casualties': 4,
#          'fight': 4,
#          'invaded': 4,
#          'Winston': 4,
#          'Republic': 4,
#          'described': 4,
#          'America': 4,
#          'D': 4,
#          'site': 4,
#          'propaganda': 4,
#          'newly': 4,
#          'went': 4,
#          'devastating': 4,
#          'suicide': 4,
#          'conflict': 4,
#          'Incident': 4,
#          'Manchuria': 4,
#          'Manchukuo': 4,
#          'relations': 4,
#          'occupation': 4,
#          'Sino': 4,
#          'conflicts': 4,
#          'Following': 4,
#          'Guinea': 4,
#          'Douglas': 4,
#          'Australian': 4,
#          'strategic': 4,
#          'Midway': 4,
#          'attacking': 4,
#          'Campaign': 4,
#          'given': 4,
#          'Gulf': 4,
#          'achieved': 4,
#          'Iwo': 4,
#          'Jima': 4,
#          'historians': 4,
#          'Okinawa': 4,
#          'lead': 4,
#          'Hiroshima': 4,
#          'Nagasaki': 4,
#          'Third': 4,
#          'Nuremberg': 4,
#          'Code': 4,
#          'areas': 4,
#          'Manhattan': 4,
#          'program': 4,
#          'success': 4,
#          'Man': 4,
#          'brought': 4,
#          'rapidly': 4,
#          'Pakistan': 4,
#          'Israel': 4,
#          'Behind': 4,
#          'Organization': 4,
#          'backed': 4,
#          'along': 4,
#          'Nixon': 4,
#          'Peace': 4,
#          'Moon': 4,
#          'astronauts': 4,
#          'video': 4,
#          'Station': 4,
#          'Computers': 4,
#          'Mark': 4,
#          'Software': 4,
#          'Bulletin': 4,
#          'Al': 4,
#          'Tim': 4,
#          'K': 4,
#          'Death': 4,
#          'Brian': 4,
#          'Learning': 4,
#          'Encyclopedia': 4,
#          'PMC': 4,
#          'Story': 4,
#          'Invasion': 4,
#          'End': 4,
#          'Fall': 4,
#          'Battles': 4,
#          'About': 4,
#          'Johnson': 4,
#          'Vol': 4,
#          'Society': 4,
#          'Personal': 3,
#          'Toggle': 3,
#          'flu': 3,
#          'Blitzkrieg': 3,
#          'tides': 3,
#          'Age': 3,
#          'empires': 3,
#          'decolonization': 3,
#          'See': 3,
#          'table': 3,
#          'languages': 3,
#          'Wikimedia': 3,
#          'encyclopedia': 3,
#          'bombs': 3,
#          'changes': 3,
#          'member': 3,
#          'initially': 3,
#          'Powers': 3,
#          'Hungary': 3,
#          'Although': 3,
#          'eastern': 3,
#          'unable': 3,
#          'deadly': 3,
#          'sides': 3,
#          'widely': 3,
#          'believed': 3,
#          'stage': 3,
#          'the': 3,
#          'Kaiser': 3,
#          'Much': 3,
#          'map': 3,
#          'formed': 3,
#          'worldwide': 3,
#          'One': 3,
#          'His': 3,
#          'wave': 3,
#          'revolution': 3,
#          'majority': 3,
#          'democracies': 3,
#          'solution': 3,
#          'industry': 3,
#          'There': 3,
#          'leadership': 3,
#          'responses': 3,
#          'steady': 3,
#          'provide': 3,
#          'gave': 3,
#          'Jewish': 3,
#          'says': 3,
#          'appeared': 3,
#          'Benito': 3,
#          'speaking': 3,
#          'extermination': 3,
#          'widespread': 3,
#          'collapsed': 3,
#          'regimes': 3,
#          'attempted': 3,
#          'Theater': 3,
#          'Molotov': 3,
#          'Ribbentrop': 3,
#          'much': 3,
#          'help': 3,
#          'Polish': 3,
#          'Wehrmacht': 3,
#          'As': 3,
#          'republics': 3,
#          'Lithuania': 3,
#          'remain': 3,
#          'possession': 3,
#          'Red': 3,
#          'met': 3,
#          'cause': 3,
#          'ally': 3,
#          'land': 3,
#          'Denmark': 3,
#          'crucial': 3,
#          'neutrality': 3,
#          'Countries': 3,
#          'border': 3,
#          'Marshal': 3,
#          'P': 3,
#          'Dunkirk': 3,
#          'Hermann': 3,
#          'ring': 3,
#          'allowing': 3,
#          'Force': 3,
#          'men': 3,
#          'core': 3,
#          'Normandy': 3,
#          'occupy': 3,
#          'three': 3,
#          'Charles': 3,
#          'create': 3,
#          'continue': 3,
#          'Throughout': 3,
#          'bombers': 3,
#          'ordered': 3,
#          'plans': 3,
#          'named': 3,
#          'RAF': 3,
#          'successful': 3,
#          'radar': 3,
#          'decision': 3,
#          'importance': 3,
#          'ever': 3,
#          'seen': 3,
#          'present': 3,
#          'advanced': 3,
#          'miles': 3,
#          'division': 3,
#          'break': 3,
#          'assured': 3,
#          'supply': 3,
#          'reality': 3,
#          'Eventually': 3,
#          'Americans': 3,
#          'n': 3,
#          't': 3,
#          'prisoners': 3,
#          'El': 3,
#          'Alamein': 3,
#          'policy': 3,
#          'lost': 3,
#          'struggling': 3,
#          'southern': 3,
#          'hands': 3,
#          'really': 3,
#          'though': 3,
#          'assault': 3,
#          'SS': 3,
#          'carried': 3,
#          'late': 3,
#          'real': 3,
#          'failure': 3,
#          'bloodiest': 3,
#          'Roosevelt': 3,
#          'agreed': 3,
#          'Most': 3,
#          'four': 3,
#          'mainly': 3,
#          'committed': 3,
#          'Iron': 3,
#          'Curtain': 3,
#          'event': 3,
#          'usually': 3,
#          'left': 3,
#          'placed': 3,
#          'reached': 3,
#          'Virginia': 3,
#          'base': 3,
#          'expansion': 3,
#          'colonies': 3,
#          'Guam': 3,
#          'aerial': 3,
#          'foreign': 3,
#          'planning': 3,
#          'mainland': 3,
#          'Leyte': 3,
#          'organized': 3,
#          'meant': 3,
#          'islands': 3,
#          'Downfall': 3,
#          'president': 3,
#          'estimated': 3,
#          'Potsdam': 3,
#          'Declaration': 3,
#          'threatened': 3,
#          'destruction': 3,
#          'dropped': 3,
#          'bombings': 3,
#          'Reich': 3,
#          'borders': 3,
#          'armed': 3,
#          'devised': 3,
#          'You': 3,
#          'knew': 3,
#          'may': 3,
#          'team': 3,
#          'close': 3,
#          'detonated': 3,
#          'produced': 3,
#          'Little': 3,
#          'Boy': 3,
#          'Fat': 3,
#          'Joe': 3,
#          'tense': 3,
#          'proliferation': 3,
#          'programs': 3,
#          'economies': 3,
#          'Trial': 3,
#          'Today': 3,
#          'Decolonization': 3,
#          'violent': 3,
#          'Indian': 3,
#          'Tom': 3,
#          'Warsaw': 3,
#          'populations': 3,
#          'Romania': 3,
#          'Cuba': 3,
#          'Two': 3,
#          'Vietnamese': 3,
#          'Offensive': 3,
#          'President': 3,
#          'Saigon': 3,
#          'Communist': 3,
#          'F': 3,
#          'Kennedy': 3,
#          'Sputnik': 3,
#          'Venera': 3,
#          'Wall': 3,
#          'hard': 3,
#          'Boris': 3,
#          'problem': 3,
#          'memory': 3,
#          'office': 3,
#          'Compaq': 3,
#          'Government': 3,
#          'games': 3,
#          'Like': 3,
#          'commercial': 3,
#          'Lee': 3,
#          'warming': 3,
#          'HIV': 3,
#          'AIDS': 3,
#          'Infectious': 3,
#          'ThoughtCo': 3,
#          'That': 3,
#          'Life': 3,
#          'Pandemic': 3,
#          'Books': 3,
#          'R': 3,
#          'Politics': 3,
#          'JSTOR': 3,
#          'Is': 3,
#          'Alan': 3,
#          'Peck': 3,
#          'warfarehistorynetwork': 3,
#          'To': 3,
#          'ed': 3,
#          'Network': 3,
#          'Knew': 3,
#          'Ago': 3,
#          'Commission': 3,
#          'Crimes': 3,
#          'Would': 3,
#          'We': 3,
#          'Time': 3,
#          'Forgotten': 3,
#          'House': 3,
#          'Art': 3,
#          'Naval': 3,
#          'Center': 3,
#          'Business': 3,
#          'Conversation': 3,
#          'Victims': 3,
#          'Stanford': 3,
#          'Political': 3,
#          'Video': 3,
#          'Commons': 3,
#          'archived': 3,
#          'content': 2,
#          'menu': 2,
#          'us': 2,
#          'changesUpload': 2,
#          'pages': 2,
#          'Appearance': 2,
#          'Donate': 2,
#          'Create': 2,
#          'account': 2,
#          'Log': 2,
#          'depression': 2,
#          'Turning': 2,
#          'Background': 2,
#          'Expansion': 2,
#          'begins': 2,
#          'proxy': 2,
#          'communications': 2,
#          'References': 2,
#          'Sources': 2,
#          'External': 2,
#          'contents': 2,
#          'ReadEditView': 2,
#          'Tools': 2,
#          'code': 2,
#          'sparked': 2,
#          'Race': 2,
#          'rockets': 2,
#          'Wide': 2,
#          'significant': 2,
#          'role': 2,
#          'today': 2,
#          'era': 2,
#          'decade': 2,
#          'inventions': 2,
#          'airplane': 2,
#          'genocide': 2,
#          'continent': 2,
#          'Congo': 2,
#          'Sarajevo': 2,
#          'following': 2,
#          'Assassination': 2,
#          'Franz': 2,
#          'Ferdinand': 2,
#          'WWI': 2,
#          'termed': 2,
#          'Austro': 2,
#          'Hungarian': 2,
#          'throne': 2,
#          'movement': 2,
#          'escalation': 2,
#          'comprised': 2,
#          'negotiated': 2,
#          'Brest': 2,
#          'Litovsk': 2,
#          'huge': 2,
#          'Ukraine': 2,
#          'signing': 2,
#          'entrance': 2,
#          'chance': 2,
#          'show': 2,
#          'strength': 2,
#          'technological': 2,
#          'introduced': 2,
#          'machine': 2,
#          'gases': 2,
#          'Both': 2,
#          'test': 2,
#          'best': 2,
#          'defense': 2,
#          'slow': 2,
#          'Division': 2,
#          'forcing': 2,
#          'make': 2,
#          'accept': 2,
#          'democratic': 2,
#          'imposed': 2,
#          'victors': 2,
#          'prevented': 2,
#          'homeland': 2,
#          'prevent': 2,
#          'things': 2,
#          'act': 2,
#          'broke': 2,
#          'globally': 2,
#          'deadliest': 2,
#          'reasons': 2,
#          'trenches': 2,
#          'existing': 2,
#          'overthrow': 2,
#          'revolutions': 2,
#          'believe': 2,
#          'socialist': 2,
#          'defeated': 2,
#          'died': 2,
#          'longer': 2,
#          'concentrated': 2,
#          'Communism': 2,
#          'photo': 2,
#          'iconic': 2,
#          'provided': 2,
#          'activity': 2,
#          'crash': 2,
#          'generally': 2,
#          'situation': 2,
#          'millions': 2,
#          'job': 2,
#          'away': 2,
#          'fascism': 2,
#          'meet': 2,
#          'correct': 2,
#          'however': 2,
#          'little': 2,
#          'alleviate': 2,
#          'suffering': 2,
#          'rather': 2,
#          'approach': 2,
#          'assumed': 2,
#          'services': 2,
#          'birth': 2,
#          'welfare': 2,
#          'belief': 2,
#          'Dictatorship': 2,
#          'business': 2,
#          'defend': 2,
#          'ideology': 2,
#          'Nazism': 2,
#          'Party': 2,
#          'annexation': 2,
#          'slave': 2,
#          'labor': 2,
#          'interests': 2,
#          'racial': 2,
#          'blame': 2,
#          'causing': 2,
#          'Anschluss': 2,
#          'Munich': 2,
#          'avoid': 2,
#          'protect': 2,
#          'Czech': 2,
#          'annexed': 2,
#          'Francisco': 2,
#          'Franco': 2,
#          'achieve': 2,
#          'total': 2,
#          'individual': 2,
#          'perpetrated': 2,
#          'Soon': 2,
#          'officially': 2,
#          'unleashed': 2,
#          'surprise': 2,
#          'acting': 2,
#          'alliance': 2,
#          ...})

# %%
countries = pd.read_csv("List of Countries_2.0.csv", index_col = 0)

# %%
countries.head()
# Out:
#        Country
# 0  Afghanistan
# 1      Albania
# 2      Algeria
# 3      Andorra
# 4       Angola

# %%
countries_list = countries['Country'].to_list()

# %%
dict_of_counts = {d : all_counts[d] for d in countries_list}

# %%
dict_of_counts
# Out:
# {'Afghanistan': 1,
#  'Albania': 2,
#  'Algeria': 1,
#  'Andorra': 0,
#  'Angola': 1,
#  'Antigua and Barbuda': 0,
#  'Argentina': 0,
#  'Armenia': 0,
#  'Australia': 2,
#  'Austria': 5,
#  'Azerbaijan': 0,
#  'Bahamas': 0,
#  'Bahrain': 0,
#  'Bangladesh': 2,
#  'Barbados': 0,
#  'Belarus': 1,
#  'Belgium': 2,
#  'Belize': 0,
#  'Benin': 0,
#  'Bhutan': 0,
#  'Bolivia': 0,
#  'Bosnia and Herzegovina': 0,
#  'Botswana': 0,
#  'Brazil': 0,
#  'Brunei': 0,
#  'Bulgaria': 1,
#  'Burkina Faso': 0,
#  'Burundi': 0,
#  'Cabo Verde': 0,
#  'Cambodia': 2,
#  'Cameroon': 0,
#  'Canada': 2,
#  'Central African Republic': 0,
#  'Chad': 0,
#  'Chile': 0,
#  'China': 10,
#  'Colombia': 0,
#  'Comoros': 0,
#  'Costa Rica': 0,
#  "Côte d'Ivoire": 0,
#  'Croatia': 0,
#  'Cuba': 3,
#  'Cyprus': 0,
#  'Czechia': 0,
#  'Democratic Republic of the Congo': 0,
#  'Denmark': 3,
#  'Djibouti': 0,
#  'Dominica': 0,
#  'Dominican Republic': 0,
#  'Ecuador': 0,
#  'Egypt': 2,
#  'El Salvador': 0,
#  'Equatorial Guinea': 0,
#  'Eritrea': 0,
#  'Estonia': 2,
#  'Eswatini': 0,
#  'Ethiopia': 0,
#  'Fiji': 0,
#  'Finland': 4,
#  'France': 17,
#  'Gabon': 0,
#  'Gambia': 0,
#  'Georgia': 0,
#  'Germany': 41,
#  'Ghana': 1,
#  'Greece': 4,
#  'Grenada': 0,
#  'Guatemala': 0,
#  'Guinea': 4,
#  'Guinea-Bissau': 0,
#  'Guyana': 0,
#  'Haiti': 0,
#  'Honduras': 0,
#  'Hungary': 3,
#  'Iceland': 0,
#  'India': 9,
#  'Indonesia': 0,
#  'Iran': 4,
#  'Iraq': 1,
#  'Ireland': 0,
#  'Israel': 4,
#  'Italy': 14,
#  'Jamaica': 0,
#  'Japan': 33,
#  'Jordan': 0,
#  'Kazakhstan': 0,
#  'Kenya': 1,
#  'Kiribati': 0,
#  'Kuwait': 0,
#  'Kyrgyzstan': 0,
#  'Laos': 1,
#  'Latvia': 2,
#  'Lebanon': 1,
#  'Lesotho': 0,
#  'Liberia': 0,
#  'Libya': 5,
#  'Liechtenstein': 0,
#  'Lithuania': 3,
#  'Luxembourg': 1,
#  'Madagascar': 0,
#  'Malawi': 0,
#  'Malaysia': 0,
#  'Maldives': 0,
#  'Mali': 0,
#  'Malta': 0,
#  'Marshall Islands': 0,
#  'Mauritania': 0,
#  'Mauritius': 0,
#  'Mexico': 1,
#  'Micronesia': 0,
#  'Moldova': 0,
#  'Monaco': 0,
#  'Mongolia': 1,
#  'Montenegro': 0,
#  'Morocco': 1,
#  'Mozambique': 1,
#  'Myanmar': 0,
#  'Namibia': 0,
#  'Nauru': 0,
#  'Nepal': 0,
#  'Netherlands': 2,
#  'New Zealand': 0,
#  'Nicaragua': 0,
#  'Niger': 0,
#  'Nigeria': 0,
#  'North Macedonia': 0,
#  'North Korea': 0,
#  'Norway': 5,
#  'Oman': 0,
#  'Pakistan': 4,
#  'Palau': 0,
#  'Palestine': 0,
#  'Panama': 1,
#  'Papua New Guinea': 0,
#  'Paraguay': 0,
#  'Peru': 0,
#  'Philippines': 5,
#  'Poland': 13,
#  'Portugal': 0,
#  'Qatar': 0,
#  'Republic of the Congo': 0,
#  'Romania': 3,
#  'Russia': 9,
#  'Rwanda': 1,
#  'Saint Kitts and Nevis': 0,
#  'Saint Lucia': 0,
#  'Saint Vincent and the Grenadines': 0,
#  'Samoa': 0,
#  'San Marino': 0,
#  'São Tomé and Príncipe': 0,
#  'Saudi Arabia': 0,
#  'Senegal': 0,
#  'Serbia': 0,
#  'Seychelles': 1,
#  'Sierra Leone': 0,
#  'Singapore': 2,
#  'Slovakia': 0,
#  'Slovenia': 0,
#  'Solomon Islands': 0,
#  'Somalia': 0,
#  'South Africa': 0,
#  'South Korea': 0,
#  'South Sudan': 0,
#  'Spain': 1,
#  'Sri Lanka': 0,
#  'Sudan': 0,
#  'Suriname': 0,
#  'Sweden': 1,
#  'Switzerland': 0,
#  'Syria': 0,
#  'Tajikistan': 0,
#  'Tanzania': 0,
#  'Thailand': 1,
#  'Timor Leste': 0,
#  'Togo': 0,
#  'Tonga': 0,
#  'Trinidad and Tobago': 0,
#  'Tunisia': 0,
#  'Türkiye': 0,
#  'Turkmenistan': 0,
#  'Tuvalu': 0,
#  'Uganda': 0,
#  'Ukraine': 2,
#  'United Arab Emirates': 0,
#  'United Kingdom': 0,
#  'United States': 0,
#  'Uruguay': 0,
#  'Uzbekistan': 0,
#  'Vanuatu': 0,
#  'Vatican City': 0,
#  'Venezuela': 0,
#  'Vietnam': 13,
#  'Yemen': 0,
#  'Zambia': 0,
#  'Zimbabwe': 0}

# %%
# Search for the countries from the list in the dictionary

dct = {v:[k] for v,k in dict_of_counts.items()}  
df = pd.DataFrame(dct)

# %%
df
# Out:
#    Afghanistan  Albania  Algeria  Andorra  Angola  Antigua and Barbuda  \
# 0            1        2        1        0       1                    0
#
#    Argentina  Armenia  Australia  Austria  ...  United States  Uruguay  \
# 0          0        0          2        5  ...              0        0
#
#    Uzbekistan  Vanuatu  Vatican City  Venezuela  Vietnam  Yemen  Zambia  \
# 0           0        0             0          0       13      0       0
#
#    Zimbabwe
# 0         0
#
# [1 rows x 195 columns]

# %%
df = df.transpose().reset_index()

# %%
df.dtypes
# Out:
# index    object
# 0         int64
# dtype: object

# %%
df.head()
# Out:
#          index  0
# 0  Afghanistan  1
# 1      Albania  2
# 2      Algeria  1
# 3      Andorra  0
# 4       Angola  1

# %%
df.rename(columns = {"index":"Country", 0:"Times mentioned"}, inplace = True)

# %%
df.head()
# Out:
#        Country  Times mentioned
# 0  Afghanistan                1
# 1      Albania                2
# 2      Algeria                1
# 3      Andorra                0
# 4       Angola                1

# %%
df.shape
# Out:
# (195, 2)

# %%
df = df.groupby("Country")["Times mentioned"].sum().reset_index()

# %%
df_top10 = df_top.sort_values("Times mentioned", ascending=False).head(10)

# %%
df_top10.head(10)
# Out:
#      Country  Times mentioned
# 63   Germany               41
# 83     Japan               33
# 59    France               17
# 81     Italy               14
# 191  Vietnam               13
# 137   Poland               13
# 35     China               10
# 142   Russia                9
# 75     India                9
# 9    Austria                5

# %%
# Plot
plt.figure(figsize=(10, 5))
ax = sns.barplot(
    x="Times mentioned",
    y="Country",
    data=df_top10
)

# Add title
ax.set_title("Most frequently mentioned countries")
plt.show()

# %%
df_top10.to_csv("top10_mentioned_countries.csv")

# %%
df.to_csv("mentioned_countries.csv")
