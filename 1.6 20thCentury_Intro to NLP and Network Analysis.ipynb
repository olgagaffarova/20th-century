# %% [markdown]
# # 1.6 Intro to NLP and Network Analysis

# %%
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
# Load spacy English module

NER = spacy.load("en_core_web_sm")

# %% [markdown]
# ## Data wrangling

# %%
with open('Key events of the 20th century_without references.txt', 'r', errors='ignore') as file:
    data = file.read().replace('\n', '')

# %%
# The text contained newline characters (\n), numbered references in square brackets (e.g., [1], [2]), and extra spaces, which could interfere with tokenization.
# There were also a few special characters (such as *) that were not relevant for analysis.

# %%
# Clean text: remove newlines, brackets, extra spaces
cleaned_data = re.sub(r'\n+', ' ', data)
cleaned_data = re.sub(r'\[[0-9]+\]', '', cleaned_data)     # remove [1], [2], etc.
cleaned_data = re.sub(r'\s+', ' ', cleaned_data).strip()   # normalize spaces
cleaned_data = re.sub(r'[^A-Za-z0-9\s.,;:\'\"-]', '', cleaned_data)  # remove odd symbols

# %%
with open("Key_events_cleaned.txt", "w") as f:
    f.write(cleaned_data)

# %% [markdown]
# ## NER

# %%
book = NER(cleaned_data)

# %%
# Visualize identified entities

displacy.render(book[273:20000], style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">centuryeditMain article:
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Edwardian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  eraThe new beginning of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 20th century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  marked significant changes.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The 1900s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  saw
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the decade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  herald a series of inventions, including the automobile, airplane and radio broadcasting.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1914
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  saw the completion of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Panama Canal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .The
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Scramble
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  for
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  continued in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 1900s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and resulted in wars and genocide across the continent. The atrocities in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Congo Free State
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  shocked the civilized world.From
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1914 to 1918
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the First World War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# , and its aftermath, caused major changes in the power balance of the world, destroying or transforming some of the most powerful empires.&quot;The war to end all wars&quot;:
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  I 19141918editMain article:
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World War IArrest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  of a suspect in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sarajevo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  following
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Assassination of Archduke Franz FerdinandThe First World War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  or simply
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WWI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , termed &quot;
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Great War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# &quot; by contemporaries, started in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July 1914
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and ended in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     November 1918
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The war was precipitated by the Assassination in Sarajevo of the Austro-Hungarian Empire's heir to the throne,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Erzherzog Franz Ferdinand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gavrilo Princip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a member of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Young Bosnia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  liberation move

# %% [markdown]
# ## Get named entity list per sentence

# %%
df_sentences = [] # empty shell to store results

# Loop through sentences, get entity list for each sentence
for sent in book.sents:
    entity_list = [ent.text for ent in sent.ents]
    df_sentences.append({"sentence": sent, "entities": entity_list})
    
df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences.head(10)
# Out:
#                                             sentence  \
# 0  (Key, events, of, the, 20th, century, -, Wikip...
# 1  (World, War, II, 193919451.4.1The, war, in, Eu...
# 2  (decolonization1.5.2The, Cold, War, 194719911....
# 3  (race1.5.5The, end, of, the, Cold, War1.5.6Inf...
# 4  (The, World, Wars, sparked, tension, between, ...
# 5  (These, advancements, have, played, a, signifi...
# 6  (Historic, events, in, the, 20th, centuryeditW...
# 7  (Edwardian, eraThe, new, beginning, of, the, 2...
# 8  (The, 1900s, saw, the, decade, herald, a, seri...
# 9  (1914, saw, the, completion, of, the, Panama, ...
#
#                                             entities
# 0  [the 20th century - WikipediaJump, Navigation ...
# 1  [World War II, Pacific1.4.7.1Background1.4.8Ja...
# 2                        [Cold War 194719911.5.3War]
# 3  [the Cold War1.5.6Information, 20th, Actions, ...
# 4                     [the Cold War, the Space Race]
# 5                          [the 21st century, today]
# 6                                         [the 20th]
# 7                      [Edwardian, the 20th century]
# 8                            [The 1900s, the decade]
# 9                           [1914, the Panama Canal]

# %% [markdown]
# ## Mapping and Normalisation

# %%
country_map = {
    # Soviet Union variations
    'Soviet Union': 'Russia',
    'Soviet': 'Russia',
    'USSR': 'Russia',
    'Union of Soviet Socialist Republics': 'Russia',

    # United States variations
    'United States of America': 'United States',
    'United States': 'United States',
    'America': 'United States',
    'US': 'United States',
    'U.S.': 'United States',

    # United Kingdom variations
    'UK': 'United Kingdom',
    'U.K.': 'United Kingdom',
    'Britain': 'United Kingdom',
    'Great Britain': 'United Kingdom',
    'England': 'United Kingdom'
}

# %%
from typing import Sequence, List

def normalise_countries(entities: Sequence[str], country_map: dict[str, str]) -> List[str]:
    """Apply manual normalisations used in the original notebook."""
    return [country_map.get(name, name) for name in entities]

# %%
normalised = normalise_countries(["US", "UK"], country_map)

# %%
#  country_map
entities_normalised = []
for entities in entities_per_sentence:
    normalised = [country_map.get(e, e) for e in entities]
    entities_normalised.append(normalised)

# %%
nlp = spacy.load("en_core_web_sm")   

entities_per_sentence = []
for sent in nlp(book).sents:
    doc = nlp(sent.text)
    entities = [ent.text for ent in doc.ents if ent.label_ == "GPE"]
    entities_per_sentence.append(entities)

# %%
df_sentences = pd.DataFrame({
    'Sentence': [sent.text for sent in nlp(book).sents],
    'Country': entities_per_sentence
})

# %% [markdown]
# ## Load country names

# %%
df_countries = pd.read_csv("List of Countries_2.0.csv", index_col = 0)

# %%
df_countries.head()
# Out:
#        Country
# 0  Afghanistan
# 1      Albania
# 2      Algeria
# 3      Andorra
# 4       Angola

# %%
valid_countries = df_countries['Country'].tolist()

entities_filtered = []
for entities in entities_normalised:
    filtered = [e for e in entities if e in entities_normalised]
    entities_filtered.append(filtered)

# %%
# Apply normalization and filtering using lambda

# Normalize country names
df_sentences['Country'] = df_sentences['Country'].apply(
    lambda lst: [country_map.get(e, e) for e in lst]
)

# Keep only countries that exist in the CSV country list
df_sentences['Country'] = df_sentences['Country'].apply(
    lambda lst: [e for e in lst if e in valid_countries]
)

# %%
# Filter out rows that don't contain any country entities
df_sentences_filtered = df_sentences[df_sentences['Country'].map(len) > 0]

# %%
df_sentences_filtered.head(10)
# Out:
#                                              Sentence  \
# 15  After a period of diplomatic and military esca...
# 16  In 1917, Russia ended hostile actions against ...
# 17  The Bolsheviks negotiated the Treaty of Brest-...
# 18  In the treaty, Bolshevik Russia ceded the Balt...
# 19    It also recognized the independence of Ukraine.
# 20  Although Germany shifted huge forces from the ...
# 29  Germany was never occupied by Allied troops, y...
# 58  Germany, 1933Fascism first appeared in Italy w...
# 60  When Adolf Hitler came to power in Germany in ...
# 61  The Nazi Party in Germany was dedicated to the...
#
#                        Country
# 15  [France, Austria, Hungary]
# 16                    [Russia]
# 17           [Germany, Russia]
# 18                   [Germany]
# 19                   [Ukraine]
# 20                   [Germany]
# 29                   [Germany]
# 58            [Germany, Italy]
# 60          [Germany, Germany]
# 61                   [Germany]

# %% [markdown]
# ## Create relationships

# %%
# Defining relationships 

# window size = 5 : this defines how many sentences will be looked at simultaneously 
relationships = [] # create an empty list

for i in range(df_sentences_filtered.index[-1]):
    end_i = min(i+5, df_sentences_filtered.index[-1])
    char_list = sum((df_sentences_filtered.loc[i: end_i].Country), [])
    
    # Remove duplicated characters that are next to each other
    char_unique = [char_list[i] for i in range(len(char_list)) 
                   if (i==0) or char_list[i] != char_list[i-1]]
    
    if len(char_unique) > 1:
        for idx, a in enumerate(char_unique[:-1]):
            b = char_unique[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
relationship_df = pd.DataFrame(relationships)

# %%
relationship_df
# Out:
#            source       target
# 0          France      Austria
# 1         Austria      Hungary
# 2          France      Austria
# 3         Austria      Hungary
# 4         Hungary       Russia
# ..            ...          ...
# 871  South Africa       Rwanda
# 872  South Africa       Rwanda
# 873  South Africa       Rwanda
# 874        Rwanda  North Korea
# 875        Rwanda  North Korea
#
# [876 rows x 2 columns]

# %%
# Sort the cases with a->b and b->a

relationship_df = pd.DataFrame(np.sort(relationship_df.values, axis = 1), columns = relationship_df.columns)
relationship_df.head()
# Out:
#     source   target
# 0  Austria   France
# 1  Austria  Hungary
# 2  Austria   France
# 3  Austria  Hungary
# 4  Hungary   Russia

# %%
# Summarize the interactions

relationship_df["value"] = 1
relationship_df = relationship_df.groupby(["source","target"], sort=False, as_index=False).sum()

# %%
relationship_df.head(10)
# Out:
#     source          target  value
# 0  Austria          France      6
# 1  Austria         Hungary      6
# 2  Hungary          Russia      5
# 3  Germany          Russia     33
# 4  Germany         Ukraine     10
# 5  Germany           Italy     26
# 6  Austria         Germany     10
# 7   France  United Kingdom     24
# 8   France          Poland      6
# 9   Poland  United Kingdom      5

# %%
relationship_df.shape
# Out:
# (114, 3)

# %%
relationship_df.to_csv('NER_countries_relationship.csv')
